# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.ensemble import RandomForestClassifier
# from lightgbm import LGBMClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, cohen_kappa_score

import os
import re
import gc
import warnings
import pickle
from tqdm import tqdm

import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
from matplotlib import rc

# %%
companies = ['VTBR', 'GAZP', 'SBER', 'NVTK', 'ROSN']

# %% [markdown]
# ## Кросс-валидация Телеграмм

# %% [markdown]
# ### Три класса

# %%
tg = pd.read_csv('final_data/df.csv')
tg_train = tg[tg.date < '2021-06-01'].copy()
tg_test = tg[(tg.date < '2022-01-01') & (tg.date > '2021-06-01')].copy()
# Out:
# /tmp/ipykernel_120799/4016276028.py:1: DtypeWarning: Columns (5,16) have mixed types. Specify dtype option on import or set low_memory=False.
#   tg = pd.read_csv('final_data/df.csv')

# %%
df = pd.DataFrame(index=['acc_test', 'pre_test', 'rec_test', 'auc_test', 'f1_test', 'kappa_test'])

# %%
os.makedirs('tg_loggs', exist_ok=True)

targets = tg_train.iloc[:,3:].columns
tfidf = TfidfVectorizer(sublinear_tf=True, min_df=5, ngram_range=(1,2), max_features=10000)
tfidf.fit(tg_train.message.values)
for company in companies:
  n_jobs=-1
  print(company)
  os.makedirs(f'tg_loggs/{company}', exist_ok=True)

  comp_train = tg_train[tg_train[company] == True].copy()
  comp_test = tg_test[tg_test[company] == True].copy()

  features_train = tfidf.transform(comp_train['message'].values)
  features_test = tfidf.transform(comp_test['message'].values)

  features_train = np.asarray(features_train.todense())
  features_test = np.asarray(features_test.todense())

  tr = [col for col in targets if company in col]
  if company in tr:
    tr.remove(company)

  for t in tr:
    y_train = comp_train[t].values.astype(int)
    y_test = comp_test[t].values.astype(int)

    one_hot_y_test = np.zeros((y_test.size, 2), dtype=int)
    one_hot_y_test[np.arange(y_test.size), y_test] = 1
    one_hot_y_test

    param_grid = {'max_depth': list(range(5, 14))}

    clf = RandomForestClassifier(random_state=123, n_estimators=200, criterion='entropy', n_jobs=-1, class_weight='balanced')

    if company in ['GAZP', 'SBER', 'VTBR']:
      n_jobs=1

    gc = GridSearchCV(estimator=clf, param_grid=param_grid, cv=4, n_jobs=n_jobs, scoring='accuracy', verbose=2)
    gc.fit(features_train, y_train)

    preds_test = gc.predict(features_test)
    preds_proba_test = gc.predict_proba(features_test)

    acc_test = accuracy_score(y_test, preds_test)
    pre_test = precision_score(y_test, preds_test, average='weighted')
    rec_test = recall_score(y_test, preds_test, average='weighted')
    auc_test = roc_auc_score(one_hot_y_test, preds_proba_test, average='weighted', multi_class='ovo')
    f1_test = f1_score(y_test, preds_test, average='weighted')
    kappa_test = cohen_kappa_score(y_test, preds_test)

    df[t] = [acc_test, pre_test, rec_test, auc_test, f1_test, kappa_test]

    filename = f'tg_loggs/{company}/{t}_neutral_all.sav'
    pickle.dump(gc, open(filename, 'wb'))

    df.to_csv('tg_loggs/all_loggs_neutral_all.csv')
# Out:
# VTBR
# Fitting 4 folds for each of 9 candidates, totalling 36 fits
# [CV] END ........................................max_depth=5; total time=   8.1s
# [CV] END ........................................max_depth=5; total time=   6.9s
# [CV] END ........................................max_depth=5; total time=  10.2s
# [CV] END ........................................max_depth=5; total time=   7.9s
# [CV] END ........................................max_depth=6; total time=   7.7s
# [CV] END ........................................max_depth=6; total time=   7.1s
# [CV] END ........................................max_depth=6; total time=   4.9s
# [CV] END ........................................max_depth=6; total time=   4.9s
# [CV] END ........................................max_depth=7; total time=   5.6s
# [CV] END ........................................max_depth=7; total time=   5.3s
# [CV] END ........................................max_depth=7; total time=   5.5s
# [CV] END ........................................max_depth=7; total time=   5.3s
# [CV] END ........................................max_depth=8; total time=   5.6s
# [CV] END ........................................max_depth=8; total time=   5.0s
# [CV] END ........................................max_depth=8; total time=   3.9s
# [CV] END ........................................max_depth=8; total time=   5.0s
# [CV] END ........................................max_depth=9; total time=   4.1s
# [CV] END ........................................max_depth=9; total time=   4.3s
# [CV] END ........................................max_depth=9; total time=   5.5s
# [CV] END ........................................max_depth=9; total time=   6.3s
# [CV] END .......................................max_depth=10; total time=   6.6s
# [CV] END .......................................max_depth=10; total time=   6.6s
# [CV] END .......................................max_depth=10; total time=   6.0s
# [CV] END .......................................max_depth=10; total time=   5.7s
# [CV] END .......................................max_depth=11; total time=   6.1s
# [CV] END .......................................max_depth=11; total time=   6.1s
# [CV] END .......................................max_depth=11; total time=   6.1s
# [CV] END .......................................max_depth=11; total time=   6.3s
# [CV] END .......................................max_depth=12; total time=   6.7s
# [CV] END .......................................max_depth=12; total time=   6.5s
# [CV] END .......................................max_depth=12; total time=   6.6s
# [CV] END .......................................max_depth=12; total time=   6.4s
# [CV] END .......................................max_depth=13; total time=   7.1s
# [CV] END .......................................max_depth=13; total time=   7.1s
# [CV] END .......................................max_depth=13; total time=   7.5s
# [CV] END .......................................max_depth=13; total time=   8.1s
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 44
#      42 pre_test = precision_score(y_test, preds_test, average='weighted')
#      43 rec_test = recall_score(y_test, preds_test, average='weighted')
# ---> 44 auc_test = roc_auc_score(y_test, preds_proba_test, average='weighted', multi_class='ovo')
#      45 f1_test = f1_score(y_test, preds_test, average='weighted')
#      46 kappa_test = cohen_kappa_score(y_test, preds_test)
#
# File ~/miniconda3/lib/python3.12/site-packages/sklearn/utils/_param_validation.py:216, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     210 try:
#     211     with config_context(
#     212         skip_parameter_validation=(
#     213             prefer_skip_nested_validation or global_skip_validation
#     214         )
#     215     ):
# --> 216         return func(*args, **kwargs)
#     217 except InvalidParameterError as e:
#     218     # When the function is just a wrapper around an estimator, we allow
#     219     # the function to delegate validation to the estimator, but we replace
#     220     # the name of the estimator by the name of the function in the error
#     221     # message to avoid confusion.
#     222     msg = re.sub(
#     223         r"parameter of \w+ must be",
#     224         f"parameter of {func.__qualname__} must be",
#     225         str(e),
#     226     )
#
# File ~/miniconda3/lib/python3.12/site-packages/sklearn/metrics/_ranking.py:641, in roc_auc_score(y_true, y_score, average, sample_weight, max_fpr, multi_class, labels)
#     639     labels = np.unique(y_true)
#     640     y_true = label_binarize(y_true, classes=labels)[:, 0]
# --> 641     return _average_binary_score(
#     642         partial(_binary_roc_auc_score, max_fpr=max_fpr),
#     643         y_true,
#     644         y_score,
#     645         average,
#     646         sample_weight=sample_weight,
#     647     )
#     648 else:  # multilabel-indicator
#     649     return _average_binary_score(
#     650         partial(_binary_roc_auc_score, max_fpr=max_fpr),
#     651         y_true,
#    (...)
#     654         sample_weight=sample_weight,
#     655     )
#
# File ~/miniconda3/lib/python3.12/site-packages/sklearn/metrics/_base.py:69, in _average_binary_score(binary_metric, y_true, y_score, average, sample_weight)
#      66     raise ValueError("{0} format is not supported".format(y_type))
#      68 if y_type == "binary":
# ---> 69     return binary_metric(y_true, y_score, sample_weight=sample_weight)
#      71 check_consistent_length(y_true, y_score, sample_weight)
#      72 y_true = check_array(y_true)
#
# File ~/miniconda3/lib/python3.12/site-packages/sklearn/metrics/_ranking.py:388, in _binary_roc_auc_score(y_true, y_score, sample_weight, max_fpr)
#     379     warnings.warn(
#     380         (
#     381             "Only one class is present in y_true. ROC AUC score "
#    (...)
#     384         UndefinedMetricWarning,
#     385     )
#     386     return np.nan
# --> 388 fpr, tpr, _ = roc_curve(y_true, y_score, sample_weight=sample_weight)
#     389 if max_fpr is None or max_fpr == 1:
#     390     return auc(fpr, tpr)
#
# File ~/miniconda3/lib/python3.12/site-packages/sklearn/utils/_param_validation.py:189, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     187 global_skip_validation = get_config()["skip_parameter_validation"]
#     188 if global_skip_validation:
# --> 189     return func(*args, **kwargs)
#     191 func_sig = signature(func)
#     193 # Map *args/**kwargs to the function signature
#
# File ~/miniconda3/lib/python3.12/site-packages/sklearn/metrics/_ranking.py:1150, in roc_curve(y_true, y_score, pos_label, sample_weight, drop_intermediate)
#    1046 @validate_params(
#    1047     {
#    1048         "y_true": ["array-like"],
#    (...)
#    1057     y_true, y_score, *, pos_label=None, sample_weight=None, drop_intermediate=True
#    1058 ):
#    1059     """Compute Receiver operating characteristic (ROC).
#    1060
#    1061     Note: this implementation is restricted to the binary classification task.
#    (...)
#    1148     array([ inf, 0.8 , 0.4 , 0.35, 0.1 ])
#    1149     """
# -> 1150     fps, tps, thresholds = _binary_clf_curve(
#    1151         y_true, y_score, pos_label=pos_label, sample_weight=sample_weight
#    1152     )
#    1154     # Attempt to drop thresholds corresponding to points in between and
#    1155     # collinear with other points. These are always suboptimal and do not
#    1156     # appear on a plotted ROC curve (and thus do not affect the AUC).
#    (...)
#    1161     # but does not drop more complicated cases like fps = [1, 3, 7],
#    1162     # tps = [1, 2, 4]; there is no harm in keeping too many thresholds.
#    1163     if drop_intermediate and len(fps) > 2:
#
# File ~/miniconda3/lib/python3.12/site-packages/sklearn/metrics/_ranking.py:822, in _binary_clf_curve(y_true, y_score, pos_label, sample_weight)
#     820 check_consistent_length(y_true, y_score, sample_weight)
#     821 y_true = column_or_1d(y_true)
# --> 822 y_score = column_or_1d(y_score)
#     823 assert_all_finite(y_true)
#     824 assert_all_finite(y_score)
#
# File ~/miniconda3/lib/python3.12/site-packages/sklearn/utils/validation.py:1485, in column_or_1d(y, dtype, warn, device)
#    1472         warnings.warn(
#    1473             (
#    1474                 "A column-vector y was passed when a 1d array was"
#    (...)
#    1479             stacklevel=2,
#    1480         )
#    1481     return _asarray_with_order(
#    1482         xp.reshape(y, (-1,)), order="C", xp=xp, device=device
#    1483     )
# -> 1485 raise ValueError(
#    1486     "y should be a 1d array, got an array of shape {} instead.".format(shape)
#    1487 )
#
# ValueError: y should be a 1d array, got an array of shape (2036, 2) instead.

# %%
df = pd.DataFrame(index=['acc_test', 'pre_test', 'rec_test', 'auc_test', 'f1_test', 'kappa_test'])

# %%
targets = tg_train.iloc[:,3:].columns
tfidf = TfidfVectorizer(sublinear_tf=True, min_df=5, ngram_range=(1,2), max_features=10000)
tfidf.fit(tg_train.message.values)
for company in companies:
  n_jobs=-1
  print(company)
  os.makedirs(f'/content/drive/MyDrive/Диссертация/tg_loggs/{company}', exist_ok=True)
  first_dates = pd.read_csv(f'/content/drive/MyDrive/Диссертация/Парсеры сайтов/Стоимость акций/1 мин/first_dates.csv', index_col='company')
  first_day = pd.to_datetime(first_dates.loc[company,:].values[0])

  comp_train = tg_train[tg_train[company] == True].copy()
  comp_test = tg_test[tg_test[company] == True].copy()

  features_train = tfidf.transform(comp_train['message'].values)
  features_test = tfidf.transform(comp_test['message'].values)

  features_train = np.asarray(features_train.todense())
  features_test = np.asarray(features_test.todense())

  tr = [col for col in targets if company in col]
  if company in tr:
    tr.remove(company)

  for t in tr:
    y_train = comp_train[t].values.astype(int)
    y_test = comp_test[t].values.astype(int)

    param_grid = {'max_depth': list(range(5, 14))}

    clf = LGBMClassifier(random_state=123, n_jobs=-1, class_weight='balanced',  n_estimators=200)

    if company in ['GAZP', 'SBER', 'VTBR']:
      n_jobs=1

    gc = GridSearchCV(estimator=clf, param_grid=param_grid, cv=4, n_jobs=n_jobs, scoring='accuracy', verbose=2)
    gc.fit(features_train, y_train)

    preds_test = gc.predict(features_test)
    preds_proba_test = gc.predict_proba(features_test)

    acc_test = accuracy_score(y_test, preds_test)
    pre_test = precision_score(y_test, preds_test, average='weighted')
    rec_test = recall_score(y_test, preds_test, average='weighted')
    auc_test = roc_auc_score(y_test, preds_proba_test, average='weighted', multi_class='ovo')
    f1_test = f1_score(y_test, preds_test, average='weighted')
    kappa_test = cohen_kappa_score(y_test, preds_test)

    df[t] = [acc_test, pre_test, rec_test, auc_test, f1_test, kappa_test]

    filename = f'/content/drive/MyDrive/Диссертация/tg_loggs/{company}/{t}_neutral_all_boosting.sav'
    pickle.dump(gc, open(filename, 'wb'))

    df.to_csv('/content/drive/MyDrive/Диссертация/tg_loggs/all_loggs_neutral_all_boosting.csv')

# %% [markdown]
# ### Два класса

# %%
tg = pd.read_parquet('/content/drive/MyDrive/Диссертация/Парсеры сайтов/tg_comps.parquet')
tg_train = tg[tg.date < '2021-06-01'].copy()
tg_test = tg[(tg.date < '2022-01-01') & (tg.date > '2021-06-01')].copy()

# %%
df = pd.read_csv('/content/drive/MyDrive/Диссертация/tg_loggs/all_loggs_all.csv', index_col=0)

# %%
df

# %%
df = pd.DataFrame(index=['acc_test', 'pre_test', 'rec_test', 'auc_test', 'f1_test', 'kappa_test'])

# %%
targets = tg_train.iloc[:,3:].columns
tfidf = TfidfVectorizer(sublinear_tf=True, min_df=5, ngram_range=(1,2), max_features=10000)
tfidf.fit(tg_train.message.values)
for company in companies:
  n_jobs=-1
  print(company)
  os.makedirs(f'/content/drive/MyDrive/Диссертация/tg_loggs/{company}', exist_ok=True)
  first_dates = pd.read_csv(f'/content/drive/MyDrive/Диссертация/Парсеры сайтов/Стоимость акций/1 мин/first_dates.csv', index_col='company')
  first_day = pd.to_datetime(first_dates.loc[company,:].values[0])

  comp_train = tg_train[tg_train[company] == True].copy()
  comp_test = tg_test[tg_test[company] == True].copy()

  features_train = tfidf.transform(comp_train['message'].values)
  features_test = tfidf.transform(comp_test['message'].values)

  features_train = np.asarray(features_train.todense())
  features_test = np.asarray(features_test.todense())

  tr = [col for col in targets if company in col]
  if company in tr:
    tr.remove(company)

  for t in tr:
    y_train = comp_train[t].values.astype(int)
    y_test = comp_test[t].values.astype(int)

    param_grid = {'max_depth': list(range(5, 14))}

    clf = RandomForestClassifier(random_state=123, n_estimators=200, criterion='entropy', n_jobs=-1, class_weight='balanced')

    if company in ['GAZP', 'SBER', 'VTBR']:
      n_jobs=1

    gc = GridSearchCV(estimator=clf, param_grid=param_grid, cv=4, n_jobs=n_jobs, scoring='accuracy', verbose=2)
    gc.fit(features_train, y_train)

    preds_test = gc.predict(features_test)
    preds_proba_test = gc.predict_proba(features_test)

    acc_test = accuracy_score(y_test, preds_test)
    pre_test = precision_score(y_test, preds_test)
    rec_test = recall_score(y_test, preds_test)
    auc_test = roc_auc_score(y_test, preds_proba_test[:,1])
    f1_test = f1_score(y_test, preds_test)
    kappa_test = cohen_kappa_score(y_test, preds_test)

    df[t] = [acc_test, pre_test, rec_test, auc_test, f1_test, kappa_test]

    filename = f'/content/drive/MyDrive/Диссертация/tg_loggs/{company}/{t}_all.sav'
    pickle.dump(gc, open(filename, 'wb'))

    df.to_csv('/content/drive/MyDrive/Диссертация/tg_loggs/all_loggs_all.csv')

# %%
df = pd.DataFrame(index=['acc_test', 'pre_test', 'rec_test', 'auc_test', 'f1_test', 'kappa_test'])

# %%
targets = tg_train.iloc[:,3:].columns
tfidf = TfidfVectorizer(sublinear_tf=True, min_df=5, ngram_range=(1,2), max_features=10000)
tfidf.fit(tg_train.message.values)
for company in companies:
  n_jobs=-1
  print(company)
  os.makedirs(f'/content/drive/MyDrive/Диссертация/tg_loggs/{company}', exist_ok=True)
  first_dates = pd.read_csv(f'/content/drive/MyDrive/Диссертация/Парсеры сайтов/Стоимость акций/1 мин/first_dates.csv', index_col='company')
  first_day = pd.to_datetime(first_dates.loc[company,:].values[0])

  comp_train = tg_train[tg_train[company] == True].copy()
  comp_test = tg_test[tg_test[company] == True].copy()

  features_train = tfidf.transform(comp_train['message'].values)
  features_test = tfidf.transform(comp_test['message'].values)

  features_train = np.asarray(features_train.todense())
  features_test = np.asarray(features_test.todense())

  tr = [col for col in targets if company in col]
  if company in tr:
    tr.remove(company)

  for t in tr:
    y_train = comp_train[t].values.astype(int)
    y_test = comp_test[t].values.astype(int)

    param_grid = {'max_depth': list(range(5, 14))}

    clf = LGBMClassifier(random_state=123, n_jobs=-1, class_weight='balanced',  n_estimators=200)

    if company in ['GAZP', 'SBER', 'VTBR']:
      n_jobs=1

    gc = GridSearchCV(estimator=clf, param_grid=param_grid, cv=4, n_jobs=n_jobs, scoring='accuracy', verbose=2)
    gc.fit(features_train, y_train)

    preds_test = gc.predict(features_test)
    preds_proba_test = gc.predict_proba(features_test)

    acc_test = accuracy_score(y_test, preds_test)
    pre_test = precision_score(y_test, preds_test, average='weighted')
    rec_test = recall_score(y_test, preds_test, average='weighted')
    auc_test = roc_auc_score(y_test, preds_proba_test, average='weighted', multi_class='ovo')
    f1_test = f1_score(y_test, preds_test, average='weighted')
    kappa_test = cohen_kappa_score(y_test, preds_test)

    df[t] = [acc_test, pre_test, rec_test, auc_test, f1_test, kappa_test]

    filename = f'/content/drive/MyDrive/Диссертация/tg_loggs/{company}/{t}_all_boosting.sav'
    pickle.dump(gc, open(filename, 'wb'))

    df.to_csv('/content/drive/MyDrive/Диссертация/tg_loggs/all_loggs_all_boosting.csv')

# %% [markdown]
# ## Кросс-валидация традиционные новости

# %%
news = pd.read_parquet('/content/drive/MyDrive/Диссертация/Парсеры сайтов/news.parquet')
news = news[news.date < '2022-01-01'].copy()
news.drop(columns=sectors, inplace=True)
news['message'] = news['title'] + ' ' + news['announce']
news.drop(columns=['link', 'title', 'announce', 'text'], inplace=True)

# %%
targets = news.iloc[:,3:-1].columns
for company in companies:
  print(company)
  os.makedirs(f'/content/drive/MyDrive/Диссертация/news_loggs/{company}', exist_ok=True)
  first_dates = pd.read_csv(f'/content/drive/MyDrive/Диссертация/Парсеры сайтов/Стоимость акций/1 мин/first_dates.csv', index_col='date')
  first_day = pd.to_datetime(first_dates.loc[company,:].values[0])
  comp = news[news[company] == True].copy()
  comp = comp[comp.date >= first_day].copy()
  comp.dropna(inplace=True)

  tfidf = TfidfVectorizer(sublinear_tf=True, min_df=5, ngram_range=(1,2))

  train, test = comp.iloc[:int(0.8*len(comp)), :], comp.iloc[int(0.8*len(comp)):, :]
  tfidf.fit(comp['message'])

  features_train = tfidf.transform(train['message'])
  features_test = tfidf.transform(test['message'])

  X_train = np.asarray(features_train.todense())
  X_test = np.asarray(features_test.todense())

  tr = [col for col in targets if company in col]

  test_logg = []
  train_logg = []

  for t in tr:
    y_train = train[t].values.astype(int)
    y_test = test[t].values.astype(int)

    param_grid = {
        'max_depth' : list(range(3,13))}

    clf = RandomForestClassifier(random_state=123, criterion='entropy', n_jobs=-1)
    gc = GridSearchCV(estimator=clf, param_grid=param_grid, cv=4, n_jobs=1, scoring='accuracy', verbose=2)
    gc.fit(X_train, y_train)

    preds_test = gc.predict(X_test)
    preds_train = gc.predict(X_train)

    preds_proba_test = gc.predict_proba(X_test)
    preds_proba_train = gc.predict_proba(X_train)

    test_logg.append(np.mean(y_test==preds_test))
    train_logg.append(np.mean(y_train==preds_train))

  with open(f'/content/drive/MyDrive/Диссертация/news_loggs/{company}/{company}_cv_rf_train_logg.txt', 'w') as fp:
    for item in train_logg:
        fp.write("%s\n" % item)
  with open(f'/content/drive/MyDrive/Диссертация/news_loggs/{company}/{company}_cv_rf_test_logg.txt', 'w') as fp:
    for item in test_logg:
        fp.write("%s\n" % item)

  
  print(f'{company} done')

# %%
targets = news.iloc[:,3:-1].columns
for company in companies:
  print(company)
  os.makedirs(f'/content/drive/MyDrive/Диссертация/news_loggs/{company}', exist_ok=True)
  first_dates = pd.read_csv(f'/content/drive/MyDrive/Диссертация/Парсеры сайтов/Стоимость акций/1 мин/first_dates.csv', index_col='date')
  first_day = pd.to_datetime(first_dates.loc[company,:].values[0])
  comp = news[news[company] == True].copy()
  comp = comp[comp.date >= first_day].copy()
  comp.dropna(inplace=True)

  tfidf = TfidfVectorizer(sublinear_tf=True, min_df=5, ngram_range=(1,2))

  train, test = comp.iloc[:int(0.8*len(comp)), :], comp.iloc[int(0.8*len(comp)):, :]
  tfidf.fit(comp['message'])

  features_train = tfidf.transform(train['message'])
  features_test = tfidf.transform(test['message'])

  X_train = np.asarray(features_train.todense())
  X_test = np.asarray(features_test.todense())

  tr = [col for col in targets if company in col]

  test_logg = []
  train_logg = []

  for t in tr:
    y_train = train[t].values.astype(int)
    y_test = test[t].values.astype(int)

    param_grid = {
        'max_depth' : list(range(3,13))}

    clf = LGBMClassifier(random_state=123, n_jobs=-1)
    gc = GridSearchCV(estimator=clf, param_grid=param_grid, cv=4, n_jobs=-1, scoring='accuracy', verbose=2)
    gc.fit(X_train, y_train)

    preds_test = gc.predict(X_test)
    preds_train = gc.predict(X_train)

    test_logg.append(np.mean(y_test==preds_test))
    train_logg.append(np.mean(y_train==preds_train))

  with open(f'/content/drive/MyDrive/Диссертация/news_loggs/{company}/{company}_cv_boosting_train_logg.txt', 'w') as fp:
    for item in train_logg:
        fp.write("%s\n" % item)
  with open(f'/content/drive/MyDrive/Диссертация/news_loggs/{company}/{company}_cv_boosting_test_logg.txt', 'w') as fp:
    for item in test_logg:
        fp.write("%s\n" % item)

  
  print(f'{company} done')

# %% [markdown]
# ## Тесты на значимость полученных результатов

# %%
def sample_test(prob1, test_values, n_times=1000):
  accs = []
  for _ in range(n_times):
    rand_test = np.random.choice([0, 1], size=len(test_values), replace=True, p=[1-prob1, prob1])
    acc = (test_values == rand_test).sum() / len(test_values)
    accs.append(acc)
  return np.mean(accs) + np.std(accs)

# %%
def _color_red_or_green(val):
    color = 'red' if val < 0 else 'green'
    return 'color: %s' % color

# %%
def sample_test_neutral(probs, test_values, n_times=1000):
  accs = []
  for _ in range(n_times):
    rand_test = np.random.choice([-1, 0, 1], size=len(test_values), replace=True, p=probs)
    acc = (test_values == rand_test).sum() / len(test_values)
    accs.append(acc)
  return np.mean(accs) + np.std(accs)

# %%
def test_const(test_values):
  zeros = np.zeros(len(test_values))
  f1 = f1_score(test_values, zeros, average='weighted')
  return f1

# %%
def get_effects_bin(df_train, df_test, loggs, companies=companies, shortened=False):
  if shortened:
    effects = pd.DataFrame(columns=['5 min', '10 min', '15 min', '30 min', '1 hour', '1 day'], index=companies)
  else:
    effects = pd.DataFrame(columns=['1 min', '5 min', '10 min', '15 min', '30 min', '1 hour', '1 day'], index=companies)

  targets = df_train.columns
  first_dates = pd.read_csv(f'/content/drive/MyDrive/Диссертация/Парсеры сайтов/Стоимость акций/1 мин/first_dates.csv', index_col='company')
  for company in companies:
    first_day = pd.to_datetime(first_dates.loc[company,:].values[0])

    comp_train = df_train[df_train[company] == True].copy()
    comp_test = df_test[df_test[company] == True].copy()

    comp_train = comp_train[comp_train.date >= first_day].copy()
    test_accs = loggs.loc['acc_test',:]

    tr = [col for col in targets if company in col]
    if company in tr:
      tr.remove(company)
    if shortened:
      tr = tr[1:]

    res = []
    for t in tr:
      ba = comp_train[t].mean()
      te = test_accs[t]
      best_acc = sample_test(ba, comp_test[t].values.astype(int), n_times=1000)
      res.append(round((te-best_acc)*100, 2))
    effects.loc[company,:] = res
  return effects

# %%
def get_effects_neutral(df_train, df_test, loggs, companies=companies):
  effects_rand = pd.DataFrame(columns=['5 min', '10 min', '15 min', '30 min', '1 hour', '1 day'], index=companies)
  effects_zero = pd.DataFrame(columns=['5 min', '10 min', '15 min', '30 min', '1 hour', '1 day'], index=companies)

  targets = df_train.columns
  first_dates = pd.read_csv(f'/content/drive/MyDrive/Диссертация/Парсеры сайтов/Стоимость акций/1 мин/first_dates.csv', index_col='company')
  for company in companies:
    first_day = pd.to_datetime(first_dates.loc[company,:].values[0])
    comp_train = df_train[df_train[company] == True].copy()
    comp_test = df_test[df_test[company] == True].copy()
    comp_train = comp_train[comp_train.date >= first_day].copy()

    tr = [col for col in targets if company in col]
    if company in tr:
      tr.remove(company)

    accs_test = loggs[[col for col in loggs.columns if company in col]].loc['acc_test', :]
    f1_test = loggs[[col for col in loggs.columns if company in col]].loc['f1_test', :]

    res_acc = []
    res_f1 = []

    for t in tr:
      neg_p = (comp_train[t] == -1).sum() / len(comp_train[t])
      neu_p = (comp_train[t] == 0).sum() / len(comp_train[t])
      pos_p = (comp_train[t] == 1).sum() / len(comp_train[t])

      best_acc = sample_test_neutral([neg_p, neu_p, pos_p], comp_test[t].values, n_times=1000)
      res_acc.append(round((accs_test[t]-best_acc)*100, 2))
      res_f1.append (f1_test[t] - test_const(comp_test[t].values))

    effects_rand.loc[company,:] = res_acc
    effects_zero.loc[company,:] = res_f1

  return effects_rand, effects_zero

# %% [markdown]
# ### Кросс-валидация Телеграмм

# %%
companies = ['ALRS', 'AFLT', 'VTBR', 'GAZP', 'GMKN', 'LSRG', 'DSKY', 'IRAO', 'LKOH', 'MAGN', 'MOEX', 'CBOM', 'MTSS',
             'ROSN', 'NLMK', 'NVTK', 'PIKK', 'PLZL', 'RTKM', 'RUAL', 'HYDR', 'SBER', 'CHMF', 'AFKS', 'SNGS', 'TATN',
             'TCSG', 'TRNFP', 'PHOR', 'FEES', 'YNDX']

# %% [markdown]
# #### 2 класса

# %%
tg = pd.read_parquet('/content/drive/MyDrive/Диссертация/Парсеры сайтов/tg_comps.parquet')
tg_train = tg[tg.date < '2021-06-01'].copy()
tg_test = tg[(tg.date < '2022-01-01') & (tg.date > '2021-06-01')].copy()

# %%
loggs = pd.read_csv('/content/drive/MyDrive/Диссертация/tg_loggs/loggs_tg_rf_bin.csv', index_col=0)

# %%
effects_tg_rf_cv = get_effects_bin(tg_train, tg_test, loggs)

# %%
effects_tg_rf_cv.sort_index().style.applymap(_color_red_or_green).format(precision=2)
# Out:
# <style type="text/css">
# #T_d3536_row0_col0, #T_d3536_row0_col3, #T_d3536_row4_col0, #T_d3536_row4_col1, #T_d3536_row4_col2, #T_d3536_row4_col3, #T_d3536_row4_col4, #T_d3536_row4_col5, #T_d3536_row5_col0, #T_d3536_row5_col1, #T_d3536_row5_col2, #T_d3536_row5_col3, #T_d3536_row5_col4, #T_d3536_row5_col5, #T_d3536_row7_col1, #T_d3536_row7_col5, #T_d3536_row8_col6, #T_d3536_row9_col1, #T_d3536_row9_col2, #T_d3536_row9_col6, #T_d3536_row10_col0, #T_d3536_row10_col1, #T_d3536_row11_col5, #T_d3536_row11_col6, #T_d3536_row12_col2, #T_d3536_row12_col3, #T_d3536_row12_col5, #T_d3536_row13_col0, #T_d3536_row13_col1, #T_d3536_row13_col2, #T_d3536_row13_col3, #T_d3536_row13_col4, #T_d3536_row13_col5, #T_d3536_row13_col6, #T_d3536_row14_col0, #T_d3536_row14_col1, #T_d3536_row14_col2, #T_d3536_row14_col5, #T_d3536_row15_col1, #T_d3536_row15_col2, #T_d3536_row15_col3, #T_d3536_row15_col4, #T_d3536_row15_col5, #T_d3536_row16_col4, #T_d3536_row16_col5, #T_d3536_row16_col6, #T_d3536_row17_col0, #T_d3536_row17_col1, #T_d3536_row17_col4, #T_d3536_row17_col5, #T_d3536_row17_col6, #T_d3536_row19_col2, #T_d3536_row19_col4, #T_d3536_row21_col0, #T_d3536_row21_col2, #T_d3536_row21_col3, #T_d3536_row21_col5, #T_d3536_row22_col2, #T_d3536_row22_col4, #T_d3536_row22_col6, #T_d3536_row25_col0, #T_d3536_row25_col1, #T_d3536_row25_col2, #T_d3536_row25_col4, #T_d3536_row25_col5, #T_d3536_row25_col6, #T_d3536_row26_col5, #T_d3536_row26_col6, #T_d3536_row27_col0, #T_d3536_row27_col1, #T_d3536_row27_col2, #T_d3536_row29_col0, #T_d3536_row29_col1, #T_d3536_row29_col2, #T_d3536_row29_col3, #T_d3536_row30_col0, #T_d3536_row30_col1 {
#   color: green;
# }
# #T_d3536_row0_col1, #T_d3536_row0_col2, #T_d3536_row0_col4, #T_d3536_row0_col5, #T_d3536_row0_col6, #T_d3536_row1_col0, #T_d3536_row1_col1, #T_d3536_row1_col2, #T_d3536_row1_col3, #T_d3536_row1_col4, #T_d3536_row1_col5, #T_d3536_row1_col6, #T_d3536_row2_col0, #T_d3536_row2_col1, #T_d3536_row2_col2, #T_d3536_row2_col3, #T_d3536_row2_col4, #T_d3536_row2_col5, #T_d3536_row2_col6, #T_d3536_row3_col0, #T_d3536_row3_col1, #T_d3536_row3_col2, #T_d3536_row3_col3, #T_d3536_row3_col4, #T_d3536_row3_col5, #T_d3536_row3_col6, #T_d3536_row4_col6, #T_d3536_row5_col6, #T_d3536_row6_col0, #T_d3536_row6_col1, #T_d3536_row6_col2, #T_d3536_row6_col3, #T_d3536_row6_col4, #T_d3536_row6_col5, #T_d3536_row6_col6, #T_d3536_row7_col0, #T_d3536_row7_col2, #T_d3536_row7_col3, #T_d3536_row7_col4, #T_d3536_row7_col6, #T_d3536_row8_col0, #T_d3536_row8_col1, #T_d3536_row8_col2, #T_d3536_row8_col3, #T_d3536_row8_col4, #T_d3536_row8_col5, #T_d3536_row9_col0, #T_d3536_row9_col3, #T_d3536_row9_col4, #T_d3536_row9_col5, #T_d3536_row10_col2, #T_d3536_row10_col3, #T_d3536_row10_col4, #T_d3536_row10_col5, #T_d3536_row10_col6, #T_d3536_row11_col0, #T_d3536_row11_col1, #T_d3536_row11_col2, #T_d3536_row11_col3, #T_d3536_row11_col4, #T_d3536_row12_col0, #T_d3536_row12_col1, #T_d3536_row12_col4, #T_d3536_row12_col6, #T_d3536_row14_col3, #T_d3536_row14_col4, #T_d3536_row14_col6, #T_d3536_row15_col0, #T_d3536_row15_col6, #T_d3536_row16_col0, #T_d3536_row16_col1, #T_d3536_row16_col2, #T_d3536_row16_col3, #T_d3536_row17_col2, #T_d3536_row17_col3, #T_d3536_row18_col0, #T_d3536_row18_col1, #T_d3536_row18_col2, #T_d3536_row18_col3, #T_d3536_row18_col4, #T_d3536_row18_col5, #T_d3536_row18_col6, #T_d3536_row19_col0, #T_d3536_row19_col1, #T_d3536_row19_col3, #T_d3536_row19_col5, #T_d3536_row19_col6, #T_d3536_row20_col0, #T_d3536_row20_col1, #T_d3536_row20_col2, #T_d3536_row20_col3, #T_d3536_row20_col4, #T_d3536_row20_col5, #T_d3536_row20_col6, #T_d3536_row21_col1, #T_d3536_row21_col4, #T_d3536_row21_col6, #T_d3536_row22_col0, #T_d3536_row22_col1, #T_d3536_row22_col3, #T_d3536_row22_col5, #T_d3536_row23_col0, #T_d3536_row23_col1, #T_d3536_row23_col2, #T_d3536_row23_col3, #T_d3536_row23_col4, #T_d3536_row23_col5, #T_d3536_row23_col6, #T_d3536_row24_col0, #T_d3536_row24_col1, #T_d3536_row24_col2, #T_d3536_row24_col3, #T_d3536_row24_col4, #T_d3536_row24_col5, #T_d3536_row24_col6, #T_d3536_row25_col3, #T_d3536_row26_col0, #T_d3536_row26_col1, #T_d3536_row26_col2, #T_d3536_row26_col3, #T_d3536_row26_col4, #T_d3536_row27_col3, #T_d3536_row27_col4, #T_d3536_row27_col5, #T_d3536_row27_col6, #T_d3536_row28_col0, #T_d3536_row28_col1, #T_d3536_row28_col2, #T_d3536_row28_col3, #T_d3536_row28_col4, #T_d3536_row28_col5, #T_d3536_row28_col6, #T_d3536_row29_col4, #T_d3536_row29_col5, #T_d3536_row29_col6, #T_d3536_row30_col2, #T_d3536_row30_col3, #T_d3536_row30_col4, #T_d3536_row30_col5, #T_d3536_row30_col6 {
#   color: red;
# }
# </style>
# <table id="T_d3536" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d3536_level0_col0" class="col_heading level0 col0" >1 min</th>
#       <th id="T_d3536_level0_col1" class="col_heading level0 col1" >5 min</th>
#       <th id="T_d3536_level0_col2" class="col_heading level0 col2" >10 min</th>
#       <th id="T_d3536_level0_col3" class="col_heading level0 col3" >15 min</th>
#       <th id="T_d3536_level0_col4" class="col_heading level0 col4" >30 min</th>
#       <th id="T_d3536_level0_col5" class="col_heading level0 col5" >1 hour</th>
#       <th id="T_d3536_level0_col6" class="col_heading level0 col6" >1 day</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d3536_level0_row0" class="row_heading level0 row0" >AFKS</th>
#       <td id="T_d3536_row0_col0" class="data row0 col0" >0.28</td>
#       <td id="T_d3536_row0_col1" class="data row0 col1" >-1.20</td>
#       <td id="T_d3536_row0_col2" class="data row0 col2" >-0.22</td>
#       <td id="T_d3536_row0_col3" class="data row0 col3" >0.26</td>
#       <td id="T_d3536_row0_col4" class="data row0 col4" >-0.93</td>
#       <td id="T_d3536_row0_col5" class="data row0 col5" >-1.14</td>
#       <td id="T_d3536_row0_col6" class="data row0 col6" >-4.23</td>
#     </tr>
#     <tr>
#       <th id="T_d3536_level0_row1" class="row_heading level0 row1" >AFLT</th>
#       <td id="T_d3536_row1_col0" class="data row1 col0" >-1.05</td>
#       <td id="T_d3536_row1_col1" class="data row1 col1" >-1.04</td>
#       <td id="T_d3536_row1_col2" class="data row1 col2" >-4.61</td>
#       <td id="T_d3536_row1_col3" class="data row1 col3" >-3.59</td>
#       <td id="T_d3536_row1_col4" class="data row1 col4" >-1.66</td>
#       <td id="T_d3536_row1_col5" class="data row1 col5" >-1.29</td>
#       <td id="T_d3536_row1_col6" class="data row1 col6" >-2.17</td>
#     </tr>
#     <tr>
#       <th id="T_d3536_level0_row2" class="row_heading level0 row2" >ALRS</th>
#       <td id="T_d3536_row2_col0" class="data row2 col0" >-3.19</td>
#       <td id="T_d3536_row2_col1" class="data row2 col1" >-5.67</td>
#       <td id="T_d3536_row2_col2" class="data row2 col2" >-1.40</td>
#       <td id="T_d3536_row2_col3" class="data row2 col3" >-2.44</td>
#       <td id="T_d3536_row2_col4" class="data row2 col4" >-3.81</td>
#       <td id="T_d3536_row2_col5" class="data row2 col5" >-0.74</td>
#       <td id="T_d3536_row2_col6" class="data row2 col6" >-5.02</td>
#     </tr>
#     <tr>
#       <th id="T_d3536_level0_row3" class="row_heading level0 row3" >CBOM</th>
#       <td id="T_d3536_row3_col0" class="data row3 col0" >-3.40</td>
#       <td id="T_d3536_row3_col1" class="data row3 col1" >-6.13</td>
#       <td id="T_d3536_row3_col2" class="data row3 col2" >-2.80</td>
#       <td id="T_d3536_row3_col3" class="data row3 col3" >-5.48</td>
#       <td id="T_d3536_row3_col4" class="data row3 col4" >-4.78</td>
#       <td id="T_d3536_row3_col5" class="data row3 col5" >-0.50</td>
#       <td id="T_d3536_row3_col6" class="data row3 col6" >-0.41</td>
#     </tr>
#     <tr>
#       <th id="T_d3536_level0_row4" class="row_heading level0 row4" >CHMF</th>
#       <td id="T_d3536_row4_col0" class="data row4 col0" >8.47</td>
#       <td id="T_d3536_row4_col1" class="data row4 col1" >3.90</td>
#       <td id="T_d3536_row4_col2" class="data row4 col2" >3.22</td>
#       <td id="T_d3536_row4_col3" class="data row4 col3" >0.87</td>
#       <td id="T_d3536_row4_col4" class="data row4 col4" >2.10</td>
#       <td id="T_d3536_row4_col5" class="da

# %%
effects_tg_rf_cv.mean()
# Out:
# 1 min    -0.620000
# 5 min    -0.976452
# 10 min   -0.352581
# 15 min   -1.544516
# 30 min   -0.751290
# 1 hour   -0.452258
# 1 day    -1.445484
# dtype: float64

# %%
effects_tg_rf_cv.filter(['MAGN', 'CHMF', 'DSKY', 'SNGS', 'NVTK'], axis=0).sort_index().style.applymap(_color_red_or_green).format(precision=2)
# Out:
# <style type="text/css">
# #T_9661f_row0_col0, #T_9661f_row0_col1, #T_9661f_row0_col2, #T_9661f_row0_col3, #T_9661f_row0_col4, #T_9661f_row0_col5, #T_9661f_row1_col0, #T_9661f_row1_col1, #T_9661f_row1_col2, #T_9661f_row1_col3, #T_9661f_row1_col4, #T_9661f_row1_col5, #T_9661f_row2_col0, #T_9661f_row2_col1, #T_9661f_row2_col2, #T_9661f_row2_col3, #T_9661f_row2_col4, #T_9661f_row2_col5, #T_9661f_row2_col6, #T_9661f_row3_col0, #T_9661f_row3_col1, #T_9661f_row3_col4, #T_9661f_row3_col5, #T_9661f_row3_col6, #T_9661f_row4_col0, #T_9661f_row4_col1, #T_9661f_row4_col2, #T_9661f_row4_col4, #T_9661f_row4_col5, #T_9661f_row4_col6 {
#   color: green;
# }
# #T_9661f_row0_col6, #T_9661f_row1_col6, #T_9661f_row3_col2, #T_9661f_row3_col3, #T_9661f_row4_col3 {
#   color: red;
# }
# </style>
# <table id="T_9661f" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9661f_level0_col0" class="col_heading level0 col0" >1 min</th>
#       <th id="T_9661f_level0_col1" class="col_heading level0 col1" >5 min</th>
#       <th id="T_9661f_level0_col2" class="col_heading level0 col2" >10 min</th>
#       <th id="T_9661f_level0_col3" class="col_heading level0 col3" >15 min</th>
#       <th id="T_9661f_level0_col4" class="col_heading level0 col4" >30 min</th>
#       <th id="T_9661f_level0_col5" class="col_heading level0 col5" >1 hour</th>
#       <th id="T_9661f_level0_col6" class="col_heading level0 col6" >1 day</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9661f_level0_row0" class="row_heading level0 row0" >CHMF</th>
#       <td id="T_9661f_row0_col0" class="data row0 col0" >8.47</td>
#       <td id="T_9661f_row0_col1" class="data row0 col1" >3.90</td>
#       <td id="T_9661f_row0_col2" class="data row0 col2" >3.22</td>
#       <td id="T_9661f_row0_col3" class="data row0 col3" >0.87</td>
#       <td id="T_9661f_row0_col4" class="data row0 col4" >2.10</td>
#       <td id="T_9661f_row0_col5" class="data row0 col5" >2.14</td>
#       <td id="T_9661f_row0_col6" class="data row0 col6" >-0.20</td>
#     </tr>
#     <tr>
#       <th id="T_9661f_level0_row1" class="row_heading level0 row1" >DSKY</th>
#       <td id="T_9661f_row1_col0" class="data row1 col0" >5.58</td>
#       <td id="T_9661f_row1_col1" class="data row1 col1" >3.69</td>
#       <td id="T_9661f_row1_col2" class="data row1 col2" >4.34</td>
#       <td id="T_9661f_row1_col3" class="data row1 col3" >7.18</td>
#       <td id="T_9661f_row1_col4" class="data row1 col4" >7.19</td>
#       <td id="T_9661f_row1_col5" class="data row1 col5" >5.41</td>
#       <td id="T_9661f_row1_col6" class="data row1 col6" >-4.74</td>
#     </tr>
#     <tr>
#       <th id="T_9661f_level0_row2" class="row_heading level0 row2" >MAGN</th>
#       <td id="T_9661f_row2_col0" class="data row2 col0" >5.12</td>
#       <td id="T_9661f_row2_col1" class="data row2 col1" >2.65</td>
#       <td id="T_9661f_row2_col2" class="data row2 col2" >0.46</td>
#       <td id="T_9661f_row2_col3" class="data row2 col3" >2.02</td>
#       <td id="T_9661f_row2_col4" class="data row2 col4" >7.04</td>
#       <td id="T_9661f_row2_col5" class="data row2 col5" >3.03</td>
#       <td id="T_9661f_row2_col6" class="data row2 col6" >2.14</td>
#     </tr>
#     <tr>
#       <th id="T_9661f_level0_row3" class="row_heading level0 row3" >NVTK</th>
#       <td id="T_9661f_row3_col0" class="data row3 col0" >2.89</td>
#       <td id="T_9661f_row3_col1" class="data row3 col1" >0.34</td>
#       <td id="T_9661f_row3_col2" class="data row3 col2" >-0.04</td>
#       <td id="T_9661f_row3_col3" class="data row3 col3" >-2.18</td>
#       <td id="T_9661f_row3_col4" class="data row3 col4" >1.10</td>
#       <td id="T_9661f_row3_col5" class="data row3 col5" >0.25</td>
#       <td id="T_9661f_row3_col6" class="data row3 col6" >1.41</td>
#     </tr>
#     <tr>
#       <th id="T_9661f_level0_row4" class="row_heading level0 row4" >SNGS</th>
#       <td id="T_9661f_row4_col0" class="data row4 col0" >3.77</td>
#       <td id="T_9661f_row4_col1" class="data row4 col1" >3.33</td>
#       <td id="T_9661f_row4_col2" class="data row4 col2" >3.73</td>
#       <td id="T_9661f_row4_col3" class="data row4 col3" >-0.07</td>
#       <td id="T_9661f_row4_col4" class="data row4 col4" >0.58</td>
#       <td id="T_9661f_row4_col5" class="data row4 col5" >0.61</td>
#       <td id="T_9661f_row4_col6" class="data row4 col6" >3.57</td>
#     </tr>
#   </tbody>
# </table>

# %%
loggs = pd.read_csv('/content/drive/MyDrive/Диссертация/tg_loggs/loggs_tg_boosting_bin.csv', index_col=0)

# %%
effects_tg_boosting_cv = get_effects_bin(tg_train, tg_test, loggs)

# %%
effects_tg_boosting_cv.sort_index().style.applymap(_color_red_or_green).format(precision=2)
# Out:
# <style type="text/css">
# #T_d5dde_row0_col0, #T_d5dde_row0_col4, #T_d5dde_row1_col5, #T_d5dde_row2_col2, #T_d5dde_row2_col5, #T_d5dde_row3_col6, #T_d5dde_row4_col0, #T_d5dde_row4_col1, #T_d5dde_row4_col2, #T_d5dde_row4_col3, #T_d5dde_row4_col5, #T_d5dde_row4_col6, #T_d5dde_row5_col0, #T_d5dde_row5_col1, #T_d5dde_row5_col2, #T_d5dde_row5_col3, #T_d5dde_row5_col4, #T_d5dde_row5_col5, #T_d5dde_row6_col4, #T_d5dde_row7_col1, #T_d5dde_row7_col2, #T_d5dde_row7_col4, #T_d5dde_row7_col5, #T_d5dde_row9_col1, #T_d5dde_row9_col6, #T_d5dde_row11_col0, #T_d5dde_row11_col6, #T_d5dde_row12_col1, #T_d5dde_row13_col0, #T_d5dde_row13_col1, #T_d5dde_row13_col4, #T_d5dde_row14_col3, #T_d5dde_row14_col5, #T_d5dde_row15_col0, #T_d5dde_row15_col5, #T_d5dde_row16_col0, #T_d5dde_row16_col4, #T_d5dde_row16_col6, #T_d5dde_row17_col0, #T_d5dde_row17_col4, #T_d5dde_row17_col5, #T_d5dde_row18_col5, #T_d5dde_row19_col4, #T_d5dde_row20_col4, #T_d5dde_row20_col5, #T_d5dde_row21_col2, #T_d5dde_row21_col3, #T_d5dde_row21_col4, #T_d5dde_row22_col4, #T_d5dde_row22_col6, #T_d5dde_row23_col0, #T_d5dde_row23_col6, #T_d5dde_row24_col0, #T_d5dde_row24_col1, #T_d5dde_row24_col5, #T_d5dde_row25_col0, #T_d5dde_row25_col2, #T_d5dde_row25_col3, #T_d5dde_row25_col4, #T_d5dde_row25_col5, #T_d5dde_row25_col6, #T_d5dde_row27_col0, #T_d5dde_row29_col3, #T_d5dde_row29_col4, #T_d5dde_row30_col0, #T_d5dde_row30_col6 {
#   color: green;
# }
# #T_d5dde_row0_col1, #T_d5dde_row0_col2, #T_d5dde_row0_col3, #T_d5dde_row0_col5, #T_d5dde_row0_col6, #T_d5dde_row1_col0, #T_d5dde_row1_col1, #T_d5dde_row1_col2, #T_d5dde_row1_col3, #T_d5dde_row1_col4, #T_d5dde_row1_col6, #T_d5dde_row2_col0, #T_d5dde_row2_col1, #T_d5dde_row2_col3, #T_d5dde_row2_col4, #T_d5dde_row2_col6, #T_d5dde_row3_col0, #T_d5dde_row3_col1, #T_d5dde_row3_col2, #T_d5dde_row3_col3, #T_d5dde_row3_col4, #T_d5dde_row3_col5, #T_d5dde_row4_col4, #T_d5dde_row5_col6, #T_d5dde_row6_col0, #T_d5dde_row6_col1, #T_d5dde_row6_col2, #T_d5dde_row6_col3, #T_d5dde_row6_col5, #T_d5dde_row6_col6, #T_d5dde_row7_col0, #T_d5dde_row7_col3, #T_d5dde_row7_col6, #T_d5dde_row8_col0, #T_d5dde_row8_col1, #T_d5dde_row8_col2, #T_d5dde_row8_col3, #T_d5dde_row8_col4, #T_d5dde_row8_col5, #T_d5dde_row8_col6, #T_d5dde_row9_col0, #T_d5dde_row9_col2, #T_d5dde_row9_col3, #T_d5dde_row9_col4, #T_d5dde_row9_col5, #T_d5dde_row10_col0, #T_d5dde_row10_col1, #T_d5dde_row10_col2, #T_d5dde_row10_col3, #T_d5dde_row10_col4, #T_d5dde_row10_col5, #T_d5dde_row10_col6, #T_d5dde_row11_col1, #T_d5dde_row11_col2, #T_d5dde_row11_col3, #T_d5dde_row11_col4, #T_d5dde_row11_col5, #T_d5dde_row12_col0, #T_d5dde_row12_col2, #T_d5dde_row12_col3, #T_d5dde_row12_col4, #T_d5dde_row12_col5, #T_d5dde_row12_col6, #T_d5dde_row13_col2, #T_d5dde_row13_col3, #T_d5dde_row13_col5, #T_d5dde_row13_col6, #T_d5dde_row14_col0, #T_d5dde_row14_col1, #T_d5dde_row14_col2, #T_d5dde_row14_col4, #T_d5dde_row14_col6, #T_d5dde_row15_col1, #T_d5dde_row15_col2, #T_d5dde_row15_col3, #T_d5dde_row15_col4, #T_d5dde_row15_col6, #T_d5dde_row16_col1, #T_d5dde_row16_col2, #T_d5dde_row16_col3, #T_d5dde_row16_col5, #T_d5dde_row17_col1, #T_d5dde_row17_col2, #T_d5dde_row17_col3, #T_d5dde_row17_col6, #T_d5dde_row18_col0, #T_d5dde_row18_col1, #T_d5dde_row18_col2, #T_d5dde_row18_col3, #T_d5dde_row18_col4, #T_d5dde_row18_col6, #T_d5dde_row19_col0, #T_d5dde_row19_col1, #T_d5dde_row19_col2, #T_d5dde_row19_col3, #T_d5dde_row19_col5, #T_d5dde_row19_col6, #T_d5dde_row20_col0, #T_d5dde_row20_col1, #T_d5dde_row20_col2, #T_d5dde_row20_col3, #T_d5dde_row20_col6, #T_d5dde_row21_col0, #T_d5dde_row21_col1, #T_d5dde_row21_col5, #T_d5dde_row21_col6, #T_d5dde_row22_col0, #T_d5dde_row22_col1, #T_d5dde_row22_col2, #T_d5dde_row22_col3, #T_d5dde_row22_col5, #T_d5dde_row23_col1, #T_d5dde_row23_col2, #T_d5dde_row23_col3, #T_d5dde_row23_col4, #T_d5dde_row23_col5, #T_d5dde_row24_col2, #T_d5dde_row24_col3, #T_d5dde_row24_col4, #T_d5dde_row24_col6, #T_d5dde_row25_col1, #T_d5dde_row26_col0, #T_d5dde_row26_col1, #T_d5dde_row26_col2, #T_d5dde_row26_col3, #T_d5dde_row26_col4, #T_d5dde_row26_col5, #T_d5dde_row26_col6, #T_d5dde_row27_col1, #T_d5dde_row27_col2, #T_d5dde_row27_col3, #T_d5dde_row27_col4, #T_d5dde_row27_col5, #T_d5dde_row27_col6, #T_d5dde_row28_col0, #T_d5dde_row28_col1, #T_d5dde_row28_col2, #T_d5dde_row28_col3, #T_d5dde_row28_col4, #T_d5dde_row28_col5, #T_d5dde_row28_col6, #T_d5dde_row29_col0, #T_d5dde_row29_col1, #T_d5dde_row29_col2, #T_d5dde_row29_col5, #T_d5dde_row29_col6, #T_d5dde_row30_col1, #T_d5dde_row30_col2, #T_d5dde_row30_col3, #T_d5dde_row30_col4, #T_d5dde_row30_col5 {
#   color: red;
# }
# </style>
# <table id="T_d5dde" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d5dde_level0_col0" class="col_heading level0 col0" >1 min</th>
#       <th id="T_d5dde_level0_col1" class="col_heading level0 col1" >5 min</th>
#       <th id="T_d5dde_level0_col2" class="col_heading level0 col2" >10 min</th>
#       <th id="T_d5dde_level0_col3" class="col_heading level0 col3" >15 min</th>
#       <th id="T_d5dde_level0_col4" class="col_heading level0 col4" >30 min</th>
#       <th id="T_d5dde_level0_col5" class="col_heading level0 col5" >1 hour</th>
#       <th id="T_d5dde_level0_col6" class="col_heading level0 col6" >1 day</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d5dde_level0_row0" class="row_heading level0 row0" >AFKS</th>
#       <td id="T_d5dde_row0_col0" class="data row0 col0" >0.16</td>
#       <td id="T_d5dde_row0_col1" class="data row0 col1" >-1.80</td>
#       <td id="T_d5dde_row0_col2" class="data row0 col2" >-0.95</td>
#       <td id="T_d5dde_row0_col3" class="data row0 col3" >-1.77</td>
#       <td id="T_d5dde_row0_col4" class="data row0 col4" >1.04</td>
#       <td id="T_d5dde_row0_col5" class="data row0 col5" >-0.66</td>
#       <td id="T_d5dde_row0_col6" class="data row0 col6" >-4.25</td>
#     </tr>
#     <tr>
#       <th id="T_d5dde_level0_row1" class="row_heading level0 row1" >AFLT</th>
#       <td id="T_d5dde_row1_col0" class="data row1 col0" >-0.09</td>
#       <td id="T_d5dde_row1_col1" class="data row1 col1" >-4.34</td>
#       <td id="T_d5dde_row1_col2" class="data row1 col2" >-5.56</td>
#       <td id="T_d5dde_row1_col3" class="data row1 col3" >-3.81</td>
#       <td id="T_d5dde_row1_col4" class="data row1 col4" >-2.30</td>
#       <td id="T_d5dde_row1_col5" class="data row1 col5" >1.36</td>
#       <td id="T_d5dde_row1_col6" class="data row1 col6" >-1.63</td>
#     </tr>
#     <tr>
#       <th id="T_d5dde_level0_row2" class="row_heading level0 row2" >ALRS</th>
#       <td id="T_d5dde_row2_col0" class="data row2 col0" >-0.29</td>
#       <td id="T_d5dde_row2_col1" class="data row2 col1" >-5.79</td>
#       <td id="T_d5dde_row2_col2" class="data row2 col2" >0.76</td>
#       <td id="T_d5dde_row2_col3" class="data row2 col3" >-2.95</td>
#       <td id="T_d5dde_row2_col4" class="data row2 col4" >-2.24</td>
#       <td id="T_d5dde_row2_col5" class="data row2 col5" >0.71</td>
#       <td id="T_d5dde_row2_col6" class="data row2 col6" >-2.66</td>
#     </tr>
#     <tr>
#       <th id="T_d5dde_level0_row3" class="row_heading level0 row3" >CBOM</th>
#       <td id="T_d5dde_row3_col0" class="data row3 col0" >-3.05</td>
#       <td id="T_d5dde_row3_col1" class="data row3 col1" >-8.17</td>
#       <td id="T_d5dde_row3_col2" class="data row3 col2" >-6.25</td>
#       <td id="T_d5dde_row3_col3" class="data row3 col3" >-1.76</td>
#       <td id="T_d5dde_row3_col4" class="data row3 col4" >-2.55</td>
#       <td id="T_d5dde_row3_col5" class="data row3 col5" >-6.36</td>
#       <td id="T_d5dde_row3_col6" class="data row3 col6" >2.36</td>
#     </tr>
#     <tr>
#       <th id="T_d5dde_level0_row4" class="row_heading level0 row4" >CHMF</th>
#       <td id="T_d5dde_row4_col0" class="data row4 col0" >1.53</td>
#       <td id="T_d5dde_row4_col1" class="data row4 col1" >1.82</td>
#       <td id="T_d5dde_row4_col2" class="data row4 col2" >0.98</td>
#       <td id="T_d5dde_row4_col3" class="data row4 col3" >2.49</td>
#       <td id="T_d5dde_row4_col4" class="data row4 col4" >-0.41</td>
#       <td id="T_d5dde_row4_col5" class="data

# %%
effects_tg_boosting_cv.mean()
# Out:
# 1 min    -0.690645
# 5 min    -1.972258
# 10 min   -1.899355
# 15 min   -1.848065
# 30 min   -0.462581
# 1 hour   -0.832258
# 1 day    -1.188065
# dtype: float64

# %% [markdown]
# #### 3 класса

# %%
tg = pd.read_parquet('/content/drive/MyDrive/Диссертация/Парсеры сайтов/tg_comps_1,5sigma_.parquet')
tg_train = tg[tg.date < '2021-06-01'].copy()
tg_test = tg[(tg.date < '2022-01-01') & (tg.date > '2021-06-01')].copy()

# %%
loggs = pd.read_csv('/content/drive/MyDrive/Диссертация/tg_loggs/loggs_tg_rf_neutral.csv', index_col=0)

# %%
effects_neutral_tg_rand_rf, effects_neutral_tg_zero_rf = get_effects_neutral(tg_train, tg_test, loggs)

# %%
effects_neutral_tg_rand_rf.sort_index().style.applymap(_color_red_or_green).format(precision=2)
# Out:
# <style type="text/css">
# #T_86b23_row0_col0, #T_86b23_row0_col1, #T_86b23_row0_col2, #T_86b23_row0_col3, #T_86b23_row0_col4, #T_86b23_row1_col1, #T_86b23_row1_col2, #T_86b23_row1_col3, #T_86b23_row1_col4, #T_86b23_row1_col5, #T_86b23_row2_col0, #T_86b23_row2_col1, #T_86b23_row2_col2, #T_86b23_row2_col4, #T_86b23_row2_col5, #T_86b23_row3_col3, #T_86b23_row3_col4, #T_86b23_row4_col1, #T_86b23_row4_col2, #T_86b23_row4_col3, #T_86b23_row4_col4, #T_86b23_row4_col5, #T_86b23_row5_col0, #T_86b23_row5_col1, #T_86b23_row5_col2, #T_86b23_row5_col3, #T_86b23_row5_col4, #T_86b23_row6_col3, #T_86b23_row6_col4, #T_86b23_row6_col5, #T_86b23_row7_col0, #T_86b23_row7_col1, #T_86b23_row7_col2, #T_86b23_row7_col3, #T_86b23_row7_col4, #T_86b23_row8_col1, #T_86b23_row8_col2, #T_86b23_row8_col3, #T_86b23_row8_col4, #T_86b23_row9_col0, #T_86b23_row9_col1, #T_86b23_row9_col2, #T_86b23_row9_col4, #T_86b23_row9_col5, #T_86b23_row11_col3, #T_86b23_row11_col4, #T_86b23_row11_col5, #T_86b23_row12_col0, #T_86b23_row12_col1, #T_86b23_row12_col2, #T_86b23_row12_col3, #T_86b23_row12_col4, #T_86b23_row13_col1, #T_86b23_row13_col2, #T_86b23_row13_col3, #T_86b23_row13_col4, #T_86b23_row14_col0, #T_86b23_row14_col1, #T_86b23_row14_col2, #T_86b23_row14_col3, #T_86b23_row14_col4, #T_86b23_row14_col5, #T_86b23_row15_col0, #T_86b23_row15_col1, #T_86b23_row15_col2, #T_86b23_row15_col3, #T_86b23_row15_col4, #T_86b23_row16_col1, #T_86b23_row16_col2, #T_86b23_row16_col3, #T_86b23_row17_col0, #T_86b23_row17_col2, #T_86b23_row17_col3, #T_86b23_row17_col4, #T_86b23_row17_col5, #T_86b23_row18_col0, #T_86b23_row18_col1, #T_86b23_row18_col2, #T_86b23_row18_col3, #T_86b23_row18_col4, #T_86b23_row18_col5, #T_86b23_row19_col1, #T_86b23_row19_col2, #T_86b23_row19_col3, #T_86b23_row19_col4, #T_86b23_row19_col5, #T_86b23_row20_col0, #T_86b23_row20_col1, #T_86b23_row20_col2, #T_86b23_row20_col3, #T_86b23_row21_col0, #T_86b23_row21_col1, #T_86b23_row21_col2, #T_86b23_row21_col3, #T_86b23_row21_col4, #T_86b23_row21_col5, #T_86b23_row22_col0, #T_86b23_row22_col1, #T_86b23_row22_col3, #T_86b23_row22_col4, #T_86b23_row23_col1, #T_86b23_row23_col2, #T_86b23_row24_col1, #T_86b23_row24_col2, #T_86b23_row24_col3, #T_86b23_row24_col4, #T_86b23_row25_col0, #T_86b23_row25_col1, #T_86b23_row25_col2, #T_86b23_row25_col3, #T_86b23_row25_col4, #T_86b23_row25_col5, #T_86b23_row26_col2, #T_86b23_row26_col3, #T_86b23_row26_col4, #T_86b23_row26_col5, #T_86b23_row28_col0, #T_86b23_row28_col4, #T_86b23_row29_col1, #T_86b23_row29_col2, #T_86b23_row29_col3, #T_86b23_row29_col4, #T_86b23_row30_col0, #T_86b23_row30_col1, #T_86b23_row30_col2, #T_86b23_row30_col5 {
#   color: green;
# }
# #T_86b23_row0_col5, #T_86b23_row1_col0, #T_86b23_row2_col3, #T_86b23_row3_col0, #T_86b23_row3_col1, #T_86b23_row3_col2, #T_86b23_row3_col5, #T_86b23_row4_col0, #T_86b23_row5_col5, #T_86b23_row6_col0, #T_86b23_row6_col1, #T_86b23_row6_col2, #T_86b23_row7_col5, #T_86b23_row8_col0, #T_86b23_row8_col5, #T_86b23_row9_col3, #T_86b23_row10_col0, #T_86b23_row10_col1, #T_86b23_row10_col2, #T_86b23_row10_col3, #T_86b23_row10_col4, #T_86b23_row10_col5, #T_86b23_row11_col0, #T_86b23_row11_col1, #T_86b23_row11_col2, #T_86b23_row12_col5, #T_86b23_row13_col0, #T_86b23_row13_col5, #T_86b23_row15_col5, #T_86b23_row16_col0, #T_86b23_row16_col4, #T_86b23_row16_col5, #T_86b23_row17_col1, #T_86b23_row19_col0, #T_86b23_row20_col4, #T_86b23_row20_col5, #T_86b23_row22_col2, #T_86b23_row22_col5, #T_86b23_row23_col0, #T_86b23_row23_col3, #T_86b23_row23_col4, #T_86b23_row23_col5, #T_86b23_row24_col0, #T_86b23_row24_col5, #T_86b23_row26_col0, #T_86b23_row26_col1, #T_86b23_row27_col0, #T_86b23_row27_col1, #T_86b23_row27_col2, #T_86b23_row27_col3, #T_86b23_row27_col4, #T_86b23_row27_col5, #T_86b23_row28_col1, #T_86b23_row28_col2, #T_86b23_row28_col3, #T_86b23_row28_col5, #T_86b23_row29_col0, #T_86b23_row29_col5, #T_86b23_row30_col3, #T_86b23_row30_col4 {
#   color: red;
# }
# </style>
# <table id="T_86b23" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_86b23_level0_col0" class="col_heading level0 col0" >5 min</th>
#       <th id="T_86b23_level0_col1" class="col_heading level0 col1" >10 min</th>
#       <th id="T_86b23_level0_col2" class="col_heading level0 col2" >15 min</th>
#       <th id="T_86b23_level0_col3" class="col_heading level0 col3" >30 min</th>
#       <th id="T_86b23_level0_col4" class="col_heading level0 col4" >1 hour</th>
#       <th id="T_86b23_level0_col5" class="col_heading level0 col5" >1 day</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_86b23_level0_row0" class="row_heading level0 row0" >AFKS</th>
#       <td id="T_86b23_row0_col0" class="data row0 col0" >1.47</td>
#       <td id="T_86b23_row0_col1" class="data row0 col1" >4.63</td>
#       <td id="T_86b23_row0_col2" class="data row0 col2" >1.27</td>
#       <td id="T_86b23_row0_col3" class="data row0 col3" >0.89</td>
#       <td id="T_86b23_row0_col4" class="data row0 col4" >0.11</td>
#       <td id="T_86b23_row0_col5" class="data row0 col5" >-0.13</td>
#     </tr>
#     <tr>
#       <th id="T_86b23_level0_row1" class="row_heading level0 row1" >AFLT</th>
#       <td id="T_86b23_row1_col0" class="data row1 col0" >-0.77</td>
#       <td id="T_86b23_row1_col1" class="data row1 col1" >1.91</td>
#       <td id="T_86b23_row1_col2" class="data row1 col2" >2.53</td>
#       <td id="T_86b23_row1_col3" class="data row1 col3" >1.44</td>
#       <td id="T_86b23_row1_col4" class="data row1 col4" >1.56</td>
#       <td id="T_86b23_row1_col5" class="data row1 col5" >2.88</td>
#     </tr>
#     <tr>
#       <th id="T_86b23_level0_row2" class="row_heading level0 row2" >ALRS</th>
#       <td id="T_86b23_row2_col0" class="data row2 col0" >0.50</td>
#       <td id="T_86b23_row2_col1" class="data row2 col1" >3.32</td>
#       <td id="T_86b23_row2_col2" class="data row2 col2" >1.84</td>
#       <td id="T_86b23_row2_col3" class="data row2 col3" >-0.35</td>
#       <td id="T_86b23_row2_col4" class="data row2 col4" >2.93</td>
#       <td id="T_86b23_row2_col5" class="data row2 col5" >2.82</td>
#     </tr>
#     <tr>
#       <th id="T_86b23_level0_row3" class="row_heading level0 row3" >CBOM</th>
#       <td id="T_86b23_row3_col0" class="data row3 col0" >-2.40</td>
#       <td id="T_86b23_row3_col1" class="data row3 col1" >-3.70</td>
#       <td id="T_86b23_row3_col2" class="data row3 col2" >-5.56</td>
#       <td id="T_86b23_row3_col3" class="data row3 col3" >4.57</td>
#       <td id="T_86b23_row3_col4" class="data row3 col4" >1.13</td>
#       <td id="T_86b23_row3_col5" class="data row3 col5" >-0.74</td>
#     </tr>
#     <tr>
#       <th id="T_86b23_level0_row4" class="row_heading level0 row4" >CHMF</th>
#       <td id="T_86b23_row4_col0" class="data row4 col0" >-0.52</td>
#       <td id="T_86b23_row4_col1" class="data row4 col1" >7.04</td>
#       <td id="T_86b23_row4_col2" class="data row4 col2" >7.72</td>
#       <td id="T_86b23_row4_col3" class="data row4 col3" >5.15</td>
#       <td id="T_86b23_row4_col4" class="data row4 col4" >7.47</td>
#       <td id="T_86b23_row4_col5" class="data row4 col5" >0.05</td>
#     </tr>
#     <tr>
#       <th id="T_86b23_level0_row5" class="row_heading level0 row5" >DSKY</th>
#       <td id="T_86b23_row5_col0" class="data row5 col0" >6.32</td>
#       <td id="T_86b23_row5_col1" class="data row5 col1" >4.01</td>
#       <td id="T_86b23_row5_col2" class="data row5 col2" >9.69</td>
#       <td id="T_86b23_row5_col3" class="data row5 col3" >14.72</td>
#       <td id="T_86b23_row5_col4" class="data row5 col4" >9.26</td>
#       <td id="T_86b23_row5_col5" class="data row5 col5" >-0.20</td>
#     </tr>
#     <tr>
#       <th id="T_86b23_level0_row6" class="row_heading level0 row6" >FEES</th>
#       <td id="T_86b23_row6_col0" class="data row6 col0" >-1.84</td>
#       <td id="T_86b23_row6_col1" class="data row6 col1" >-2.32</td>
#       <td id="T_86b23_row6_col2" class="data row6 col2" >-3.71</td>
#       <td id="T_86b23_row6_col3" class="data row6 col3" >1.09</td>
#       <td id="T_86b23_row6_col4" class="data row6 col4" >0.58</td>
#       <td id="T_86b23_row6_col5" class="data

# %%
effects_neutral_tg_rand_rf.mean()
# Out:
# 5 min     0.740968
# 10 min    1.600000
# 15 min    1.801290
# 30 min    1.856129
# 1 hour    1.946129
# 1 day     0.149355
# dtype: float64

# %%
effects_neutral_tg_rand_rf.filter(['ALRS', 'AFLT', 'GAZP', 'LSRG', 'DSKY', 'MAGN', 'MOEX', 'MTSS', 'ROSN', 'NVTK', 'PIKK', 'HYDR', 'CHMF', 'AFKS', 'SNGS', 'PHOR'], axis=0).sort_index().style.applymap(_color_red_or_green).format(precision=2)
# Out:
# <style type="text/css">
# #T_606df_row0_col0, #T_606df_row0_col1, #T_606df_row0_col2, #T_606df_row0_col3, #T_606df_row0_col4, #T_606df_row1_col1, #T_606df_row1_col2, #T_606df_row1_col3, #T_606df_row1_col4, #T_606df_row1_col5, #T_606df_row2_col0, #T_606df_row2_col1, #T_606df_row2_col2, #T_606df_row2_col4, #T_606df_row2_col5, #T_606df_row3_col1, #T_606df_row3_col2, #T_606df_row3_col3, #T_606df_row3_col4, #T_606df_row3_col5, #T_606df_row4_col0, #T_606df_row4_col1, #T_606df_row4_col2, #T_606df_row4_col3, #T_606df_row4_col4, #T_606df_row5_col0, #T_606df_row5_col1, #T_606df_row5_col2, #T_606df_row5_col3, #T_606df_row5_col4, #T_606df_row6_col0, #T_606df_row6_col1, #T_606df_row6_col2, #T_606df_row6_col4, #T_606df_row6_col5, #T_606df_row7_col0, #T_606df_row7_col1, #T_606df_row7_col2, #T_606df_row7_col3, #T_606df_row7_col4, #T_606df_row8_col1, #T_606df_row8_col2, #T_606df_row8_col3, #T_606df_row8_col4, #T_606df_row9_col0, #T_606df_row9_col1, #T_606df_row9_col2, #T_606df_row9_col3, #T_606df_row9_col4, #T_606df_row9_col5, #T_606df_row10_col0, #T_606df_row10_col1, #T_606df_row10_col2, #T_606df_row10_col3, #T_606df_row10_col4, #T_606df_row11_col0, #T_606df_row11_col2, #T_606df_row11_col3, #T_606df_row11_col4, #T_606df_row11_col5, #T_606df_row12_col0, #T_606df_row12_col1, #T_606df_row12_col2, #T_606df_row12_col3, #T_606df_row12_col4, #T_606df_row12_col5, #T_606df_row13_col1, #T_606df_row13_col2, #T_606df_row13_col3, #T_606df_row13_col4, #T_606df_row13_col5, #T_606df_row14_col0, #T_606df_row14_col1, #T_606df_row14_col2, #T_606df_row14_col3, #T_606df_row14_col4, #T_606df_row14_col5, #T_606df_row15_col0, #T_606df_row15_col1, #T_606df_row15_col2, #T_606df_row15_col3, #T_606df_row15_col4, #T_606df_row15_col5 {
#   color: green;
# }
# #T_606df_row0_col5, #T_606df_row1_col0, #T_606df_row2_col3, #T_606df_row3_col0, #T_606df_row4_col5, #T_606df_row5_col5, #T_606df_row6_col3, #T_606df_row7_col5, #T_606df_row8_col0, #T_606df_row8_col5, #T_606df_row10_col5, #T_606df_row11_col1, #T_606df_row13_col0 {
#   color: red;
# }
# </style>
# <table id="T_606df" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_606df_level0_col0" class="col_heading level0 col0" >5 min</th>
#       <th id="T_606df_level0_col1" class="col_heading level0 col1" >10 min</th>
#       <th id="T_606df_level0_col2" class="col_heading level0 col2" >15 min</th>
#       <th id="T_606df_level0_col3" class="col_heading level0 col3" >30 min</th>
#       <th id="T_606df_level0_col4" class="col_heading level0 col4" >1 hour</th>
#       <th id="T_606df_level0_col5" class="col_heading level0 col5" >1 day</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_606df_level0_row0" class="row_heading level0 row0" >AFKS</th>
#       <td id="T_606df_row0_col0" class="data row0 col0" >1.47</td>
#       <td id="T_606df_row0_col1" class="data row0 col1" >4.63</td>
#       <td id="T_606df_row0_col2" class="data row0 col2" >1.27</td>
#       <td id="T_606df_row0_col3" class="data row0 col3" >0.89</td>
#       <td id="T_606df_row0_col4" class="data row0 col4" >0.11</td>
#       <td id="T_606df_row0_col5" class="data row0 col5" >-0.13</td>
#     </tr>
#     <tr>
#       <th id="T_606df_level0_row1" class="row_heading level0 row1" >AFLT</th>
#       <td id="T_606df_row1_col0" class="data row1 col0" >-0.77</td>
#       <td id="T_606df_row1_col1" class="data row1 col1" >1.91</td>
#       <td id="T_606df_row1_col2" class="data row1 col2" >2.53</td>
#       <td id="T_606df_row1_col3" class="data row1 col3" >1.44</td>
#       <td id="T_606df_row1_col4" class="data row1 col4" >1.56</td>
#       <td id="T_606df_row1_col5" class="data row1 col5" >2.88</td>
#     </tr>
#     <tr>
#       <th id="T_606df_level0_row2" class="row_heading level0 row2" >ALRS</th>
#       <td id="T_606df_row2_col0" class="data row2 col0" >0.50</td>
#       <td id="T_606df_row2_col1" class="data row2 col1" >3.32</td>
#       <td id="T_606df_row2_col2" class="data row2 col2" >1.84</td>
#       <td id="T_606df_row2_col3" class="data row2 col3" >-0.35</td>
#       <td id="T_606df_row2_col4" class="data row2 col4" >2.93</td>
#       <td id="T_606df_row2_col5" class="data row2 col5" >2.82</td>
#     </tr>
#     <tr>
#       <th id="T_606df_level0_row3" class="row_heading level0 row3" >CHMF</th>
#       <td id="T_606df_row3_col0" class="data row3 col0" >-0.52</td>
#       <td id="T_606df_row3_col1" class="data row3 col1" >7.04</td>
#       <td id="T_606df_row3_col2" class="data row3 col2" >7.72</td>
#       <td id="T_606df_row3_col3" class="data row3 col3" >5.15</td>
#       <td id="T_606df_row3_col4" class="data row3 col4" >7.47</td>
#       <td id="T_606df_row3_col5" class="data row3 col5" >0.05</td>
#     </tr>
#     <tr>
#       <th id="T_606df_level0_row4" class="row_heading level0 row4" >DSKY</th>
#       <td id="T_606df_row4_col0" class="data row4 col0" >6.32</td>
#       <td id="T_606df_row4_col1" class="data row4 col1" >4.01</td>
#       <td id="T_606df_row4_col2" class="data row4 col2" >9.69</td>
#       <td id="T_606df_row4_col3" class="data row4 col3" >14.72</td>
#       <td id="T_606df_row4_col4" class="data row4 col4" >9.26</td>
#       <td id="T_606df_row4_col5" class="data row4 col5" >-0.20</td>
#     </tr>
#     <tr>
#       <th id="T_606df_level0_row5" class="row_heading level0 row5" >GAZP</th>
#       <td id="T_606df_row5_col0" class="data row5 col0" >1.94</td>
#       <td id="T_606df_row5_col1" class="data row5 col1" >1.00</td>
#       <td id="T_606df_row5_col2" class="data row5 col2" >1.97</td>
#       <td id="T_606df_row5_col3" class="data row5 col3" >2.37</td>
#       <td id="T_606df_row5_col4" class="data row5 col4" >2.45</td>
#       <td id="T_606df_row5_col5" class="data row5 col5" >-0.45</td>
#     </tr>
#     <tr>
#       <th id="T_606df_level0_row6" class="row_heading level0 row6" >HYDR</th>
#       <td id="T_606df_row6_col0" class="data row6 col0" >4.50</td>
#       <td id="T_606df_row6_col1" class="data row6 col1" >4.27</td>
#       <td id="T_606df_row6_col2" class="data row6 col2" >6.03</td>
#       <td id="T_606df_row6_col3" class="data row6 col3" >-1.58</td>
#       <td id="T_606df_row6_col4" class="data row6 col4" >1.63</td>
#       <td id="T_606df_row6_col5" class="data row6 col5" >4.17</td>
#     </tr>
#     <tr>
#       <th id="T_606df_level0_row7" class="row_heading level0 row7" >LSRG</th>
#       <td id="T_606df_row7_col0" class="data row7 col0" >5.13</td>
#       <td id="T_606df_row7_col1" class="data row7 col1" >3.22</td>
#       <td id="T_606df_row7_col2" class="data row7 col2" >0.48</td>
#       <td id="T_606df_row7_col3" class="data row7 col3" >3.63</td>
#       <td id="T_606df_row7_col4" class="data row7 col4" >0.27</td>
#       <td id="T_606df_row7_col5" class="data row7 col5" >-1.48</td>
#     </tr>
#     <tr>
#       <th id="T_606df_level0_row8" class="row_heading level0 row8" >MAGN</th>
#       <td id="T_606df_row8_col0" class="data row8 col0" >-2.17</td>
#       <td id="T_606df_row8_col1" class="data row8 col1" >2.37</td>
#       <td id="T_606df_row8_col2" class="data row8 col2" >4.53</td>
#       <td id="T_606df_row8_col3" class="data row8 col3" >2.86</td>
#       <td id="T_606df_row8_col4" class="data row8 col4" >5.24</td>
#       <td id="T_606df_row8_col5" class="data row8 col5" >-0.05</td>
#     </tr>
#     <tr>
#       <th id="T_606df_level0_row9" class="row_heading level0 row9" >MOEX</th>
#       <td id="T_606df_row9_col0" class="data row9 col0" >1.16</td>
#       <td id="T_606df_row9_col1" class="data row9 col1" >1.47</td>
#       <td id="T_606df_row9_col2" class="data row9 col2" >1.80</td>
#       <td id="T_606df_row9_col3" class="data row9 col3" >1.74</td>
#       <td id="T_606df_row9_col4" class="data row9 col4" >2.43</td>
#       <td id="T_606df_row9_col5" class="data row9 col5" >1.26</td>
#     </tr>
#     <tr>
#       <th id="T_606df_level0_row10" class="row_heading level0 row10" >MTSS</th>
#       <td id="T_606df_row10_col0" class="data row10 col0" >4.34</td>
#       <td id="T_606df_row10_col1" class="data row10 col1" >2.96</td>
#       <td id="T_606df_row10_col2" class="data row10 col2" >5.06</td>
#       <td id="T_606df_row10_col3" class="data row10 col3" >6.28</td

# %%
effects_neutral_tg_zero_rf.sort_index().style.applymap(_color_red_or_green).format(precision=2)
# Out:
# <style type="text/css">
# #T_f7c97_row0_col0, #T_f7c97_row0_col1, #T_f7c97_row0_col2, #T_f7c97_row0_col3, #T_f7c97_row0_col4, #T_f7c97_row0_col5, #T_f7c97_row1_col0, #T_f7c97_row1_col1, #T_f7c97_row1_col2, #T_f7c97_row1_col3, #T_f7c97_row1_col4, #T_f7c97_row1_col5, #T_f7c97_row2_col0, #T_f7c97_row2_col1, #T_f7c97_row2_col2, #T_f7c97_row2_col3, #T_f7c97_row2_col4, #T_f7c97_row2_col5, #T_f7c97_row3_col0, #T_f7c97_row3_col1, #T_f7c97_row3_col2, #T_f7c97_row3_col3, #T_f7c97_row3_col4, #T_f7c97_row3_col5, #T_f7c97_row4_col0, #T_f7c97_row4_col1, #T_f7c97_row4_col2, #T_f7c97_row4_col3, #T_f7c97_row4_col4, #T_f7c97_row4_col5, #T_f7c97_row5_col0, #T_f7c97_row5_col1, #T_f7c97_row5_col2, #T_f7c97_row5_col3, #T_f7c97_row5_col4, #T_f7c97_row5_col5, #T_f7c97_row6_col0, #T_f7c97_row6_col1, #T_f7c97_row6_col2, #T_f7c97_row6_col3, #T_f7c97_row6_col4, #T_f7c97_row6_col5, #T_f7c97_row7_col0, #T_f7c97_row7_col1, #T_f7c97_row7_col2, #T_f7c97_row7_col3, #T_f7c97_row7_col4, #T_f7c97_row7_col5, #T_f7c97_row8_col0, #T_f7c97_row8_col1, #T_f7c97_row8_col2, #T_f7c97_row8_col3, #T_f7c97_row8_col4, #T_f7c97_row8_col5, #T_f7c97_row9_col0, #T_f7c97_row9_col1, #T_f7c97_row9_col2, #T_f7c97_row9_col3, #T_f7c97_row9_col4, #T_f7c97_row9_col5, #T_f7c97_row10_col0, #T_f7c97_row10_col1, #T_f7c97_row10_col2, #T_f7c97_row10_col3, #T_f7c97_row10_col4, #T_f7c97_row10_col5, #T_f7c97_row11_col0, #T_f7c97_row11_col1, #T_f7c97_row11_col2, #T_f7c97_row11_col3, #T_f7c97_row11_col4, #T_f7c97_row11_col5, #T_f7c97_row12_col0, #T_f7c97_row12_col1, #T_f7c97_row12_col2, #T_f7c97_row12_col3, #T_f7c97_row12_col4, #T_f7c97_row12_col5, #T_f7c97_row13_col0, #T_f7c97_row13_col1, #T_f7c97_row13_col2, #T_f7c97_row13_col3, #T_f7c97_row13_col4, #T_f7c97_row13_col5, #T_f7c97_row14_col0, #T_f7c97_row14_col1, #T_f7c97_row14_col2, #T_f7c97_row14_col3, #T_f7c97_row14_col4, #T_f7c97_row14_col5, #T_f7c97_row15_col0, #T_f7c97_row15_col1, #T_f7c97_row15_col2, #T_f7c97_row15_col3, #T_f7c97_row15_col4, #T_f7c97_row16_col0, #T_f7c97_row16_col1, #T_f7c97_row16_col2, #T_f7c97_row16_col3, #T_f7c97_row16_col4, #T_f7c97_row16_col5, #T_f7c97_row17_col0, #T_f7c97_row17_col1, #T_f7c97_row17_col2, #T_f7c97_row17_col3, #T_f7c97_row17_col4, #T_f7c97_row17_col5, #T_f7c97_row18_col0, #T_f7c97_row18_col1, #T_f7c97_row18_col2, #T_f7c97_row18_col3, #T_f7c97_row18_col4, #T_f7c97_row18_col5, #T_f7c97_row19_col0, #T_f7c97_row19_col1, #T_f7c97_row19_col2, #T_f7c97_row19_col3, #T_f7c97_row19_col4, #T_f7c97_row19_col5, #T_f7c97_row20_col0, #T_f7c97_row20_col1, #T_f7c97_row20_col2, #T_f7c97_row20_col3, #T_f7c97_row20_col4, #T_f7c97_row21_col0, #T_f7c97_row21_col1, #T_f7c97_row21_col2, #T_f7c97_row21_col3, #T_f7c97_row21_col4, #T_f7c97_row21_col5, #T_f7c97_row22_col0, #T_f7c97_row22_col1, #T_f7c97_row22_col2, #T_f7c97_row22_col3, #T_f7c97_row22_col4, #T_f7c97_row22_col5, #T_f7c97_row23_col0, #T_f7c97_row23_col1, #T_f7c97_row23_col2, #T_f7c97_row23_col3, #T_f7c97_row23_col4, #T_f7c97_row23_col5, #T_f7c97_row24_col0, #T_f7c97_row24_col1, #T_f7c97_row24_col2, #T_f7c97_row24_col3, #T_f7c97_row24_col4, #T_f7c97_row24_col5, #T_f7c97_row25_col0, #T_f7c97_row25_col1, #T_f7c97_row25_col2, #T_f7c97_row25_col3, #T_f7c97_row25_col4, #T_f7c97_row25_col5, #T_f7c97_row26_col0, #T_f7c97_row26_col1, #T_f7c97_row26_col2, #T_f7c97_row26_col3, #T_f7c97_row26_col4, #T_f7c97_row26_col5, #T_f7c97_row27_col0, #T_f7c97_row27_col1, #T_f7c97_row27_col2, #T_f7c97_row27_col3, #T_f7c97_row27_col4, #T_f7c97_row27_col5, #T_f7c97_row28_col0, #T_f7c97_row28_col2, #T_f7c97_row28_col3, #T_f7c97_row28_col4, #T_f7c97_row28_col5, #T_f7c97_row29_col0, #T_f7c97_row29_col1, #T_f7c97_row29_col2, #T_f7c97_row29_col3, #T_f7c97_row29_col4, #T_f7c97_row29_col5, #T_f7c97_row30_col0, #T_f7c97_row30_col1, #T_f7c97_row30_col2, #T_f7c97_row30_col3, #T_f7c97_row30_col4, #T_f7c97_row30_col5 {
#   color: green;
# }
# #T_f7c97_row15_col5, #T_f7c97_row20_col5, #T_f7c97_row28_col1 {
#   color: red;
# }
# </style>
# <table id="T_f7c97" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f7c97_level0_col0" class="col_heading level0 col0" >5 min</th>
#       <th id="T_f7c97_level0_col1" class="col_heading level0 col1" >10 min</th>
#       <th id="T_f7c97_level0_col2" class="col_heading level0 col2" >15 min</th>
#       <th id="T_f7c97_level0_col3" class="col_heading level0 col3" >30 min</th>
#       <th id="T_f7c97_level0_col4" class="col_heading level0 col4" >1 hour</th>
#       <th id="T_f7c97_level0_col5" class="col_heading level0 col5" >1 day</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f7c97_level0_row0" class="row_heading level0 row0" >AFKS</th>
#       <td id="T_f7c97_row0_col0" class="data row0 col0" >0.15</td>
#       <td id="T_f7c97_row0_col1" class="data row0 col1" >0.19</td>
#       <td id="T_f7c97_row0_col2" class="data row0 col2" >0.18</td>
#       <td id="T_f7c97_row0_col3" class="data row0 col3" >0.18</td>
#       <td id="T_f7c97_row0_col4" class="data row0 col4" >0.17</td>
#       <td id="T_f7c97_row0_col5" class="data row0 col5" >0.11</td>
#     </tr>
#     <tr>
#       <th id="T_f7c97_level0_row1" class="row_heading level0 row1" >AFLT</th>
#       <td id="T_f7c97_row1_col0" class="data row1 col0" >0.13</td>
#       <td id="T_f7c97_row1_col1" class="data row1 col1" >0.14</td>
#       <td id="T_f7c97_row1_col2" class="data row1 col2" >0.16</td>
#       <td id="T_f7c97_row1_col3" class="data row1 col3" >0.17</td>
#       <td id="T_f7c97_row1_col4" class="data row1 col4" >0.17</td>
#       <td id="T_f7c97_row1_col5" class="data row1 col5" >0.14</td>
#     </tr>
#     <tr>
#       <th id="T_f7c97_level0_row2" class="row_heading level0 row2" >ALRS</th>
#       <td id="T_f7c97_row2_col0" class="data row2 col0" >0.11</td>
#       <td id="T_f7c97_row2_col1" class="data row2 col1" >0.24</td>
#       <td id="T_f7c97_row2_col2" class="data row2 col2" >0.19</td>
#       <td id="T_f7c97_row2_col3" class="data row2 col3" >0.20</td>
#       <td id="T_f7c97_row2_col4" class="data row2 col4" >0.26</td>
#       <td id="T_f7c97_row2_col5" class="data row2 col5" >0.22</td>
#     </tr>
#     <tr>
#       <th id="T_f7c97_level0_row3" class="row_heading level0 row3" >CBOM</th>
#       <td id="T_f7c97_row3_col0" class="data row3 col0" >0.08</td>
#       <td id="T_f7c97_row3_col1" class="data row3 col1" >0.11</td>
#       <td id="T_f7c97_row3_col2" class="data row3 col2" >0.10</td>
#       <td id="T_f7c97_row3_col3" class="data row3 col3" >0.24</td>
#       <td id="T_f7c97_row3_col4" class="data row3 col4" >0.21</td>
#       <td id="T_f7c97_row3_col5" class="data row3 col5" >0.16</td>
#     </tr>
#     <tr>
#       <th id="T_f7c97_level0_row4" class="row_heading level0 row4" >CHMF</th>
#       <td id="T_f7c97_row4_col0" class="data row4 col0" >0.07</td>
#       <td id="T_f7c97_row4_col1" class="data row4 col1" >0.29</td>
#       <td id="T_f7c97_row4_col2" class="data row4 col2" >0.31</td>
#       <td id="T_f7c97_row4_col3" class="data row4 col3" >0.26</td>
#       <td id="T_f7c97_row4_col4" class="data row4 col4" >0.27</td>
#       <td id="T_f7c97_row4_col5" class="data row4 col5" >0.16</td>
#     </tr>
#     <tr>
#       <th id="T_f7c97_level0_row5" class="row_heading level0 row5" >DSKY</th>
#       <td id="T_f7c97_row5_col0" class="data row5 col0" >0.28</td>
#       <td id="T_f7c97_row5_col1" class="data row5 col1" >0.33</td>
#       <td id="T_f7c97_row5_col2" class="data row5 col2" >0.36</td>
#       <td id="T_f7c97_row5_col3" class="data row5 col3" >0.46</td>
#       <td id="T_f7c97_row5_col4" class="data row5 col4" >0.39</td>
#       <td id="T_f7c97_row5_col5" class="data row5 col5" >0.19</td>
#     </tr>
#     <tr>
#       <th id="T_f7c97_level0_row6" class="row_heading level0 row6" >FEES</th>
#       <td id="T_f7c97_row6_col0" class="data row6 col0" >0.08</td>
#       <td id="T_f7c97_row6_col1" class="data row6 col1" >0.10</td>
#       <td id="T_f7c97_row6_col2" class="data row6 col2" >0.07</td>
#       <td id="T_f7c97_row6_col3" class="data row6 col3" >0.14</td>
#       <td id="T_f7c97_row6_col4" class="data row6 col4" >0.18</td>
#       <td id="T_f7c97_row6_col5" class="data row6 col5" >0

# %%
effects_neutral_tg_zero_rf.filter(['ALRS', 'AFLT', 'GAZP', 'LSRG', 'DSKY', 'MAGN', 'MOEX', 'MTSS', 'ROSN', 'NVTK', 'PIKK', 'HYDR', 'CHMF', 'AFKS', 'SNGS', 'PHOR'], axis=0).sort_index().style.applymap(_color_red_or_green).format(precision=2)
# Out:
# <style type="text/css">
# #T_97d1d_row0_col0, #T_97d1d_row0_col1, #T_97d1d_row0_col2, #T_97d1d_row0_col3, #T_97d1d_row0_col4, #T_97d1d_row0_col5, #T_97d1d_row1_col0, #T_97d1d_row1_col1, #T_97d1d_row1_col2, #T_97d1d_row1_col3, #T_97d1d_row1_col4, #T_97d1d_row1_col5, #T_97d1d_row2_col0, #T_97d1d_row2_col1, #T_97d1d_row2_col2, #T_97d1d_row2_col3, #T_97d1d_row2_col4, #T_97d1d_row2_col5, #T_97d1d_row3_col0, #T_97d1d_row3_col1, #T_97d1d_row3_col2, #T_97d1d_row3_col3, #T_97d1d_row3_col4, #T_97d1d_row3_col5, #T_97d1d_row4_col0, #T_97d1d_row4_col1, #T_97d1d_row4_col2, #T_97d1d_row4_col3, #T_97d1d_row4_col4, #T_97d1d_row4_col5, #T_97d1d_row5_col0, #T_97d1d_row5_col1, #T_97d1d_row5_col2, #T_97d1d_row5_col3, #T_97d1d_row5_col4, #T_97d1d_row5_col5, #T_97d1d_row6_col0, #T_97d1d_row6_col1, #T_97d1d_row6_col2, #T_97d1d_row6_col3, #T_97d1d_row6_col4, #T_97d1d_row6_col5, #T_97d1d_row7_col0, #T_97d1d_row7_col1, #T_97d1d_row7_col2, #T_97d1d_row7_col3, #T_97d1d_row7_col4, #T_97d1d_row7_col5, #T_97d1d_row8_col0, #T_97d1d_row8_col1, #T_97d1d_row8_col2, #T_97d1d_row8_col3, #T_97d1d_row8_col4, #T_97d1d_row8_col5, #T_97d1d_row9_col0, #T_97d1d_row9_col1, #T_97d1d_row9_col2, #T_97d1d_row9_col3, #T_97d1d_row9_col4, #T_97d1d_row9_col5, #T_97d1d_row10_col0, #T_97d1d_row10_col1, #T_97d1d_row10_col2, #T_97d1d_row10_col3, #T_97d1d_row10_col4, #T_97d1d_row11_col0, #T_97d1d_row11_col1, #T_97d1d_row11_col2, #T_97d1d_row11_col3, #T_97d1d_row11_col4, #T_97d1d_row11_col5, #T_97d1d_row12_col0, #T_97d1d_row12_col1, #T_97d1d_row12_col2, #T_97d1d_row12_col3, #T_97d1d_row12_col4, #T_97d1d_row12_col5, #T_97d1d_row13_col0, #T_97d1d_row13_col1, #T_97d1d_row13_col2, #T_97d1d_row13_col3, #T_97d1d_row13_col4, #T_97d1d_row13_col5, #T_97d1d_row14_col0, #T_97d1d_row14_col1, #T_97d1d_row14_col2, #T_97d1d_row14_col3, #T_97d1d_row14_col4, #T_97d1d_row14_col5, #T_97d1d_row15_col0, #T_97d1d_row15_col1, #T_97d1d_row15_col2, #T_97d1d_row15_col3, #T_97d1d_row15_col4, #T_97d1d_row15_col5 {
#   color: green;
# }
# #T_97d1d_row10_col5 {
#   color: red;
# }
# </style>
# <table id="T_97d1d" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_97d1d_level0_col0" class="col_heading level0 col0" >5 min</th>
#       <th id="T_97d1d_level0_col1" class="col_heading level0 col1" >10 min</th>
#       <th id="T_97d1d_level0_col2" class="col_heading level0 col2" >15 min</th>
#       <th id="T_97d1d_level0_col3" class="col_heading level0 col3" >30 min</th>
#       <th id="T_97d1d_level0_col4" class="col_heading level0 col4" >1 hour</th>
#       <th id="T_97d1d_level0_col5" class="col_heading level0 col5" >1 day</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_97d1d_level0_row0" class="row_heading level0 row0" >AFKS</th>
#       <td id="T_97d1d_row0_col0" class="data row0 col0" >0.15</td>
#       <td id="T_97d1d_row0_col1" class="data row0 col1" >0.19</td>
#       <td id="T_97d1d_row0_col2" class="data row0 col2" >0.18</td>
#       <td id="T_97d1d_row0_col3" class="data row0 col3" >0.18</td>
#       <td id="T_97d1d_row0_col4" class="data row0 col4" >0.17</td>
#       <td id="T_97d1d_row0_col5" class="data row0 col5" >0.11</td>
#     </tr>
#     <tr>
#       <th id="T_97d1d_level0_row1" class="row_heading level0 row1" >AFLT</th>
#       <td id="T_97d1d_row1_col0" class="data row1 col0" >0.13</td>
#       <td id="T_97d1d_row1_col1" class="data row1 col1" >0.14</td>
#       <td id="T_97d1d_row1_col2" class="data row1 col2" >0.16</td>
#       <td id="T_97d1d_row1_col3" class="data row1 col3" >0.17</td>
#       <td id="T_97d1d_row1_col4" class="data row1 col4" >0.17</td>
#       <td id="T_97d1d_row1_col5" class="data row1 col5" >0.14</td>
#     </tr>
#     <tr>
#       <th id="T_97d1d_level0_row2" class="row_heading level0 row2" >ALRS</th>
#       <td id="T_97d1d_row2_col0" class="data row2 col0" >0.11</td>
#       <td id="T_97d1d_row2_col1" class="data row2 col1" >0.24</td>
#       <td id="T_97d1d_row2_col2" class="data row2 col2" >0.19</td>
#       <td id="T_97d1d_row2_col3" class="data row2 col3" >0.20</td>
#       <td id="T_97d1d_row2_col4" class="data row2 col4" >0.26</td>
#       <td id="T_97d1d_row2_col5" class="data row2 col5" >0.22</td>
#     </tr>
#     <tr>
#       <th id="T_97d1d_level0_row3" class="row_heading level0 row3" >CHMF</th>
#       <td id="T_97d1d_row3_col0" class="data row3 col0" >0.07</td>
#       <td id="T_97d1d_row3_col1" class="data row3 col1" >0.29</td>
#       <td id="T_97d1d_row3_col2" class="data row3 col2" >0.31</td>
#       <td id="T_97d1d_row3_col3" class="data row3 col3" >0.26</td>
#       <td id="T_97d1d_row3_col4" class="data row3 col4" >0.27</td>
#       <td id="T_97d1d_row3_col5" class="data row3 col5" >0.16</td>
#     </tr>
#     <tr>
#       <th id="T_97d1d_level0_row4" class="row_heading level0 row4" >DSKY</th>
#       <td id="T_97d1d_row4_col0" class="data row4 col0" >0.28</td>
#       <td id="T_97d1d_row4_col1" class="data row4 col1" >0.33</td>
#       <td id="T_97d1d_row4_col2" class="data row4 col2" >0.36</td>
#       <td id="T_97d1d_row4_col3" class="data row4 col3" >0.46</td>
#       <td id="T_97d1d_row4_col4" class="data row4 col4" >0.39</td>
#       <td id="T_97d1d_row4_col5" class="data row4 col5" >0.19</td>
#     </tr>
#     <tr>
#       <th id="T_97d1d_level0_row5" class="row_heading level0 row5" >GAZP</th>
#       <td id="T_97d1d_row5_col0" class="data row5 col0" >0.15</td>
#       <td id="T_97d1d_row5_col1" class="data row5 col1" >0.18</td>
#       <td id="T_97d1d_row5_col2" class="data row5 col2" >0.17</td>
#       <td id="T_97d1d_row5_col3" class="data row5 col3" >0.20</td>
#       <td id="T_97d1d_row5_col4" class="data row5 col4" >0.15</td>
#       <td id="T_97d1d_row5_col5" class="data row5 col5" >0.15</td>
#     </tr>
#     <tr>
#       <th id="T_97d1d_level0_row6" class="row_heading level0 row6" >HYDR</th>
#       <td id="T_97d1d_row6_col0" class="data row6 col0" >0.10</td>
#       <td id="T_97d1d_row6_col1" class="data row6 col1" >0.11</td>
#       <td id="T_97d1d_row6_col2" class="data row6 col2" >0.16</td>
#       <td id="T_97d1d_row6_col3" class="data row6 col3" >0.11</td>
#       <td id="T_97d1d_row6_col4" class="data row6 col4" >0.15</td>
#       <td id="T_97d1d_row6_col5" class="data row6 col5" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_97d1d_level0_row7" class="row_heading level0 row7" >LSRG</th>
#       <td id="T_97d1d_row7_col0" class="data row7 col0" >0.04</td>
#       <td id="T_97d1d_row7_col1" class="data row7 col1" >0.06</td>
#       <td id="T_97d1d_row7_col2" class="data row7 col2" >0.09</td>
#       <td id="T_97d1d_row7_col3" class="data row7 col3" >0.06</td>
#       <td id="T_97d1d_row7_col4" class="data row7 col4" >0.11</td>
#       <td id="T_97d1d_row7_col5" class="data row7 col5" >0.03</td>
#     </tr>
#     <tr>
#       <th id="T_97d1d_level0_row8" class="row_heading level0 row8" >MAGN</th>
#       <td id="T_97d1d_row8_col0" class="data row8 col0" >0.12</td>
#       <td id="T_97d1d_row8_col1" class="data row8 col1" >0.17</td>
#       <td id="T_97d1d_row8_col2" class="data row8 col2" >0.24</td>
#       <td id="T_97d1d_row8_col3" class="data row8 col3" >0.23</td>
#       <td id="T_97d1d_row8_col4" class="data row8 col4" >0.25</td>
#       <td id="T_97d1d_row8_col5" class="data row8 col5" >0.15</td>
#     </tr>
#     <tr>
#       <th id="T_97d1d_level0_row9" class="row_heading level0 row9" >MOEX</th>
#       <td id="T_97d1d_row9_col0" class="data row9 col0" >0.12</td>
#       <td id="T_97d1d_row9_col1" class="data row9 col1" >0.15</td>
#       <td id="T_97d1d_row9_col2" class="data row9 col2" >0.19</td>
#       <td id="T_97d1d_row9_col3" class="data row9 col3" >0.20</td>
#       <td id="T_97d1d_row9_col4" class="data row9 col4" >0.17</td>
#       <td id="T_97d1d_row9_col5" class="data row9 col5" >0.10</td>
#     </tr>
#     <tr>
#       <th id="T_97d1d_level0_row10" class="row_heading level0 row10" >MTSS</th>
#       <td id="T_97d1d_row10_col0" class="data row10 col0" >0.07</td>
#       <td id="T_97d1d_row10_col1" class="data row10 col1" >0.12</td>
#       <td id="T_97d1d_row10_col2" class="data row10 col2" >0.16</td>
#       <td id="T_97d1d_row10_col3" class="data row10 col3" >0.19</td>
#       <td

# %%
effects_neutral_tg_zero_rf.mean()
# Out:
# 5 min     0.122517
# 10 min    0.167812
# 15 min    0.173382
# 30 min    0.187880
# 1 hour    0.192530
# 1 day     0.104955
# dtype: float64

# %%
loggs = pd.read_csv('/content/drive/MyDrive/Диссертация/tg_loggs/loggs_tg_boosting_neutral.csv', index_col=0)

# %%
effects_neutral_tg_rand_boosting, effects_neutral_tg_zero_boosting = get_effects_neutral(tg_train, tg_test, loggs)

# %%
effects_neutral_tg_rand_boosting.sort_index().style.applymap(_color_red_or_green).format(precision=2)
# Out:
# <style type="text/css">
# #T_ab4c0_row0_col0, #T_ab4c0_row0_col1, #T_ab4c0_row0_col5, #T_ab4c0_row1_col1, #T_ab4c0_row2_col0, #T_ab4c0_row2_col1, #T_ab4c0_row2_col4, #T_ab4c0_row2_col5, #T_ab4c0_row3_col0, #T_ab4c0_row3_col1, #T_ab4c0_row3_col5, #T_ab4c0_row4_col0, #T_ab4c0_row4_col5, #T_ab4c0_row6_col0, #T_ab4c0_row6_col1, #T_ab4c0_row6_col3, #T_ab4c0_row6_col5, #T_ab4c0_row8_col0, #T_ab4c0_row8_col2, #T_ab4c0_row8_col5, #T_ab4c0_row9_col0, #T_ab4c0_row9_col3, #T_ab4c0_row9_col4, #T_ab4c0_row10_col0, #T_ab4c0_row10_col1, #T_ab4c0_row10_col2, #T_ab4c0_row10_col3, #T_ab4c0_row10_col4, #T_ab4c0_row10_col5, #T_ab4c0_row12_col1, #T_ab4c0_row12_col2, #T_ab4c0_row12_col3, #T_ab4c0_row12_col4, #T_ab4c0_row12_col5, #T_ab4c0_row13_col0, #T_ab4c0_row13_col4, #T_ab4c0_row13_col5, #T_ab4c0_row14_col0, #T_ab4c0_row14_col2, #T_ab4c0_row14_col3, #T_ab4c0_row14_col5, #T_ab4c0_row15_col0, #T_ab4c0_row15_col4, #T_ab4c0_row15_col5, #T_ab4c0_row16_col2, #T_ab4c0_row16_col4, #T_ab4c0_row16_col5, #T_ab4c0_row18_col0, #T_ab4c0_row18_col1, #T_ab4c0_row18_col2, #T_ab4c0_row18_col4, #T_ab4c0_row19_col0, #T_ab4c0_row19_col4, #T_ab4c0_row19_col5, #T_ab4c0_row20_col0, #T_ab4c0_row20_col1, #T_ab4c0_row20_col5, #T_ab4c0_row21_col0, #T_ab4c0_row22_col0, #T_ab4c0_row22_col1, #T_ab4c0_row22_col2, #T_ab4c0_row22_col4, #T_ab4c0_row22_col5, #T_ab4c0_row23_col3, #T_ab4c0_row23_col4, #T_ab4c0_row24_col0, #T_ab4c0_row24_col5, #T_ab4c0_row26_col0, #T_ab4c0_row26_col1, #T_ab4c0_row26_col2, #T_ab4c0_row27_col2, #T_ab4c0_row27_col3, #T_ab4c0_row27_col4, #T_ab4c0_row27_col5, #T_ab4c0_row28_col2, #T_ab4c0_row28_col3, #T_ab4c0_row28_col4, #T_ab4c0_row28_col5, #T_ab4c0_row29_col0, #T_ab4c0_row29_col1, #T_ab4c0_row29_col2, #T_ab4c0_row29_col3, #T_ab4c0_row29_col5, #T_ab4c0_row30_col0, #T_ab4c0_row30_col3 {
#   color: red;
# }
# #T_ab4c0_row0_col2, #T_ab4c0_row0_col3, #T_ab4c0_row0_col4, #T_ab4c0_row1_col0, #T_ab4c0_row1_col2, #T_ab4c0_row1_col3, #T_ab4c0_row1_col4, #T_ab4c0_row1_col5, #T_ab4c0_row2_col2, #T_ab4c0_row2_col3, #T_ab4c0_row3_col2, #T_ab4c0_row3_col3, #T_ab4c0_row3_col4, #T_ab4c0_row4_col1, #T_ab4c0_row4_col2, #T_ab4c0_row4_col3, #T_ab4c0_row4_col4, #T_ab4c0_row5_col0, #T_ab4c0_row5_col1, #T_ab4c0_row5_col2, #T_ab4c0_row5_col3, #T_ab4c0_row5_col4, #T_ab4c0_row5_col5, #T_ab4c0_row6_col2, #T_ab4c0_row6_col4, #T_ab4c0_row7_col0, #T_ab4c0_row7_col1, #T_ab4c0_row7_col2, #T_ab4c0_row7_col3, #T_ab4c0_row7_col4, #T_ab4c0_row7_col5, #T_ab4c0_row8_col1, #T_ab4c0_row8_col3, #T_ab4c0_row8_col4, #T_ab4c0_row9_col1, #T_ab4c0_row9_col2, #T_ab4c0_row9_col5, #T_ab4c0_row11_col0, #T_ab4c0_row11_col1, #T_ab4c0_row11_col2, #T_ab4c0_row11_col3, #T_ab4c0_row11_col4, #T_ab4c0_row11_col5, #T_ab4c0_row12_col0, #T_ab4c0_row13_col1, #T_ab4c0_row13_col2, #T_ab4c0_row13_col3, #T_ab4c0_row14_col1, #T_ab4c0_row14_col4, #T_ab4c0_row15_col1, #T_ab4c0_row15_col2, #T_ab4c0_row15_col3, #T_ab4c0_row16_col0, #T_ab4c0_row16_col1, #T_ab4c0_row16_col3, #T_ab4c0_row17_col0, #T_ab4c0_row17_col1, #T_ab4c0_row17_col2, #T_ab4c0_row17_col3, #T_ab4c0_row17_col4, #T_ab4c0_row17_col5, #T_ab4c0_row18_col3, #T_ab4c0_row18_col5, #T_ab4c0_row19_col1, #T_ab4c0_row19_col2, #T_ab4c0_row19_col3, #T_ab4c0_row20_col2, #T_ab4c0_row20_col3, #T_ab4c0_row20_col4, #T_ab4c0_row21_col1, #T_ab4c0_row21_col2, #T_ab4c0_row21_col3, #T_ab4c0_row21_col4, #T_ab4c0_row21_col5, #T_ab4c0_row22_col3, #T_ab4c0_row23_col0, #T_ab4c0_row23_col1, #T_ab4c0_row23_col2, #T_ab4c0_row23_col5, #T_ab4c0_row24_col1, #T_ab4c0_row24_col2, #T_ab4c0_row24_col3, #T_ab4c0_row24_col4, #T_ab4c0_row25_col0, #T_ab4c0_row25_col1, #T_ab4c0_row25_col2, #T_ab4c0_row25_col3, #T_ab4c0_row25_col4, #T_ab4c0_row25_col5, #T_ab4c0_row26_col3, #T_ab4c0_row26_col4, #T_ab4c0_row26_col5, #T_ab4c0_row27_col0, #T_ab4c0_row27_col1, #T_ab4c0_row28_col0, #T_ab4c0_row28_col1, #T_ab4c0_row29_col4, #T_ab4c0_row30_col1, #T_ab4c0_row30_col2, #T_ab4c0_row30_col4, #T_ab4c0_row30_col5 {
#   color: green;
# }
# </style>
# <table id="T_ab4c0" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ab4c0_level0_col0" class="col_heading level0 col0" >5 min</th>
#       <th id="T_ab4c0_level0_col1" class="col_heading level0 col1" >10 min</th>
#       <th id="T_ab4c0_level0_col2" class="col_heading level0 col2" >15 min</th>
#       <th id="T_ab4c0_level0_col3" class="col_heading level0 col3" >30 min</th>
#       <th id="T_ab4c0_level0_col4" class="col_heading level0 col4" >1 hour</th>
#       <th id="T_ab4c0_level0_col5" class="col_heading level0 col5" >1 day</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ab4c0_level0_row0" class="row_heading level0 row0" >AFKS</th>
#       <td id="T_ab4c0_row0_col0" class="data row0 col0" >-0.69</td>
#       <td id="T_ab4c0_row0_col1" class="data row0 col1" >-0.77</td>
#       <td id="T_ab4c0_row0_col2" class="data row0 col2" >0.39</td>
#       <td id="T_ab4c0_row0_col3" class="data row0 col3" >0.17</td>
#       <td id="T_ab4c0_row0_col4" class="data row0 col4" >0.68</td>
#       <td id="T_ab4c0_row0_col5" class="data row0 col5" >-0.39</td>
#     </tr>
#     <tr>
#       <th id="T_ab4c0_level0_row1" class="row_heading level0 row1" >AFLT</th>
#       <td id="T_ab4c0_row1_col0" class="data row1 col0" >1.13</td>
#       <td id="T_ab4c0_row1_col1" class="data row1 col1" >-1.34</td>
#       <td id="T_ab4c0_row1_col2" class="data row1 col2" >1.51</td>
#       <td id="T_ab4c0_row1_col3" class="data row1 col3" >2.26</td>
#       <td id="T_ab4c0_row1_col4" class="data row1 col4" >1.75</td>
#       <td id="T_ab4c0_row1_col5" class="data row1 col5" >3.89</td>
#     </tr>
#     <tr>
#       <th id="T_ab4c0_level0_row2" class="row_heading level0 row2" >ALRS</th>
#       <td id="T_ab4c0_row2_col0" class="data row2 col0" >-5.26</td>
#       <td id="T_ab4c0_row2_col1" class="data row2 col1" >-0.34</td>
#       <td id="T_ab4c0_row2_col2" class="data row2 col2" >0.69</td>
#       <td id="T_ab4c0_row2_col3" class="data row2 col3" >1.44</td>
#       <td id="T_ab4c0_row2_col4" class="data row2 col4" >-0.73</td>
#       <td id="T_ab4c0_row2_col5" class="data row2 col5" >-0.11</td>
#     </tr>
#     <tr>
#       <th id="T_ab4c0_level0_row3" class="row_heading level0 row3" >CBOM</th>
#       <td id="T_ab4c0_row3_col0" class="data row3 col0" >-2.10</td>
#       <td id="T_ab4c0_row3_col1" class="data row3 col1" >-2.85</td>
#       <td id="T_ab4c0_row3_col2" class="data row3 col2" >1.51</td>
#       <td id="T_ab4c0_row3_col3" class="data row3 col3" >1.92</td>
#       <td id="T_ab4c0_row3_col4" class="data row3 col4" >5.47</td>
#       <td id="T_ab4c0_row3_col5" class="data row3 col5" >-2.95</td>
#     </tr>
#     <tr>
#       <th id="T_ab4c0_level0_row4" class="row_heading level0 row4" >CHMF</th>
#       <td id="T_ab4c0_row4_col0" class="data row4 col0" >-1.21</td>
#       <td id="T_ab4c0_row4_col1" class="data row4 col1" >4.05</td>
#       <td id="T_ab4c0_row4_col2" class="data row4 col2" >6.72</td>
#       <td id="T_ab4c0_row4_col3" class="data row4 col3" >5.25</td>
#       <td id="T_ab4c0_row4_col4" class="data row4 col4" >5.63</td>
#       <td id="T_ab4c0_row4_col5" class="data row4 col5" >-2.42</td>
#     </tr>
#     <tr>
#       <th id="T_ab4c0_level0_row5" class="row_heading level0 row5" >DSKY</th>
#       <td id="T_ab4c0_row5_col0" class="data row5 col0" >3.45</td>
#       <td id="T_ab4c0_row5_col1" class="data row5 col1" >3.60</td>
#       <td id="T_ab4c0_row5_col2" class="data row5 col2" >8.56</td>
#       <td id="T_ab4c0_row5_col3" class="data row5 col3" >9.94</td>
#       <td id="T_ab4c0_row5_col4" class="data row5 col4" >6.41</td>
#       <td id="T_ab4c0_row5_col5" class="data row5 col5" >0.37</td>
#     </tr>
#     <tr>
#       <th id="T_ab4c0_level0_row6" class="row_heading level0 row6" >FEES</th>
#       <td id="T_ab4c0_row6_col0" class="data row6 col0" >-1.27</td>
#       <td id="T_ab4c0_row6_col1" class="data row6 col1" >-4.07</td>
#       <td id="T_ab4c0_row6_col2" class="data row6 col2" >1.34</td>
#       <td id="T_ab4c0_row6_col3" class="data row6 col3" >-1.63</td>
#       <td id="T_ab4c0_row6_col4" class="data row6 col4" >0.08</td>
#       <td id="T_ab4c0_row6_col5" class="da

# %%
effects_neutral_tg_rand_boosting.mean()
# Out:
# 5 min    -0.357742
# 10 min   -0.073226
# 15 min    0.417097
# 30 min    0.838710
# 1 hour    0.499032
# 1 day    -0.670645
# dtype: float64

# %%
effects_neutral_tg_zero_boosting.sort_index().style.applymap(_color_red_or_green).format(precision=2)
# Out:
# <style type="text/css">
# #T_7e2f7_row0_col0, #T_7e2f7_row0_col1, #T_7e2f7_row0_col2, #T_7e2f7_row0_col3, #T_7e2f7_row0_col4, #T_7e2f7_row0_col5, #T_7e2f7_row1_col0, #T_7e2f7_row1_col1, #T_7e2f7_row1_col2, #T_7e2f7_row1_col3, #T_7e2f7_row1_col4, #T_7e2f7_row1_col5, #T_7e2f7_row2_col0, #T_7e2f7_row2_col1, #T_7e2f7_row2_col2, #T_7e2f7_row2_col3, #T_7e2f7_row2_col4, #T_7e2f7_row2_col5, #T_7e2f7_row3_col0, #T_7e2f7_row3_col1, #T_7e2f7_row3_col2, #T_7e2f7_row3_col3, #T_7e2f7_row3_col4, #T_7e2f7_row3_col5, #T_7e2f7_row4_col0, #T_7e2f7_row4_col1, #T_7e2f7_row4_col2, #T_7e2f7_row4_col3, #T_7e2f7_row4_col4, #T_7e2f7_row4_col5, #T_7e2f7_row5_col0, #T_7e2f7_row5_col1, #T_7e2f7_row5_col2, #T_7e2f7_row5_col3, #T_7e2f7_row5_col4, #T_7e2f7_row5_col5, #T_7e2f7_row6_col0, #T_7e2f7_row6_col1, #T_7e2f7_row6_col2, #T_7e2f7_row6_col3, #T_7e2f7_row6_col4, #T_7e2f7_row6_col5, #T_7e2f7_row7_col0, #T_7e2f7_row7_col1, #T_7e2f7_row7_col2, #T_7e2f7_row7_col3, #T_7e2f7_row7_col4, #T_7e2f7_row7_col5, #T_7e2f7_row8_col0, #T_7e2f7_row8_col1, #T_7e2f7_row8_col2, #T_7e2f7_row8_col3, #T_7e2f7_row8_col4, #T_7e2f7_row8_col5, #T_7e2f7_row9_col0, #T_7e2f7_row9_col1, #T_7e2f7_row9_col2, #T_7e2f7_row9_col3, #T_7e2f7_row9_col4, #T_7e2f7_row10_col0, #T_7e2f7_row10_col1, #T_7e2f7_row10_col2, #T_7e2f7_row10_col3, #T_7e2f7_row10_col4, #T_7e2f7_row10_col5, #T_7e2f7_row11_col0, #T_7e2f7_row11_col1, #T_7e2f7_row11_col2, #T_7e2f7_row11_col3, #T_7e2f7_row11_col4, #T_7e2f7_row11_col5, #T_7e2f7_row12_col0, #T_7e2f7_row12_col1, #T_7e2f7_row12_col2, #T_7e2f7_row12_col3, #T_7e2f7_row12_col4, #T_7e2f7_row12_col5, #T_7e2f7_row13_col0, #T_7e2f7_row13_col1, #T_7e2f7_row13_col2, #T_7e2f7_row13_col3, #T_7e2f7_row13_col4, #T_7e2f7_row13_col5, #T_7e2f7_row14_col0, #T_7e2f7_row14_col1, #T_7e2f7_row14_col2, #T_7e2f7_row14_col3, #T_7e2f7_row14_col4, #T_7e2f7_row14_col5, #T_7e2f7_row15_col0, #T_7e2f7_row15_col1, #T_7e2f7_row15_col2, #T_7e2f7_row15_col3, #T_7e2f7_row15_col4, #T_7e2f7_row15_col5, #T_7e2f7_row16_col0, #T_7e2f7_row16_col1, #T_7e2f7_row16_col2, #T_7e2f7_row16_col3, #T_7e2f7_row16_col4, #T_7e2f7_row16_col5, #T_7e2f7_row17_col0, #T_7e2f7_row17_col1, #T_7e2f7_row17_col2, #T_7e2f7_row17_col3, #T_7e2f7_row17_col4, #T_7e2f7_row17_col5, #T_7e2f7_row18_col0, #T_7e2f7_row18_col1, #T_7e2f7_row18_col2, #T_7e2f7_row18_col3, #T_7e2f7_row18_col4, #T_7e2f7_row18_col5, #T_7e2f7_row19_col0, #T_7e2f7_row19_col1, #T_7e2f7_row19_col2, #T_7e2f7_row19_col3, #T_7e2f7_row19_col4, #T_7e2f7_row19_col5, #T_7e2f7_row20_col0, #T_7e2f7_row20_col1, #T_7e2f7_row20_col2, #T_7e2f7_row20_col3, #T_7e2f7_row20_col4, #T_7e2f7_row21_col0, #T_7e2f7_row21_col1, #T_7e2f7_row21_col2, #T_7e2f7_row21_col3, #T_7e2f7_row21_col4, #T_7e2f7_row21_col5, #T_7e2f7_row22_col0, #T_7e2f7_row22_col1, #T_7e2f7_row22_col2, #T_7e2f7_row22_col3, #T_7e2f7_row22_col4, #T_7e2f7_row22_col5, #T_7e2f7_row23_col0, #T_7e2f7_row23_col1, #T_7e2f7_row23_col2, #T_7e2f7_row23_col3, #T_7e2f7_row23_col4, #T_7e2f7_row23_col5, #T_7e2f7_row24_col0, #T_7e2f7_row24_col1, #T_7e2f7_row24_col2, #T_7e2f7_row24_col3, #T_7e2f7_row24_col4, #T_7e2f7_row24_col5, #T_7e2f7_row25_col0, #T_7e2f7_row25_col1, #T_7e2f7_row25_col2, #T_7e2f7_row25_col3, #T_7e2f7_row25_col4, #T_7e2f7_row25_col5, #T_7e2f7_row26_col0, #T_7e2f7_row26_col1, #T_7e2f7_row26_col2, #T_7e2f7_row26_col3, #T_7e2f7_row26_col4, #T_7e2f7_row26_col5, #T_7e2f7_row27_col0, #T_7e2f7_row27_col1, #T_7e2f7_row27_col2, #T_7e2f7_row27_col3, #T_7e2f7_row27_col4, #T_7e2f7_row27_col5, #T_7e2f7_row28_col0, #T_7e2f7_row28_col1, #T_7e2f7_row28_col2, #T_7e2f7_row28_col3, #T_7e2f7_row28_col4, #T_7e2f7_row28_col5, #T_7e2f7_row29_col0, #T_7e2f7_row29_col1, #T_7e2f7_row29_col2, #T_7e2f7_row29_col3, #T_7e2f7_row29_col4, #T_7e2f7_row29_col5, #T_7e2f7_row30_col0, #T_7e2f7_row30_col1, #T_7e2f7_row30_col2, #T_7e2f7_row30_col3, #T_7e2f7_row30_col4, #T_7e2f7_row30_col5 {
#   color: green;
# }
# #T_7e2f7_row9_col5, #T_7e2f7_row20_col5 {
#   color: red;
# }
# </style>
# <table id="T_7e2f7" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7e2f7_level0_col0" class="col_heading level0 col0" >5 min</th>
#       <th id="T_7e2f7_level0_col1" class="col_heading level0 col1" >10 min</th>
#       <th id="T_7e2f7_level0_col2" class="col_heading level0 col2" >15 min</th>
#       <th id="T_7e2f7_level0_col3" class="col_heading level0 col3" >30 min</th>
#       <th id="T_7e2f7_level0_col4" class="col_heading level0 col4" >1 hour</th>
#       <th id="T_7e2f7_level0_col5" class="col_heading level0 col5" >1 day</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7e2f7_level0_row0" class="row_heading level0 row0" >AFKS</th>
#       <td id="T_7e2f7_row0_col0" class="data row0 col0" >0.14</td>
#       <td id="T_7e2f7_row0_col1" class="data row0 col1" >0.15</td>
#       <td id="T_7e2f7_row0_col2" class="data row0 col2" >0.17</td>
#       <td id="T_7e2f7_row0_col3" class="data row0 col3" >0.18</td>
#       <td id="T_7e2f7_row0_col4" class="data row0 col4" >0.17</td>
#       <td id="T_7e2f7_row0_col5" class="data row0 col5" >0.10</td>
#     </tr>
#     <tr>
#       <th id="T_7e2f7_level0_row1" class="row_heading level0 row1" >AFLT</th>
#       <td id="T_7e2f7_row1_col0" class="data row1 col0" >0.15</td>
#       <td id="T_7e2f7_row1_col1" class="data row1 col1" >0.13</td>
#       <td id="T_7e2f7_row1_col2" class="data row1 col2" >0.17</td>
#       <td id="T_7e2f7_row1_col3" class="data row1 col3" >0.19</td>
#       <td id="T_7e2f7_row1_col4" class="data row1 col4" >0.18</td>
#       <td id="T_7e2f7_row1_col5" class="data row1 col5" >0.16</td>
#     </tr>
#     <tr>
#       <th id="T_7e2f7_level0_row2" class="row_heading level0 row2" >ALRS</th>
#       <td id="T_7e2f7_row2_col0" class="data row2 col0" >0.06</td>
#       <td id="T_7e2f7_row2_col1" class="data row2 col1" >0.21</td>
#       <td id="T_7e2f7_row2_col2" class="data row2 col2" >0.20</td>
#       <td id="T_7e2f7_row2_col3" class="data row2 col3" >0.24</td>
#       <td id="T_7e2f7_row2_col4" class="data row2 col4" >0.24</td>
#       <td id="T_7e2f7_row2_col5" class="data row2 col5" >0.19</td>
#     </tr>
#     <tr>
#       <th id="T_7e2f7_level0_row3" class="row_heading level0 row3" >CBOM</th>
#       <td id="T_7e2f7_row3_col0" class="data row3 col0" >0.11</td>
#       <td id="T_7e2f7_row3_col1" class="data row3 col1" >0.15</td>
#       <td id="T_7e2f7_row3_col2" class="data row3 col2" >0.20</td>
#       <td id="T_7e2f7_row3_col3" class="data row3 col3" >0.22</td>
#       <td id="T_7e2f7_row3_col4" class="data row3 col4" >0.27</td>
#       <td id="T_7e2f7_row3_col5" class="data row3 col5" >0.15</td>
#     </tr>
#     <tr>
#       <th id="T_7e2f7_level0_row4" class="row_heading level0 row4" >CHMF</th>
#       <td id="T_7e2f7_row4_col0" class="data row4 col0" >0.06</td>
#       <td id="T_7e2f7_row4_col1" class="data row4 col1" >0.26</td>
#       <td id="T_7e2f7_row4_col2" class="data row4 col2" >0.29</td>
#       <td id="T_7e2f7_row4_col3" class="data row4 col3" >0.26</td>
#       <td id="T_7e2f7_row4_col4" class="data row4 col4" >0.26</td>
#       <td id="T_7e2f7_row4_col5" class="data row4 col5" >0.13</td>
#     </tr>
#     <tr>
#       <th id="T_7e2f7_level0_row5" class="row_heading level0 row5" >DSKY</th>
#       <td id="T_7e2f7_row5_col0" class="data row5 col0" >0.26</td>
#       <td id="T_7e2f7_row5_col1" class="data row5 col1" >0.33</td>
#       <td id="T_7e2f7_row5_col2" class="data row5 col2" >0.35</td>
#       <td id="T_7e2f7_row5_col3" class="data row5 col3" >0.41</td>
#       <td id="T_7e2f7_row5_col4" class="data row5 col4" >0.38</td>
#       <td id="T_7e2f7_row5_col5" class="data row5 col5" >0.20</td>
#     </tr>
#     <tr>
#       <th id="T_7e2f7_level0_row6" class="row_heading level0 row6" >FEES</th>
#       <td id="T_7e2f7_row6_col0" class="data row6 col0" >0.09</td>
#       <td id="T_7e2f7_row6_col1" class="data row6 col1" >0.10</td>
#       <td id="T_7e2f7_row6_col2" class="data row6 col2" >0.15</td>
#       <td id="T_7e2f7_row6_col3" class="data row6 col3" >0.12</td>
#       <td id="T_7e2f7_row6_col4" class="data row6 col4" >0.18</td>
#       <td id="T_7e2f7_row6_col5" class="data row6 col5" >0

# %%
effects_neutral_tg_zero_boosting.mean()
# Out:
# 5 min     0.123813
# 10 min    0.166759
# 15 min    0.175258
# 30 min    0.189400
# 1 hour    0.193876
# 1 day     0.106521
# dtype: float64

# %% [markdown]
# ### Кросс-валидация традиционные новости

# %%
companies = ['ALRS', 'AFLT', 'VTBR', 'GAZP', 'GMKN', 'LSRG', 'DSKY', 'IRAO', 'LKOH', 'MAGN', 'MOEX', 'CBOM', 'MTSS',
             'ROSN', 'NVTK', 'PIKK', 'RTKM', 'RUAL', 'HYDR', 'SBER', 'CHMF', 'AFKS', 'SNGS', 'TATN',
             'TCSG', 'TRNFP', 'PHOR', 'YNDX']

# %% [markdown]
# #### 2 класса

# %%
news = pd.read_parquet('/content/drive/MyDrive/Диссертация/Парсеры сайтов/news_comps.parquet')
news_train = news[news.date < '2021-06-01'].copy()
news_test = news[(news.date < '2022-01-01') & (news.date > '2021-06-01')].copy()

# %%
loggs = pd.read_csv('/content/drive/MyDrive/Диссертация/news_loggs/loggs_news_rf_bin.csv', index_col=0)

# %%
effects_news_rf_cv = get_effects_bin(news_train, news_test, loggs, companies=companies)

# %%
effects_news_rf_cv.sort_index().style.applymap(_color_red_or_green).format(precision=2)
# Out:
# <style type="text/css">
# #T_baf11_row0_col0, #T_baf11_row0_col1, #T_baf11_row0_col2, #T_baf11_row0_col3, #T_baf11_row0_col4, #T_baf11_row0_col5, #T_baf11_row0_col6, #T_baf11_row1_col1, #T_baf11_row1_col2, #T_baf11_row1_col3, #T_baf11_row1_col4, #T_baf11_row1_col5, #T_baf11_row1_col6, #T_baf11_row2_col1, #T_baf11_row2_col2, #T_baf11_row2_col4, #T_baf11_row2_col5, #T_baf11_row3_col0, #T_baf11_row3_col1, #T_baf11_row3_col2, #T_baf11_row3_col4, #T_baf11_row3_col5, #T_baf11_row3_col6, #T_baf11_row4_col0, #T_baf11_row4_col3, #T_baf11_row4_col4, #T_baf11_row4_col6, #T_baf11_row5_col0, #T_baf11_row5_col1, #T_baf11_row5_col2, #T_baf11_row5_col4, #T_baf11_row5_col5, #T_baf11_row7_col0, #T_baf11_row7_col1, #T_baf11_row7_col2, #T_baf11_row7_col3, #T_baf11_row7_col4, #T_baf11_row7_col5, #T_baf11_row7_col6, #T_baf11_row8_col0, #T_baf11_row8_col1, #T_baf11_row8_col2, #T_baf11_row8_col3, #T_baf11_row8_col4, #T_baf11_row8_col5, #T_baf11_row8_col6, #T_baf11_row9_col0, #T_baf11_row9_col1, #T_baf11_row9_col2, #T_baf11_row9_col3, #T_baf11_row9_col6, #T_baf11_row10_col0, #T_baf11_row10_col1, #T_baf11_row10_col2, #T_baf11_row10_col3, #T_baf11_row10_col4, #T_baf11_row10_col5, #T_baf11_row10_col6, #T_baf11_row11_col0, #T_baf11_row11_col2, #T_baf11_row11_col3, #T_baf11_row11_col4, #T_baf11_row11_col5, #T_baf11_row11_col6, #T_baf11_row12_col0, #T_baf11_row12_col1, #T_baf11_row12_col2, #T_baf11_row12_col3, #T_baf11_row12_col4, #T_baf11_row12_col6, #T_baf11_row13_col3, #T_baf11_row13_col4, #T_baf11_row13_col5, #T_baf11_row13_col6, #T_baf11_row14_col1, #T_baf11_row14_col3, #T_baf11_row14_col5, #T_baf11_row14_col6, #T_baf11_row15_col1, #T_baf11_row15_col2, #T_baf11_row15_col4, #T_baf11_row15_col6, #T_baf11_row16_col0, #T_baf11_row16_col1, #T_baf11_row16_col2, #T_baf11_row16_col5, #T_baf11_row16_col6, #T_baf11_row17_col1, #T_baf11_row17_col2, #T_baf11_row17_col4, #T_baf11_row17_col5, #T_baf11_row18_col0, #T_baf11_row18_col3, #T_baf11_row18_col5, #T_baf11_row19_col0, #T_baf11_row19_col1, #T_baf11_row19_col2, #T_baf11_row19_col3, #T_baf11_row19_col4, #T_baf11_row19_col5, #T_baf11_row19_col6, #T_baf11_row20_col0, #T_baf11_row20_col1, #T_baf11_row20_col2, #T_baf11_row20_col3, #T_baf11_row20_col4, #T_baf11_row20_col5, #T_baf11_row20_col6, #T_baf11_row21_col0, #T_baf11_row21_col1, #T_baf11_row21_col2, #T_baf11_row21_col3, #T_baf11_row21_col4, #T_baf11_row21_col5, #T_baf11_row21_col6, #T_baf11_row22_col0, #T_baf11_row22_col1, #T_baf11_row22_col2, #T_baf11_row22_col3, #T_baf11_row22_col5, #T_baf11_row22_col6, #T_baf11_row23_col0, #T_baf11_row23_col1, #T_baf11_row23_col2, #T_baf11_row23_col3, #T_baf11_row23_col4, #T_baf11_row23_col5, #T_baf11_row24_col4, #T_baf11_row24_col6, #T_baf11_row25_col1, #T_baf11_row25_col2, #T_baf11_row25_col3, #T_baf11_row25_col4, #T_baf11_row25_col5, #T_baf11_row25_col6, #T_baf11_row26_col6, #T_baf11_row27_col0, #T_baf11_row27_col1, #T_baf11_row27_col2, #T_baf11_row27_col4, #T_baf11_row27_col6 {
#   color: red;
# }
# #T_baf11_row1_col0, #T_baf11_row2_col0, #T_baf11_row2_col3, #T_baf11_row2_col6, #T_baf11_row3_col3, #T_baf11_row4_col1, #T_baf11_row4_col2, #T_baf11_row4_col5, #T_baf11_row5_col3, #T_baf11_row5_col6, #T_baf11_row6_col0, #T_baf11_row6_col1, #T_baf11_row6_col2, #T_baf11_row6_col3, #T_baf11_row6_col4, #T_baf11_row6_col5, #T_baf11_row6_col6, #T_baf11_row9_col4, #T_baf11_row9_col5, #T_baf11_row11_col1, #T_baf11_row12_col5, #T_baf11_row13_col0, #T_baf11_row13_col1, #T_baf11_row13_col2, #T_baf11_row14_col0, #T_baf11_row14_col2, #T_baf11_row14_col4, #T_baf11_row15_col0, #T_baf11_row15_col3, #T_baf11_row15_col5, #T_baf11_row16_col3, #T_baf11_row16_col4, #T_baf11_row17_col0, #T_baf11_row17_col3, #T_baf11_row17_col6, #T_baf11_row18_col1, #T_baf11_row18_col2, #T_baf11_row18_col4, #T_baf11_row18_col6, #T_baf11_row22_col4, #T_baf11_row23_col6, #T_baf11_row24_col0, #T_baf11_row24_col1, #T_baf11_row24_col2, #T_baf11_row24_col3, #T_baf11_row24_col5, #T_baf11_row25_col0, #T_baf11_row26_col0, #T_baf11_row26_col1, #T_baf11_row26_col2, #T_baf11_row26_col3, #T_baf11_row26_col4, #T_baf11_row26_col5, #T_baf11_row27_col3, #T_baf11_row27_col5 {
#   color: green;
# }
# </style>
# <table id="T_baf11" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_baf11_level0_col0" class="col_heading level0 col0" >1 min</th>
#       <th id="T_baf11_level0_col1" class="col_heading level0 col1" >5 min</th>
#       <th id="T_baf11_level0_col2" class="col_heading level0 col2" >10 min</th>
#       <th id="T_baf11_level0_col3" class="col_heading level0 col3" >15 min</th>
#       <th id="T_baf11_level0_col4" class="col_heading level0 col4" >30 min</th>
#       <th id="T_baf11_level0_col5" class="col_heading level0 col5" >1 hour</th>
#       <th id="T_baf11_level0_col6" class="col_heading level0 col6" >1 day</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_baf11_level0_row0" class="row_heading level0 row0" >AFKS</th>
#       <td id="T_baf11_row0_col0" class="data row0 col0" >-12.54</td>
#       <td id="T_baf11_row0_col1" class="data row0 col1" >-9.56</td>
#       <td id="T_baf11_row0_col2" class="data row0 col2" >-4.19</td>
#       <td id="T_baf11_row0_col3" class="data row0 col3" >-8.09</td>
#       <td id="T_baf11_row0_col4" class="data row0 col4" >-4.24</td>
#       <td id="T_baf11_row0_col5" class="data row0 col5" >-14.59</td>
#       <td id="T_baf11_row0_col6" class="data row0 col6" >-19.86</td>
#     </tr>
#     <tr>
#       <th id="T_baf11_level0_row1" class="row_heading level0 row1" >AFLT</th>
#       <td id="T_baf11_row1_col0" class="data row1 col0" >3.09</td>
#       <td id="T_baf11_row1_col1" class="data row1 col1" >-1.82</td>
#       <td id="T_baf11_row1_col2" class="data row1 col2" >-4.04</td>
#       <td id="T_baf11_row1_col3" class="data row1 col3" >-10.29</td>
#       <td id="T_baf11_row1_col4" class="data row1 col4" >-4.56</td>
#       <td id="T_baf11_row1_col5" class="data row1 col5" >-4.59</td>
#       <td id="T_baf11_row1_col6" class="data row1 col6" >-1.03</td>
#     </tr>
#     <tr>
#       <th id="T_baf11_level0_row2" class="row_heading level0 row2" >ALRS</th>
#       <td id="T_baf11_row2_col0" class="data row2 col0" >4.15</td>
#       <td id="T_baf11_row2_col1" class="data row2 col1" >-1.33</td>
#       <td id="T_baf11_row2_col2" class="data row2 col2" >-3.60</td>
#       <td id="T_baf11_row2_col3" class="data row2 col3" >1.56</td>
#       <td id="T_baf11_row2_col4" class="data row2 col4" >-4.61</td>
#       <td id="T_baf11_row2_col5" class="data row2 col5" >-4.72</td>
#       <td id="T_baf11_row2_col6" class="data row2 col6" >3.77</td>
#     </tr>
#     <tr>
#       <th id="T_baf11_level0_row3" class="row_heading level0 row3" >CBOM</th>
#       <td id="T_baf11_row3_col0" class="data row3 col0" >-0.14</td>
#       <td id="T_baf11_row3_col1" class="data row3 col1" >-5.00</td>
#       <td id="T_baf11_row3_col2" class="data row3 col2" >-0.83</td>
#       <td id="T_baf11_row3_col3" class="data row3 col3" >1.57</td>
#       <td id="T_baf11_row3_col4" class="data row3 col4" >-7.50</td>
#       <td id="T_baf11_row3_col5" class="data row3 col5" >-2.83</td>
#       <td id="T_baf11_row3_col6" class="data row3 col6" >-7.50</td>
#     </tr>
#     <tr>
#       <th id="T_baf11_level0_row4" class="row_heading level0 row4" >CHMF</th>
#       <td id="T_baf11_row4_col0" class="data row4 col0" >-3.56</td>
#       <td id="T_baf11_row4_col1" class="data row4 col1" >3.63</td>
#       <td id="T_baf11_row4_col2" class="data row4 col2" >6.38</td>
#       <td id="T_baf11_row4_col3" class="data row4 col3" >-1.32</td>
#       <td id="T_baf11_row4_col4" class="data row4 col4" >-1.36</td>
#       <td id="T_baf11_row4_col5" class="data row4 col5" >2.28</td>
#       <td id="T_baf11_row4_col6" class="data row4 col6" >-10.07</td>
#     </tr>
#     <tr>
#       <th id="T_baf11_level0_row5" class="row_heading level0 row5" >DSKY</th>
#       <td id="T_baf11_row5_col0" class="data row5 col0" >-28.00</td>
#       <td id="T_baf11_row5_col1" class="data row5 col1" >-32.07</td>
#       <td id="T_baf11_row5_col2" class="data row5 col2" >-15.05</td>
#       <td id="T_baf11_row5_col3" class=

# %%
effects_news_rf_cv.filter(['GAZP', 'TCSG', 'VTBR'], axis=0).sort_index().style.applymap(_color_red_or_green).format(precision=2)
# Out:
# <style type="text/css">
# #T_c2bde_row0_col0, #T_c2bde_row0_col1, #T_c2bde_row0_col2, #T_c2bde_row0_col3, #T_c2bde_row0_col4, #T_c2bde_row0_col5, #T_c2bde_row0_col6, #T_c2bde_row1_col0, #T_c2bde_row1_col1, #T_c2bde_row1_col2, #T_c2bde_row1_col3, #T_c2bde_row1_col5, #T_c2bde_row2_col0, #T_c2bde_row2_col1, #T_c2bde_row2_col2, #T_c2bde_row2_col3, #T_c2bde_row2_col4, #T_c2bde_row2_col5 {
#   color: green;
# }
# #T_c2bde_row1_col4, #T_c2bde_row1_col6, #T_c2bde_row2_col6 {
#   color: red;
# }
# </style>
# <table id="T_c2bde" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c2bde_level0_col0" class="col_heading level0 col0" >1 min</th>
#       <th id="T_c2bde_level0_col1" class="col_heading level0 col1" >5 min</th>
#       <th id="T_c2bde_level0_col2" class="col_heading level0 col2" >10 min</th>
#       <th id="T_c2bde_level0_col3" class="col_heading level0 col3" >15 min</th>
#       <th id="T_c2bde_level0_col4" class="col_heading level0 col4" >30 min</th>
#       <th id="T_c2bde_level0_col5" class="col_heading level0 col5" >1 hour</th>
#       <th id="T_c2bde_level0_col6" class="col_heading level0 col6" >1 day</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c2bde_level0_row0" class="row_heading level0 row0" >GAZP</th>
#       <td id="T_c2bde_row0_col0" class="data row0 col0" >1.66</td>
#       <td id="T_c2bde_row0_col1" class="data row0 col1" >4.49</td>
#       <td id="T_c2bde_row0_col2" class="data row0 col2" >3.71</td>
#       <td id="T_c2bde_row0_col3" class="data row0 col3" >4.82</td>
#       <td id="T_c2bde_row0_col4" class="data row0 col4" >3.88</td>
#       <td id="T_c2bde_row0_col5" class="data row0 col5" >3.35</td>
#       <td id="T_c2bde_row0_col6" class="data row0 col6" >3.11</td>
#     </tr>
#     <tr>
#       <th id="T_c2bde_level0_row1" class="row_heading level0 row1" >TCSG</th>
#       <td id="T_c2bde_row1_col0" class="data row1 col0" >4.80</td>
#       <td id="T_c2bde_row1_col1" class="data row1 col1" >8.93</td>
#       <td id="T_c2bde_row1_col2" class="data row1 col2" >7.44</td>
#       <td id="T_c2bde_row1_col3" class="data row1 col3" >0.71</td>
#       <td id="T_c2bde_row1_col4" class="data row1 col4" >-3.88</td>
#       <td id="T_c2bde_row1_col5" class="data row1 col5" >1.22</td>
#       <td id="T_c2bde_row1_col6" class="data row1 col6" >-2.19</td>
#     </tr>
#     <tr>
#       <th id="T_c2bde_level0_row2" class="row_heading level0 row2" >VTBR</th>
#       <td id="T_c2bde_row2_col0" class="data row2 col0" >5.74</td>
#       <td id="T_c2bde_row2_col1" class="data row2 col1" >0.52</td>
#       <td id="T_c2bde_row2_col2" class="data row2 col2" >1.68</td>
#       <td id="T_c2bde_row2_col3" class="data row2 col3" >1.07</td>
#       <td id="T_c2bde_row2_col4" class="data row2 col4" >0.99</td>
#       <td id="T_c2bde_row2_col5" class="data row2 col5" >1.74</td>
#       <td id="T_c2bde_row2_col6" class="data row2 col6" >-0.27</td>
#     </tr>
#   </tbody>
# </table>

# %%
effects_news_rf_cv.mean()
# Out:
# 1 min    -4.558571
# 5 min    -3.799643
# 10 min   -4.447857
# 15 min   -4.815000
# 30 min   -3.686429
# 1 hour   -5.552857
# 1 day    -7.297500
# dtype: float64

# %%
loggs = pd.read_csv('/content/drive/MyDrive/Диссертация/news_loggs/loggs_news_boosting_bin.csv', index_col=0)

# %%
effects_news_boosting_cv = get_effects_bin(news_train, news_test, loggs, companies=companies)

# %%
effects_news_boosting_cv.sort_index().style.applymap(_color_red_or_green).format(precision=2)
# Out:
# <style type="text/css">
# #T_2e023_row0_col0, #T_2e023_row0_col1, #T_2e023_row0_col2, #T_2e023_row0_col3, #T_2e023_row0_col4, #T_2e023_row0_col5, #T_2e023_row0_col6, #T_2e023_row1_col1, #T_2e023_row1_col2, #T_2e023_row1_col3, #T_2e023_row1_col4, #T_2e023_row1_col5, #T_2e023_row2_col0, #T_2e023_row2_col1, #T_2e023_row2_col2, #T_2e023_row2_col3, #T_2e023_row2_col4, #T_2e023_row3_col0, #T_2e023_row3_col1, #T_2e023_row3_col2, #T_2e023_row3_col3, #T_2e023_row3_col4, #T_2e023_row3_col5, #T_2e023_row4_col0, #T_2e023_row4_col3, #T_2e023_row4_col4, #T_2e023_row4_col5, #T_2e023_row5_col1, #T_2e023_row5_col2, #T_2e023_row5_col3, #T_2e023_row5_col4, #T_2e023_row5_col5, #T_2e023_row5_col6, #T_2e023_row6_col4, #T_2e023_row7_col0, #T_2e023_row7_col1, #T_2e023_row7_col2, #T_2e023_row7_col3, #T_2e023_row7_col4, #T_2e023_row7_col5, #T_2e023_row7_col6, #T_2e023_row8_col0, #T_2e023_row8_col1, #T_2e023_row8_col2, #T_2e023_row8_col3, #T_2e023_row8_col4, #T_2e023_row8_col5, #T_2e023_row8_col6, #T_2e023_row9_col0, #T_2e023_row9_col1, #T_2e023_row9_col2, #T_2e023_row9_col3, #T_2e023_row9_col6, #T_2e023_row10_col0, #T_2e023_row10_col1, #T_2e023_row10_col2, #T_2e023_row10_col3, #T_2e023_row10_col4, #T_2e023_row10_col5, #T_2e023_row10_col6, #T_2e023_row11_col0, #T_2e023_row11_col1, #T_2e023_row11_col2, #T_2e023_row11_col3, #T_2e023_row11_col4, #T_2e023_row11_col5, #T_2e023_row11_col6, #T_2e023_row12_col0, #T_2e023_row12_col1, #T_2e023_row12_col2, #T_2e023_row12_col3, #T_2e023_row12_col6, #T_2e023_row13_col1, #T_2e023_row13_col2, #T_2e023_row13_col3, #T_2e023_row13_col4, #T_2e023_row13_col5, #T_2e023_row13_col6, #T_2e023_row14_col0, #T_2e023_row14_col1, #T_2e023_row14_col2, #T_2e023_row14_col3, #T_2e023_row14_col4, #T_2e023_row14_col5, #T_2e023_row14_col6, #T_2e023_row15_col0, #T_2e023_row15_col1, #T_2e023_row15_col2, #T_2e023_row15_col3, #T_2e023_row15_col4, #T_2e023_row15_col5, #T_2e023_row15_col6, #T_2e023_row16_col1, #T_2e023_row16_col2, #T_2e023_row16_col3, #T_2e023_row16_col5, #T_2e023_row16_col6, #T_2e023_row17_col0, #T_2e023_row17_col1, #T_2e023_row17_col3, #T_2e023_row17_col4, #T_2e023_row17_col5, #T_2e023_row18_col0, #T_2e023_row18_col1, #T_2e023_row19_col0, #T_2e023_row19_col1, #T_2e023_row19_col2, #T_2e023_row19_col3, #T_2e023_row19_col4, #T_2e023_row19_col5, #T_2e023_row19_col6, #T_2e023_row20_col0, #T_2e023_row20_col1, #T_2e023_row20_col3, #T_2e023_row20_col5, #T_2e023_row20_col6, #T_2e023_row21_col0, #T_2e023_row21_col1, #T_2e023_row21_col2, #T_2e023_row21_col3, #T_2e023_row21_col4, #T_2e023_row21_col5, #T_2e023_row21_col6, #T_2e023_row22_col0, #T_2e023_row22_col1, #T_2e023_row22_col2, #T_2e023_row22_col5, #T_2e023_row22_col6, #T_2e023_row23_col0, #T_2e023_row23_col1, #T_2e023_row23_col2, #T_2e023_row23_col3, #T_2e023_row23_col4, #T_2e023_row23_col5, #T_2e023_row24_col0, #T_2e023_row24_col1, #T_2e023_row24_col2, #T_2e023_row24_col3, #T_2e023_row24_col6, #T_2e023_row25_col2, #T_2e023_row25_col3, #T_2e023_row25_col4, #T_2e023_row25_col5, #T_2e023_row25_col6, #T_2e023_row26_col4, #T_2e023_row26_col5, #T_2e023_row26_col6, #T_2e023_row27_col0, #T_2e023_row27_col1, #T_2e023_row27_col2, #T_2e023_row27_col4, #T_2e023_row27_col6 {
#   color: red;
# }
# #T_2e023_row1_col0, #T_2e023_row1_col6, #T_2e023_row2_col5, #T_2e023_row2_col6, #T_2e023_row3_col6, #T_2e023_row4_col1, #T_2e023_row4_col2, #T_2e023_row4_col6, #T_2e023_row5_col0, #T_2e023_row6_col0, #T_2e023_row6_col1, #T_2e023_row6_col2, #T_2e023_row6_col3, #T_2e023_row6_col5, #T_2e023_row6_col6, #T_2e023_row9_col4, #T_2e023_row9_col5, #T_2e023_row12_col4, #T_2e023_row12_col5, #T_2e023_row13_col0, #T_2e023_row16_col0, #T_2e023_row16_col4, #T_2e023_row17_col2, #T_2e023_row17_col6, #T_2e023_row18_col2, #T_2e023_row18_col3, #T_2e023_row18_col4, #T_2e023_row18_col5, #T_2e023_row18_col6, #T_2e023_row20_col2, #T_2e023_row20_col4, #T_2e023_row22_col3, #T_2e023_row22_col4, #T_2e023_row23_col6, #T_2e023_row24_col4, #T_2e023_row24_col5, #T_2e023_row25_col0, #T_2e023_row25_col1, #T_2e023_row26_col0, #T_2e023_row26_col1, #T_2e023_row26_col2, #T_2e023_row26_col3, #T_2e023_row27_col3, #T_2e023_row27_col5 {
#   color: green;
# }
# </style>
# <table id="T_2e023" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2e023_level0_col0" class="col_heading level0 col0" >1 min</th>
#       <th id="T_2e023_level0_col1" class="col_heading level0 col1" >5 min</th>
#       <th id="T_2e023_level0_col2" class="col_heading level0 col2" >10 min</th>
#       <th id="T_2e023_level0_col3" class="col_heading level0 col3" >15 min</th>
#       <th id="T_2e023_level0_col4" class="col_heading level0 col4" >30 min</th>
#       <th id="T_2e023_level0_col5" class="col_heading level0 col5" >1 hour</th>
#       <th id="T_2e023_level0_col6" class="col_heading level0 col6" >1 day</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2e023_level0_row0" class="row_heading level0 row0" >AFKS</th>
#       <td id="T_2e023_row0_col0" class="data row0 col0" >-1.89</td>
#       <td id="T_2e023_row0_col1" class="data row0 col1" >-6.81</td>
#       <td id="T_2e023_row0_col2" class="data row0 col2" >-2.09</td>
#       <td id="T_2e023_row0_col3" class="data row0 col3" >-2.91</td>
#       <td id="T_2e023_row0_col4" class="data row0 col4" >-10.34</td>
#       <td id="T_2e023_row0_col5" class="data row0 col5" >-7.86</td>
#       <td id="T_2e023_row0_col6" class="data row0 col6" >-10.26</td>
#     </tr>
#     <tr>
#       <th id="T_2e023_level0_row1" class="row_heading level0 row1" >AFLT</th>
#       <td id="T_2e023_row1_col0" class="data row1 col0" >2.65</td>
#       <td id="T_2e023_row1_col1" class="data row1 col1" >-1.38</td>
#       <td id="T_2e023_row1_col2" class="data row1 col2" >-4.42</td>
#       <td id="T_2e023_row1_col3" class="data row1 col3" >-3.61</td>
#       <td id="T_2e023_row1_col4" class="data row1 col4" >-10.37</td>
#       <td id="T_2e023_row1_col5" class="data row1 col5" >-6.07</td>
#       <td id="T_2e023_row1_col6" class="data row1 col6" >0.93</td>
#     </tr>
#     <tr>
#       <th id="T_2e023_level0_row2" class="row_heading level0 row2" >ALRS</th>
#       <td id="T_2e023_row2_col0" class="data row2 col0" >-13.24</td>
#       <td id="T_2e023_row2_col1" class="data row2 col1" >-18.27</td>
#       <td id="T_2e023_row2_col2" class="data row2 col2" >-18.05</td>
#       <td id="T_2e023_row2_col3" class="data row2 col3" >-21.09</td>
#       <td id="T_2e023_row2_col4" class="data row2 col4" >-25.05</td>
#       <td id="T_2e023_row2_col5" class="data row2 col5" >1.06</td>
#       <td id="T_2e023_row2_col6" class="data row2 col6" >1.35</td>
#     </tr>
#     <tr>
#       <th id="T_2e023_level0_row3" class="row_heading level0 row3" >CBOM</th>
#       <td id="T_2e023_row3_col0" class="data row3 col0" >-4.07</td>
#       <td id="T_2e023_row3_col1" class="data row3 col1" >-8.44</td>
#       <td id="T_2e023_row3_col2" class="data row3 col2" >-1.25</td>
#       <td id="T_2e023_row3_col3" class="data row3 col3" >-4.82</td>
#       <td id="T_2e023_row3_col4" class="data row3 col4" >-5.25</td>
#       <td id="T_2e023_row3_col5" class="data row3 col5" >-10.21</td>
#       <td id="T_2e023_row3_col6" class="data row3 col6" >3.93</td>
#     </tr>
#     <tr>
#       <th id="T_2e023_level0_row4" class="row_heading level0 row4" >CHMF</th>
#       <td id="T_2e023_row4_col0" class="data row4 col0" >-1.74</td>
#       <td id="T_2e023_row4_col1" class="data row4 col1" >3.72</td>
#       <td id="T_2e023_row4_col2" class="data row4 col2" >4.06</td>
#       <td id="T_2e023_row4_col3" class="data row4 col3" >-2.42</td>
#       <td id="T_2e023_row4_col4" class="data row4 col4" >-5.80</td>
#       <td id="T_2e023_row4_col5" class="data row4 col5" >-4.47</td>
#       <td id="T_2e023_row4_col6" class="data row4 col6" >2.13</td>
#     </tr>
#     <tr>
#       <th id="T_2e023_level0_row5" class="row_heading level0 row5" >DSKY</th>
#       <td id="T_2e023_row5_col0" class="data row5 col0" >2.30</td>
#       <td id="T_2e023_row5_col1" class="data row5 col1" >-8.53</td>
#       <td id="T_2e023_row5_col2" class="data row5 col2" >-7.75</td>
#       <td id="T_2e023_row5_col3" class=

# %%
effects_news_boosting_cv.mean()
# Out:
# 1 min    -5.684286
# 5 min    -5.639643
# 10 min   -6.119643
# 15 min   -6.228214
# 30 min   -4.814286
# 1 hour   -5.713571
# 1 day    -5.465000
# dtype: float64

# %% [markdown]
# #### 3 класса

# %%
companies = ['ALRS', 'AFLT', 'VTBR', 'GAZP', 'GMKN', 'DSKY', 'IRAO', 'LKOH', 'MAGN', 'MOEX', 'CBOM', 'MTSS',
             'ROSN', 'NVTK', 'PIKK', 'RTKM', 'RUAL', 'HYDR', 'SBER', 'CHMF', 'AFKS', 'SNGS', 'TATN',
             'TCSG', 'TRNFP', 'PHOR', 'YNDX']

# %%
news = pd.read_parquet('/content/drive/MyDrive/Диссертация/Парсеры сайтов/news_comps_1,5sigma_.parquet')
news_train = news[news.date < '2021-06-01'].copy()
news_test = news[(news.date < '2022-01-01') & (news.date > '2021-06-01')].copy()

# %%
loggs = pd.read_csv('/content/drive/MyDrive/Диссертация/news_loggs/loggs_news_rf_neutral.csv', index_col=0)

# %%
effects_neutral_news_rand_rf, effects_neutral_news_zero_rf = get_effects_neutral(news_train, news_test, loggs, companies=companies)

# %%
effects_neutral_news_rand_rf.sort_index().style.applymap(_color_red_or_green).format(precision=2)
# Out:
# <style type="text/css">
# #T_e8c28_row0_col0, #T_e8c28_row0_col1, #T_e8c28_row0_col2, #T_e8c28_row0_col3, #T_e8c28_row0_col4, #T_e8c28_row0_col5, #T_e8c28_row1_col0, #T_e8c28_row1_col1, #T_e8c28_row1_col2, #T_e8c28_row1_col5, #T_e8c28_row2_col1, #T_e8c28_row2_col2, #T_e8c28_row2_col5, #T_e8c28_row3_col1, #T_e8c28_row3_col2, #T_e8c28_row3_col3, #T_e8c28_row3_col4, #T_e8c28_row3_col5, #T_e8c28_row4_col0, #T_e8c28_row4_col1, #T_e8c28_row4_col3, #T_e8c28_row4_col4, #T_e8c28_row4_col5, #T_e8c28_row5_col0, #T_e8c28_row5_col1, #T_e8c28_row5_col2, #T_e8c28_row5_col4, #T_e8c28_row5_col5, #T_e8c28_row6_col4, #T_e8c28_row7_col1, #T_e8c28_row7_col2, #T_e8c28_row7_col3, #T_e8c28_row7_col4, #T_e8c28_row7_col5, #T_e8c28_row8_col0, #T_e8c28_row8_col1, #T_e8c28_row8_col2, #T_e8c28_row8_col3, #T_e8c28_row8_col4, #T_e8c28_row8_col5, #T_e8c28_row9_col0, #T_e8c28_row9_col1, #T_e8c28_row9_col2, #T_e8c28_row9_col3, #T_e8c28_row9_col4, #T_e8c28_row10_col0, #T_e8c28_row10_col1, #T_e8c28_row10_col4, #T_e8c28_row10_col5, #T_e8c28_row11_col0, #T_e8c28_row11_col1, #T_e8c28_row11_col2, #T_e8c28_row11_col3, #T_e8c28_row11_col4, #T_e8c28_row11_col5, #T_e8c28_row12_col0, #T_e8c28_row12_col1, #T_e8c28_row12_col2, #T_e8c28_row12_col3, #T_e8c28_row12_col5, #T_e8c28_row13_col5, #T_e8c28_row14_col0, #T_e8c28_row14_col1, #T_e8c28_row14_col3, #T_e8c28_row14_col4, #T_e8c28_row14_col5, #T_e8c28_row15_col1, #T_e8c28_row15_col2, #T_e8c28_row15_col3, #T_e8c28_row16_col0, #T_e8c28_row16_col1, #T_e8c28_row16_col2, #T_e8c28_row16_col3, #T_e8c28_row16_col4, #T_e8c28_row16_col5, #T_e8c28_row17_col0, #T_e8c28_row17_col1, #T_e8c28_row17_col2, #T_e8c28_row18_col0, #T_e8c28_row18_col5, #T_e8c28_row19_col2, #T_e8c28_row19_col3, #T_e8c28_row19_col4, #T_e8c28_row21_col0, #T_e8c28_row21_col2, #T_e8c28_row21_col3, #T_e8c28_row21_col4, #T_e8c28_row21_col5, #T_e8c28_row22_col0, #T_e8c28_row22_col1, #T_e8c28_row22_col2, #T_e8c28_row22_col3, #T_e8c28_row22_col4, #T_e8c28_row22_col5, #T_e8c28_row24_col1, #T_e8c28_row24_col3, #T_e8c28_row24_col4, #T_e8c28_row24_col5, #T_e8c28_row25_col5, #T_e8c28_row26_col5 {
#   color: red;
# }
# #T_e8c28_row1_col3, #T_e8c28_row1_col4, #T_e8c28_row2_col0, #T_e8c28_row2_col3, #T_e8c28_row2_col4, #T_e8c28_row3_col0, #T_e8c28_row4_col2, #T_e8c28_row5_col3, #T_e8c28_row6_col0, #T_e8c28_row6_col1, #T_e8c28_row6_col2, #T_e8c28_row6_col3, #T_e8c28_row6_col5, #T_e8c28_row7_col0, #T_e8c28_row9_col5, #T_e8c28_row10_col2, #T_e8c28_row10_col3, #T_e8c28_row12_col4, #T_e8c28_row13_col0, #T_e8c28_row13_col1, #T_e8c28_row13_col2, #T_e8c28_row13_col3, #T_e8c28_row13_col4, #T_e8c28_row14_col2, #T_e8c28_row15_col0, #T_e8c28_row15_col4, #T_e8c28_row15_col5, #T_e8c28_row17_col3, #T_e8c28_row17_col4, #T_e8c28_row17_col5, #T_e8c28_row18_col1, #T_e8c28_row18_col2, #T_e8c28_row18_col3, #T_e8c28_row18_col4, #T_e8c28_row19_col0, #T_e8c28_row19_col1, #T_e8c28_row19_col5, #T_e8c28_row20_col0, #T_e8c28_row20_col1, #T_e8c28_row20_col2, #T_e8c28_row20_col3, #T_e8c28_row20_col4, #T_e8c28_row20_col5, #T_e8c28_row21_col1, #T_e8c28_row23_col0, #T_e8c28_row23_col1, #T_e8c28_row23_col2, #T_e8c28_row23_col3, #T_e8c28_row23_col4, #T_e8c28_row23_col5, #T_e8c28_row24_col0, #T_e8c28_row24_col2, #T_e8c28_row25_col0, #T_e8c28_row25_col1, #T_e8c28_row25_col2, #T_e8c28_row25_col3, #T_e8c28_row25_col4, #T_e8c28_row26_col0, #T_e8c28_row26_col1, #T_e8c28_row26_col2, #T_e8c28_row26_col3, #T_e8c28_row26_col4 {
#   color: green;
# }
# </style>
# <table id="T_e8c28" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e8c28_level0_col0" class="col_heading level0 col0" >5 min</th>
#       <th id="T_e8c28_level0_col1" class="col_heading level0 col1" >10 min</th>
#       <th id="T_e8c28_level0_col2" class="col_heading level0 col2" >15 min</th>
#       <th id="T_e8c28_level0_col3" class="col_heading level0 col3" >30 min</th>
#       <th id="T_e8c28_level0_col4" class="col_heading level0 col4" >1 hour</th>
#       <th id="T_e8c28_level0_col5" class="col_heading level0 col5" >1 day</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e8c28_level0_row0" class="row_heading level0 row0" >AFKS</th>
#       <td id="T_e8c28_row0_col0" class="data row0 col0" >-16.27</td>
#       <td id="T_e8c28_row0_col1" class="data row0 col1" >-3.04</td>
#       <td id="T_e8c28_row0_col2" class="data row0 col2" >-12.33</td>
#       <td id="T_e8c28_row0_col3" class="data row0 col3" >-11.56</td>
#       <td id="T_e8c28_row0_col4" class="data row0 col4" >-4.21</td>
#       <td id="T_e8c28_row0_col5" class="data row0 col5" >-10.45</td>
#     </tr>
#     <tr>
#       <th id="T_e8c28_level0_row1" class="row_heading level0 row1" >AFLT</th>
#       <td id="T_e8c28_row1_col0" class="data row1 col0" >-6.10</td>
#       <td id="T_e8c28_row1_col1" class="data row1 col1" >-10.36</td>
#       <td id="T_e8c28_row1_col2" class="data row1 col2" >-2.97</td>
#       <td id="T_e8c28_row1_col3" class="data row1 col3" >2.04</td>
#       <td id="T_e8c28_row1_col4" class="data row1 col4" >1.31</td>
#       <td id="T_e8c28_row1_col5" class="data row1 col5" >-3.85</td>
#     </tr>
#     <tr>
#       <th id="T_e8c28_level0_row2" class="row_heading level0 row2" >ALRS</th>
#       <td id="T_e8c28_row2_col0" class="data row2 col0" >4.75</td>
#       <td id="T_e8c28_row2_col1" class="data row2 col1" >-13.27</td>
#       <td id="T_e8c28_row2_col2" class="data row2 col2" >-14.51</td>
#       <td id="T_e8c28_row2_col3" class="data row2 col3" >2.57</td>
#       <td id="T_e8c28_row2_col4" class="data row2 col4" >-0.00</td>
#       <td id="T_e8c28_row2_col5" class="data row2 col5" >-0.79</td>
#     </tr>
#     <tr>
#       <th id="T_e8c28_level0_row3" class="row_heading level0 row3" >CBOM</th>
#       <td id="T_e8c28_row3_col0" class="data row3 col0" >2.15</td>
#       <td id="T_e8c28_row3_col1" class="data row3 col1" >-2.37</td>
#       <td id="T_e8c28_row3_col2" class="data row3 col2" >-5.03</td>
#       <td id="T_e8c28_row3_col3" class="data row3 col3" >-9.32</td>
#       <td id="T_e8c28_row3_col4" class="data row3 col4" >-11.78</td>
#       <td id="T_e8c28_row3_col5" class="data row3 col5" >-5.64</td>
#     </tr>
#     <tr>
#       <th id="T_e8c28_level0_row4" class="row_heading level0 row4" >CHMF</th>
#       <td id="T_e8c28_row4_col0" class="data row4 col0" >-6.39</td>
#       <td id="T_e8c28_row4_col1" class="data row4 col1" >-0.34</td>
#       <td id="T_e8c28_row4_col2" class="data row4 col2" >1.34</td>
#       <td id="T_e8c28_row4_col3" class="data row4 col3" >-4.73</td>
#       <td id="T_e8c28_row4_col4" class="data row4 col4" >-3.02</td>
#       <td id="T_e8c28_row4_col5" class="data row4 col5" >-4.85</td>
#     </tr>
#     <tr>
#       <th id="T_e8c28_level0_row5" class="row_heading level0 row5" >DSKY</th>
#       <td id="T_e8c28_row5_col0" class="data row5 col0" >-19.69</td>
#       <td id="T_e8c28_row5_col1" class="data row5 col1" >-34.20</td>
#       <td id="T_e8c28_row5_col2" class="data row5 col2" >-9.42</td>
#       <td id="T_e8c28_row5_col3" class="data row5 col3" >6.39</td>
#       <td id="T_e8c28_row5_col4" class="data row5 col4" >-0.24</td>
#       <td id="T_e8c28_row5_col5" class="data row5 col5" >-23.96</td>
#     </tr>
#     <tr>
#       <th id="T_e8c28_level0_row6" class="row_heading level0 row6" >GAZP</th>
#       <td id="T_e8c28_row6_col0" class="data row6 col0" >2.58</td>
#       <td id="T_e8c28_row6_col1" class="data row6 col1" >6.15</td>
#       <td id="T_e8c28_row6_col2" class="data row6 col2" >6.30</td>
#       <td id="T_e8c28_row6_col3" class="data row6 col3" >6.36</td>
#       <td id="T_e8c28_row6_col4" class="data row6 col4" >-6.33</td>
#       <td id="T_e8c28_row6_col5" class="data row6 col5" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_e8c28_level0_row7" class="row_heading level0 row7" >GMKN</th>
#       <td id="T_e8c28_row7_col0" class="data row7 col0" >2.41</td>
#       <td id="T_e8c28_row7_col1" class="data row7 col1" >-10.69</td>
#       <td id="T_e8c28_row7_col2" class="data row7 col2" >-3.67</td>
#       <td id="T_e8c28_row7_col3" class="data row7 col3" >-2.41</td>
#       <td id="T_e8c28_row7_col4" class="data row7 col4" >-0.34</td>
#       <td id="T_e

# %%
effects_neutral_news_rand_rf.mean()
# Out:
# 5 min    -4.429259
# 10 min   -3.124815
# 15 min   -1.812222
# 30 min   -1.809259
# 1 hour   -1.610000
# 1 day    -6.300000
# dtype: float64

# %%
effects_neutral_news_rand_rf.filter(['GAZP', 'MTSS', 'RTKM', 'SBER', 'TCSG', 'VTBR', 'YNDX'], axis=0).sort_index().style.applymap(_color_red_or_green).format(precision=2)
# Out:
# <style type="text/css">
# #T_ccb23_row0_col0, #T_ccb23_row0_col1, #T_ccb23_row0_col2, #T_ccb23_row0_col3, #T_ccb23_row0_col5, #T_ccb23_row1_col0, #T_ccb23_row1_col1, #T_ccb23_row1_col2, #T_ccb23_row1_col3, #T_ccb23_row1_col4, #T_ccb23_row2_col1, #T_ccb23_row2_col2, #T_ccb23_row2_col3, #T_ccb23_row2_col4, #T_ccb23_row3_col0, #T_ccb23_row3_col1, #T_ccb23_row3_col2, #T_ccb23_row3_col3, #T_ccb23_row3_col4, #T_ccb23_row3_col5, #T_ccb23_row4_col0, #T_ccb23_row4_col1, #T_ccb23_row4_col2, #T_ccb23_row4_col3, #T_ccb23_row4_col4, #T_ccb23_row4_col5, #T_ccb23_row5_col0, #T_ccb23_row5_col1, #T_ccb23_row5_col2, #T_ccb23_row5_col3, #T_ccb23_row5_col4, #T_ccb23_row6_col0, #T_ccb23_row6_col1, #T_ccb23_row6_col2, #T_ccb23_row6_col3, #T_ccb23_row6_col4 {
#   color: green;
# }
# #T_ccb23_row0_col4, #T_ccb23_row1_col5, #T_ccb23_row2_col0, #T_ccb23_row2_col5, #T_ccb23_row5_col5, #T_ccb23_row6_col5 {
#   color: red;
# }
# </style>
# <table id="T_ccb23" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ccb23_level0_col0" class="col_heading level0 col0" >5 min</th>
#       <th id="T_ccb23_level0_col1" class="col_heading level0 col1" >10 min</th>
#       <th id="T_ccb23_level0_col2" class="col_heading level0 col2" >15 min</th>
#       <th id="T_ccb23_level0_col3" class="col_heading level0 col3" >30 min</th>
#       <th id="T_ccb23_level0_col4" class="col_heading level0 col4" >1 hour</th>
#       <th id="T_ccb23_level0_col5" class="col_heading level0 col5" >1 day</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ccb23_level0_row0" class="row_heading level0 row0" >GAZP</th>
#       <td id="T_ccb23_row0_col0" class="data row0 col0" >2.58</td>
#       <td id="T_ccb23_row0_col1" class="data row0 col1" >6.15</td>
#       <td id="T_ccb23_row0_col2" class="data row0 col2" >6.30</td>
#       <td id="T_ccb23_row0_col3" class="data row0 col3" >6.36</td>
#       <td id="T_ccb23_row0_col4" class="data row0 col4" >-6.33</td>
#       <td id="T_ccb23_row0_col5" class="data row0 col5" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_ccb23_level0_row1" class="row_heading level0 row1" >MTSS</th>
#       <td id="T_ccb23_row1_col0" class="data row1 col0" >5.83</td>
#       <td id="T_ccb23_row1_col1" class="data row1 col1" >0.59</td>
#       <td id="T_ccb23_row1_col2" class="data row1 col2" >13.75</td>
#       <td id="T_ccb23_row1_col3" class="data row1 col3" >1.42</td>
#       <td id="T_ccb23_row1_col4" class="data row1 col4" >5.89</td>
#       <td id="T_ccb23_row1_col5" class="data row1 col5" >-13.76</td>
#     </tr>
#     <tr>
#       <th id="T_ccb23_level0_row2" class="row_heading level0 row2" >RTKM</th>
#       <td id="T_ccb23_row2_col0" class="data row2 col0" >-11.37</td>
#       <td id="T_ccb23_row2_col1" class="data row2 col1" >6.78</td>
#       <td id="T_ccb23_row2_col2" class="data row2 col2" >4.21</td>
#       <td id="T_ccb23_row2_col3" class="data row2 col3" >0.13</td>
#       <td id="T_ccb23_row2_col4" class="data row2 col4" >3.83</td>
#       <td id="T_ccb23_row2_col5" class="data row2 col5" >-11.84</td>
#     </tr>
#     <tr>
#       <th id="T_ccb23_level0_row3" class="row_heading level0 row3" >SBER</th>
#       <td id="T_ccb23_row3_col0" class="data row3 col0" >1.07</td>
#       <td id="T_ccb23_row3_col1" class="data row3 col1" >2.16</td>
#       <td id="T_ccb23_row3_col2" class="data row3 col2" >2.42</td>
#       <td id="T_ccb23_row3_col3" class="data row3 col3" >3.20</td>
#       <td id="T_ccb23_row3_col4" class="data row3 col4" >3.17</td>
#       <td id="T_ccb23_row3_col5" class="data row3 col5" >6.72</td>
#     </tr>
#     <tr>
#       <th id="T_ccb23_level0_row4" class="row_heading level0 row4" >TCSG</th>
#       <td id="T_ccb23_row4_col0" class="data row4 col0" >1.47</td>
#       <td id="T_ccb23_row4_col1" class="data row4 col1" >0.20</td>
#       <td id="T_ccb23_row4_col2" class="data row4 col2" >1.07</td>
#       <td id="T_ccb23_row4_col3" class="data row4 col3" >9.47</td>
#       <td id="T_ccb23_row4_col4" class="data row4 col4" >3.59</td>
#       <td id="T_ccb23_row4_col5" class="data row4 col5" >1.51</td>
#     </tr>
#     <tr>
#       <th id="T_ccb23_level0_row5" class="row_heading level0 row5" >VTBR</th>
#       <td id="T_ccb23_row5_col0" class="data row5 col0" >2.77</td>
#       <td id="T_ccb23_row5_col1" class="data row5 col1" >9.70</td>
#       <td id="T_ccb23_row5_col2" class="data row5 col2" >10.51</td>
#       <td id="T_ccb23_row5_col3" class="data row5 col3" >10.47</td>
#       <td id="T_ccb23_row5_col4" class="data row5 col4" >10.26</td>
#       <td id="T_ccb23_row5_col5" class="data row5 col5" >-10.56</td>
#     </tr>
#     <tr>
#       <th id="T_ccb23_level0_row6" class="row_heading level0 row6" >YNDX</th>
#       <td id="T_ccb23_row6_col0" class="data row6 col0" >4.30</td>
#       <td id="T_ccb23_row6_col1" class="data row6 col1" >6.99</td>
#       <td id="T_ccb23_row6_col2" class="data row6 col2" >7.84</td>
#       <td id="T_ccb23_row6_col3" class="data row6 col3" >4.12</td>
#       <td id="T_ccb23_row6_col4" class="data row6 col4" >2.27</td>
#       <td id="T_ccb23_row6_col5" class="data row6 col5" >-1.97</td>
#     </tr>
#   </tbody>
# </table>

# %%
effects_neutral_news_zero_rf.sort_index().style.applymap(_color_red_or_green).format(precision=2)
# Out:
# <style type="text/css">
# #T_44368_row0_col0, #T_44368_row5_col0, #T_44368_row5_col1, #T_44368_row5_col5, #T_44368_row8_col0, #T_44368_row8_col5, #T_44368_row11_col2, #T_44368_row12_col0, #T_44368_row13_col5, #T_44368_row22_col0, #T_44368_row22_col1, #T_44368_row22_col4, #T_44368_row22_col5, #T_44368_row25_col5, #T_44368_row26_col5 {
#   color: red;
# }
# #T_44368_row0_col1, #T_44368_row0_col2, #T_44368_row0_col3, #T_44368_row0_col4, #T_44368_row0_col5, #T_44368_row1_col0, #T_44368_row1_col1, #T_44368_row1_col2, #T_44368_row1_col3, #T_44368_row1_col4, #T_44368_row1_col5, #T_44368_row2_col0, #T_44368_row2_col1, #T_44368_row2_col2, #T_44368_row2_col3, #T_44368_row2_col4, #T_44368_row2_col5, #T_44368_row3_col0, #T_44368_row3_col1, #T_44368_row3_col2, #T_44368_row3_col3, #T_44368_row3_col4, #T_44368_row3_col5, #T_44368_row4_col0, #T_44368_row4_col1, #T_44368_row4_col2, #T_44368_row4_col3, #T_44368_row4_col4, #T_44368_row4_col5, #T_44368_row5_col2, #T_44368_row5_col3, #T_44368_row5_col4, #T_44368_row6_col0, #T_44368_row6_col1, #T_44368_row6_col2, #T_44368_row6_col3, #T_44368_row6_col4, #T_44368_row6_col5, #T_44368_row7_col0, #T_44368_row7_col1, #T_44368_row7_col2, #T_44368_row7_col3, #T_44368_row7_col4, #T_44368_row7_col5, #T_44368_row8_col1, #T_44368_row8_col2, #T_44368_row8_col3, #T_44368_row8_col4, #T_44368_row9_col0, #T_44368_row9_col1, #T_44368_row9_col2, #T_44368_row9_col3, #T_44368_row9_col4, #T_44368_row9_col5, #T_44368_row10_col0, #T_44368_row10_col1, #T_44368_row10_col2, #T_44368_row10_col3, #T_44368_row10_col4, #T_44368_row10_col5, #T_44368_row11_col0, #T_44368_row11_col1, #T_44368_row11_col3, #T_44368_row11_col4, #T_44368_row11_col5, #T_44368_row12_col1, #T_44368_row12_col2, #T_44368_row12_col3, #T_44368_row12_col4, #T_44368_row12_col5, #T_44368_row13_col0, #T_44368_row13_col1, #T_44368_row13_col2, #T_44368_row13_col3, #T_44368_row13_col4, #T_44368_row14_col0, #T_44368_row14_col1, #T_44368_row14_col2, #T_44368_row14_col3, #T_44368_row14_col4, #T_44368_row14_col5, #T_44368_row15_col0, #T_44368_row15_col1, #T_44368_row15_col2, #T_44368_row15_col3, #T_44368_row15_col4, #T_44368_row15_col5, #T_44368_row16_col0, #T_44368_row16_col1, #T_44368_row16_col2, #T_44368_row16_col3, #T_44368_row16_col4, #T_44368_row16_col5, #T_44368_row17_col0, #T_44368_row17_col1, #T_44368_row17_col2, #T_44368_row17_col3, #T_44368_row17_col4, #T_44368_row17_col5, #T_44368_row18_col0, #T_44368_row18_col1, #T_44368_row18_col2, #T_44368_row18_col3, #T_44368_row18_col4, #T_44368_row18_col5, #T_44368_row19_col0, #T_44368_row19_col1, #T_44368_row19_col2, #T_44368_row19_col3, #T_44368_row19_col4, #T_44368_row19_col5, #T_44368_row20_col0, #T_44368_row20_col1, #T_44368_row20_col2, #T_44368_row20_col3, #T_44368_row20_col4, #T_44368_row20_col5, #T_44368_row21_col0, #T_44368_row21_col1, #T_44368_row21_col2, #T_44368_row21_col3, #T_44368_row21_col4, #T_44368_row21_col5, #T_44368_row22_col2, #T_44368_row22_col3, #T_44368_row23_col0, #T_44368_row23_col1, #T_44368_row23_col2, #T_44368_row23_col3, #T_44368_row23_col4, #T_44368_row23_col5, #T_44368_row24_col0, #T_44368_row24_col1, #T_44368_row24_col2, #T_44368_row24_col3, #T_44368_row24_col4, #T_44368_row24_col5, #T_44368_row25_col0, #T_44368_row25_col1, #T_44368_row25_col2, #T_44368_row25_col3, #T_44368_row25_col4, #T_44368_row26_col0, #T_44368_row26_col1, #T_44368_row26_col2, #T_44368_row26_col3, #T_44368_row26_col4 {
#   color: green;
# }
# </style>
# <table id="T_44368" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_44368_level0_col0" class="col_heading level0 col0" >5 min</th>
#       <th id="T_44368_level0_col1" class="col_heading level0 col1" >10 min</th>
#       <th id="T_44368_level0_col2" class="col_heading level0 col2" >15 min</th>
#       <th id="T_44368_level0_col3" class="col_heading level0 col3" >30 min</th>
#       <th id="T_44368_level0_col4" class="col_heading level0 col4" >1 hour</th>
#       <th id="T_44368_level0_col5" class="col_heading level0 col5" >1 day</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_44368_level0_row0" class="row_heading level0 row0" >AFKS</th>
#       <td id="T_44368_row0_col0" class="data row0 col0" >-0.01</td>
#       <td id="T_44368_row0_col1" class="data row0 col1" >0.14</td>
#       <td id="T_44368_row0_col2" class="data row0 col2" >0.08</td>
#       <td id="T_44368_row0_col3" class="data row0 col3" >0.01</td>
#       <td id="T_44368_row0_col4" class="data row0 col4" >0.12</td>
#       <td id="T_44368_row0_col5" class="data row0 col5" >0.05</td>
#     </tr>
#     <tr>
#       <th id="T_44368_level0_row1" class="row_heading level0 row1" >AFLT</th>
#       <td id="T_44368_row1_col0" class="data row1 col0" >0.06</td>
#       <td id="T_44368_row1_col1" class="data row1 col1" >0.00</td>
#       <td id="T_44368_row1_col2" class="data row1 col2" >0.07</td>
#       <td id="T_44368_row1_col3" class="data row1 col3" >0.16</td>
#       <td id="T_44368_row1_col4" class="data row1 col4" >0.15</td>
#       <td id="T_44368_row1_col5" class="data row1 col5" >0.05</td>
#     </tr>
#     <tr>
#       <th id="T_44368_level0_row2" class="row_heading level0 row2" >ALRS</th>
#       <td id="T_44368_row2_col0" class="data row2 col0" >0.25</td>
#       <td id="T_44368_row2_col1" class="data row2 col1" >0.09</td>
#       <td id="T_44368_row2_col2" class="data row2 col2" >0.11</td>
#       <td id="T_44368_row2_col3" class="data row2 col3" >0.35</td>
#       <td id="T_44368_row2_col4" class="data row2 col4" >0.30</td>
#       <td id="T_44368_row2_col5" class="data row2 col5" >0.16</td>
#     </tr>
#     <tr>
#       <th id="T_44368_level0_row3" class="row_heading level0 row3" >CBOM</th>
#       <td id="T_44368_row3_col0" class="data row3 col0" >0.05</td>
#       <td id="T_44368_row3_col1" class="data row3 col1" >0.10</td>
#       <td id="T_44368_row3_col2" class="data row3 col2" >0.06</td>
#       <td id="T_44368_row3_col3" class="data row3 col3" >0.08</td>
#       <td id="T_44368_row3_col4" class="data row3 col4" >0.06</td>
#       <td id="T_44368_row3_col5" class="data row3 col5" >0.06</td>
#     </tr>
#     <tr>
#       <th id="T_44368_level0_row4" class="row_heading level0 row4" >CHMF</th>
#       <td id="T_44368_row4_col0" class="data row4 col0" >0.15</td>
#       <td id="T_44368_row4_col1" class="data row4 col1" >0.20</td>
#       <td id="T_44368_row4_col2" class="data row4 col2" >0.24</td>
#       <td id="T_44368_row4_col3" class="data row4 col3" >0.15</td>
#       <td id="T_44368_row4_col4" class="data row4 col4" >0.10</td>
#       <td id="T_44368_row4_col5" class="data row4 col5" >0.12</td>
#     </tr>
#     <tr>
#       <th id="T_44368_level0_row5" class="row_heading level0 row5" >DSKY</th>
#       <td id="T_44368_row5_col0" class="data row5 col0" >-0.00</td>
#       <td id="T_44368_row5_col1" class="data row5 col1" >-0.09</td>
#       <td id="T_44368_row5_col2" class="data row5 col2" >0.05</td>
#       <td id="T_44368_row5_col3" class="data row5 col3" >0.30</td>
#       <td id="T_44368_row5_col4" class="data row5 col4" >0.00</td>
#       <td id="T_44368_row5_col5" class="data row5 col5" >-0.03</td>
#     </tr>
#     <tr>
#       <th id="T_44368_level0_row6" class="row_heading level0 row6" >GAZP</th>
#       <td id="T_44368_row6_col0" class="data row6 col0" >0.10</td>
#       <td id="T_44368_row6_col1" class="data row6 col1" >0.13</td>
#       <td id="T_44368_row6_col2" class="data row6 col2" >0.12</td>
#       <td id="T_44368_row6_col3" class="data row6 col3" >0.15</td>
#       <td id="T_44368_row6_col4" class="data row6 col4" >0.06</td>
#       <td id="T_44368_row6_col5" class="data row6 col5" >0.10</td>
#     </tr>
#     <tr>
#       <th id="T_44368_level0_row7" class="row_heading level0 row7" >GMKN</th>
#       <td id="T_44368_row7_col0" class="data row7 col0" >0.14</td>
#       <td id="T_44368_row7_col1" class="data row7 col1" >0.06</td>
#       <td id="T_44368_row7_col2" class="data row7 col2" >0.16</td>
#       <td id="T_44368_row7_col3" class="data row7 col3" >0.16</td>
#       <td id="T_44368_row7_col4" class="data row7 col4" >0.14</td>
#       <td id="T_44368_row7_col5" class="data row7 col5" >0.

# %%
effects_neutral_news_zero_rf.mean()
# Out:
# 5 min     0.092041
# 10 min    0.146940
# 15 min    0.149434
# 30 min    0.167547
# 1 hour    0.149813
# 1 day     0.055965
# dtype: float64

# %%
effects_neutral_news_zero_rf.filter(['GAZP', 'MTSS', 'RTKM', 'SBER', 'TCSG', 'VTBR', 'YNDX'], axis=0).sort_index().style.applymap(_color_red_or_green).format(precision=2)
# Out:
# <style type="text/css">
# #T_4cebb_row0_col0, #T_4cebb_row0_col1, #T_4cebb_row0_col2, #T_4cebb_row0_col3, #T_4cebb_row0_col4, #T_4cebb_row0_col5, #T_4cebb_row1_col0, #T_4cebb_row1_col1, #T_4cebb_row1_col2, #T_4cebb_row1_col3, #T_4cebb_row1_col4, #T_4cebb_row2_col0, #T_4cebb_row2_col1, #T_4cebb_row2_col2, #T_4cebb_row2_col3, #T_4cebb_row2_col4, #T_4cebb_row2_col5, #T_4cebb_row3_col0, #T_4cebb_row3_col1, #T_4cebb_row3_col2, #T_4cebb_row3_col3, #T_4cebb_row3_col4, #T_4cebb_row3_col5, #T_4cebb_row4_col0, #T_4cebb_row4_col1, #T_4cebb_row4_col2, #T_4cebb_row4_col3, #T_4cebb_row4_col4, #T_4cebb_row4_col5, #T_4cebb_row5_col0, #T_4cebb_row5_col1, #T_4cebb_row5_col2, #T_4cebb_row5_col3, #T_4cebb_row5_col4, #T_4cebb_row6_col0, #T_4cebb_row6_col1, #T_4cebb_row6_col2, #T_4cebb_row6_col3, #T_4cebb_row6_col4 {
#   color: green;
# }
# #T_4cebb_row1_col5, #T_4cebb_row5_col5, #T_4cebb_row6_col5 {
#   color: red;
# }
# </style>
# <table id="T_4cebb" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4cebb_level0_col0" class="col_heading level0 col0" >5 min</th>
#       <th id="T_4cebb_level0_col1" class="col_heading level0 col1" >10 min</th>
#       <th id="T_4cebb_level0_col2" class="col_heading level0 col2" >15 min</th>
#       <th id="T_4cebb_level0_col3" class="col_heading level0 col3" >30 min</th>
#       <th id="T_4cebb_level0_col4" class="col_heading level0 col4" >1 hour</th>
#       <th id="T_4cebb_level0_col5" class="col_heading level0 col5" >1 day</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4cebb_level0_row0" class="row_heading level0 row0" >GAZP</th>
#       <td id="T_4cebb_row0_col0" class="data row0 col0" >0.10</td>
#       <td id="T_4cebb_row0_col1" class="data row0 col1" >0.13</td>
#       <td id="T_4cebb_row0_col2" class="data row0 col2" >0.12</td>
#       <td id="T_4cebb_row0_col3" class="data row0 col3" >0.15</td>
#       <td id="T_4cebb_row0_col4" class="data row0 col4" >0.06</td>
#       <td id="T_4cebb_row0_col5" class="data row0 col5" >0.10</td>
#     </tr>
#     <tr>
#       <th id="T_4cebb_level0_row1" class="row_heading level0 row1" >MTSS</th>
#       <td id="T_4cebb_row1_col0" class="data row1 col0" >0.22</td>
#       <td id="T_4cebb_row1_col1" class="data row1 col1" >0.24</td>
#       <td id="T_4cebb_row1_col2" class="data row1 col2" >0.31</td>
#       <td id="T_4cebb_row1_col3" class="data row1 col3" >0.27</td>
#       <td id="T_4cebb_row1_col4" class="data row1 col4" >0.28</td>
#       <td id="T_4cebb_row1_col5" class="data row1 col5" >-0.01</td>
#     </tr>
#     <tr>
#       <th id="T_4cebb_level0_row2" class="row_heading level0 row2" >RTKM</th>
#       <td id="T_4cebb_row2_col0" class="data row2 col0" >0.01</td>
#       <td id="T_4cebb_row2_col1" class="data row2 col1" >0.17</td>
#       <td id="T_4cebb_row2_col2" class="data row2 col2" >0.21</td>
#       <td id="T_4cebb_row2_col3" class="data row2 col3" >0.20</td>
#       <td id="T_4cebb_row2_col4" class="data row2 col4" >0.20</td>
#       <td id="T_4cebb_row2_col5" class="data row2 col5" >0.04</td>
#     </tr>
#     <tr>
#       <th id="T_4cebb_level0_row3" class="row_heading level0 row3" >SBER</th>
#       <td id="T_4cebb_row3_col0" class="data row3 col0" >0.11</td>
#       <td id="T_4cebb_row3_col1" class="data row3 col1" >0.18</td>
#       <td id="T_4cebb_row3_col2" class="data row3 col2" >0.20</td>
#       <td id="T_4cebb_row3_col3" class="data row3 col3" >0.24</td>
#       <td id="T_4cebb_row3_col4" class="data row3 col4" >0.23</td>
#       <td id="T_4cebb_row3_col5" class="data row3 col5" >0.17</td>
#     </tr>
#     <tr>
#       <th id="T_4cebb_level0_row4" class="row_heading level0 row4" >TCSG</th>
#       <td id="T_4cebb_row4_col0" class="data row4 col0" >0.15</td>
#       <td id="T_4cebb_row4_col1" class="data row4 col1" >0.21</td>
#       <td id="T_4cebb_row4_col2" class="data row4 col2" >0.16</td>
#       <td id="T_4cebb_row4_col3" class="data row4 col3" >0.28</td>
#       <td id="T_4cebb_row4_col4" class="data row4 col4" >0.16</td>
#       <td id="T_4cebb_row4_col5" class="data row4 col5" >0.21</td>
#     </tr>
#     <tr>
#       <th id="T_4cebb_level0_row5" class="row_heading level0 row5" >VTBR</th>
#       <td id="T_4cebb_row5_col0" class="data row5 col0" >0.15</td>
#       <td id="T_4cebb_row5_col1" class="data row5 col1" >0.27</td>
#       <td id="T_4cebb_row5_col2" class="data row5 col2" >0.30</td>
#       <td id="T_4cebb_row5_col3" class="data row5 col3" >0.28</td>
#       <td id="T_4cebb_row5_col4" class="data row5 col4" >0.29</td>
#       <td id="T_4cebb_row5_col5" class="data row5 col5" >-0.10</td>
#     </tr>
#     <tr>
#       <th id="T_4cebb_level0_row6" class="row_heading level0 row6" >YNDX</th>
#       <td id="T_4cebb_row6_col0" class="data row6 col0" >0.22</td>
#       <td id="T_4cebb_row6_col1" class="data row6 col1" >0.24</td>
#       <td id="T_4cebb_row6_col2" class="data row6 col2" >0.24</td>
#       <td id="T_4cebb_row6_col3" class="data row6 col3" >0.18</td>
#       <td id="T_4cebb_row6_col4" class="data row6 col4" >0.14</td>
#       <td id="T_4cebb_row6_col5" class="data row6 col5" >-0.06</td>
#     </tr>
#   </tbody>
# </table>

# %%
loggs = pd.read_csv('/content/drive/MyDrive/Диссертация/news_loggs/loggs_news_boosting_neutral.csv', index_col=0)

# %%
effects_neutral_news_rand_boosting, effects_neutral_news_zero_boosting = get_effects_neutral(news_train, news_test, loggs, companies=companies)

# %%
effects_neutral_news_rand_boosting.sort_index().style.applymap(_color_red_or_green).format(precision=2)
# Out:
# <style type="text/css">
# #T_d7087_row0_col0, #T_d7087_row0_col1, #T_d7087_row0_col2, #T_d7087_row0_col3, #T_d7087_row0_col4, #T_d7087_row0_col5, #T_d7087_row1_col0, #T_d7087_row1_col1, #T_d7087_row1_col2, #T_d7087_row1_col3, #T_d7087_row2_col0, #T_d7087_row2_col1, #T_d7087_row2_col2, #T_d7087_row2_col3, #T_d7087_row2_col4, #T_d7087_row3_col0, #T_d7087_row3_col1, #T_d7087_row3_col3, #T_d7087_row3_col4, #T_d7087_row3_col5, #T_d7087_row4_col0, #T_d7087_row4_col1, #T_d7087_row4_col3, #T_d7087_row5_col1, #T_d7087_row5_col4, #T_d7087_row5_col5, #T_d7087_row7_col0, #T_d7087_row7_col2, #T_d7087_row7_col3, #T_d7087_row7_col5, #T_d7087_row8_col0, #T_d7087_row8_col1, #T_d7087_row8_col2, #T_d7087_row8_col3, #T_d7087_row8_col4, #T_d7087_row8_col5, #T_d7087_row9_col0, #T_d7087_row9_col1, #T_d7087_row9_col2, #T_d7087_row9_col3, #T_d7087_row9_col4, #T_d7087_row9_col5, #T_d7087_row10_col0, #T_d7087_row10_col2, #T_d7087_row10_col3, #T_d7087_row10_col5, #T_d7087_row11_col0, #T_d7087_row11_col2, #T_d7087_row11_col3, #T_d7087_row11_col4, #T_d7087_row11_col5, #T_d7087_row12_col0, #T_d7087_row12_col1, #T_d7087_row12_col2, #T_d7087_row12_col5, #T_d7087_row13_col1, #T_d7087_row13_col2, #T_d7087_row13_col4, #T_d7087_row13_col5, #T_d7087_row14_col0, #T_d7087_row14_col1, #T_d7087_row14_col2, #T_d7087_row14_col3, #T_d7087_row14_col4, #T_d7087_row14_col5, #T_d7087_row15_col0, #T_d7087_row15_col1, #T_d7087_row15_col2, #T_d7087_row15_col4, #T_d7087_row16_col0, #T_d7087_row16_col1, #T_d7087_row16_col2, #T_d7087_row16_col3, #T_d7087_row16_col4, #T_d7087_row16_col5, #T_d7087_row17_col0, #T_d7087_row17_col1, #T_d7087_row17_col2, #T_d7087_row17_col3, #T_d7087_row17_col4, #T_d7087_row17_col5, #T_d7087_row18_col0, #T_d7087_row18_col1, #T_d7087_row18_col2, #T_d7087_row18_col4, #T_d7087_row18_col5, #T_d7087_row19_col0, #T_d7087_row19_col1, #T_d7087_row19_col2, #T_d7087_row19_col4, #T_d7087_row19_col5, #T_d7087_row20_col0, #T_d7087_row20_col1, #T_d7087_row20_col5, #T_d7087_row21_col0, #T_d7087_row21_col1, #T_d7087_row21_col2, #T_d7087_row21_col3, #T_d7087_row21_col4, #T_d7087_row21_col5, #T_d7087_row22_col0, #T_d7087_row22_col1, #T_d7087_row22_col2, #T_d7087_row22_col3, #T_d7087_row22_col4, #T_d7087_row22_col5, #T_d7087_row23_col0, #T_d7087_row24_col0, #T_d7087_row24_col1, #T_d7087_row24_col2, #T_d7087_row24_col3, #T_d7087_row24_col4, #T_d7087_row24_col5, #T_d7087_row25_col0, #T_d7087_row25_col5, #T_d7087_row26_col0, #T_d7087_row26_col5 {
#   color: red;
# }
# #T_d7087_row1_col4, #T_d7087_row1_col5, #T_d7087_row2_col5, #T_d7087_row3_col2, #T_d7087_row4_col2, #T_d7087_row4_col4, #T_d7087_row4_col5, #T_d7087_row5_col0, #T_d7087_row5_col2, #T_d7087_row5_col3, #T_d7087_row6_col0, #T_d7087_row6_col1, #T_d7087_row6_col2, #T_d7087_row6_col3, #T_d7087_row6_col4, #T_d7087_row6_col5, #T_d7087_row7_col1, #T_d7087_row7_col4, #T_d7087_row10_col1, #T_d7087_row10_col4, #T_d7087_row11_col1, #T_d7087_row12_col3, #T_d7087_row12_col4, #T_d7087_row13_col0, #T_d7087_row13_col3, #T_d7087_row15_col3, #T_d7087_row15_col5, #T_d7087_row18_col3, #T_d7087_row19_col3, #T_d7087_row20_col2, #T_d7087_row20_col3, #T_d7087_row20_col4, #T_d7087_row23_col1, #T_d7087_row23_col2, #T_d7087_row23_col3, #T_d7087_row23_col4, #T_d7087_row23_col5, #T_d7087_row25_col1, #T_d7087_row25_col2, #T_d7087_row25_col3, #T_d7087_row25_col4, #T_d7087_row26_col1, #T_d7087_row26_col2, #T_d7087_row26_col3, #T_d7087_row26_col4 {
#   color: green;
# }
# </style>
# <table id="T_d7087" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d7087_level0_col0" class="col_heading level0 col0" >5 min</th>
#       <th id="T_d7087_level0_col1" class="col_heading level0 col1" >10 min</th>
#       <th id="T_d7087_level0_col2" class="col_heading level0 col2" >15 min</th>
#       <th id="T_d7087_level0_col3" class="col_heading level0 col3" >30 min</th>
#       <th id="T_d7087_level0_col4" class="col_heading level0 col4" >1 hour</th>
#       <th id="T_d7087_level0_col5" class="col_heading level0 col5" >1 day</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d7087_level0_row0" class="row_heading level0 row0" >AFKS</th>
#       <td id="T_d7087_row0_col0" class="data row0 col0" >-10.01</td>
#       <td id="T_d7087_row0_col1" class="data row0 col1" >-10.76</td>
#       <td id="T_d7087_row0_col2" class="data row0 col2" >-6.45</td>
#       <td id="T_d7087_row0_col3" class="data row0 col3" >-7.41</td>
#       <td id="T_d7087_row0_col4" class="data row0 col4" >-1.08</td>
#       <td id="T_d7087_row0_col5" class="data row0 col5" >-2.23</td>
#     </tr>
#     <tr>
#       <th id="T_d7087_level0_row1" class="row_heading level0 row1" >AFLT</th>
#       <td id="T_d7087_row1_col0" class="data row1 col0" >-4.63</td>
#       <td id="T_d7087_row1_col1" class="data row1 col1" >-10.61</td>
#       <td id="T_d7087_row1_col2" class="data row1 col2" >-1.58</td>
#       <td id="T_d7087_row1_col3" class="data row1 col3" >-5.70</td>
#       <td id="T_d7087_row1_col4" class="data row1 col4" >6.32</td>
#       <td id="T_d7087_row1_col5" class="data row1 col5" >0.38</td>
#     </tr>
#     <tr>
#       <th id="T_d7087_level0_row2" class="row_heading level0 row2" >ALRS</th>
#       <td id="T_d7087_row2_col0" class="data row2 col0" >-18.21</td>
#       <td id="T_d7087_row2_col1" class="data row2 col1" >-15.79</td>
#       <td id="T_d7087_row2_col2" class="data row2 col2" >-8.65</td>
#       <td id="T_d7087_row2_col3" class="data row2 col3" >-15.11</td>
#       <td id="T_d7087_row2_col4" class="data row2 col4" >-0.29</td>
#       <td id="T_d7087_row2_col5" class="data row2 col5" >10.67</td>
#     </tr>
#     <tr>
#       <th id="T_d7087_level0_row3" class="row_heading level0 row3" >CBOM</th>
#       <td id="T_d7087_row3_col0" class="data row3 col0" >-15.49</td>
#       <td id="T_d7087_row3_col1" class="data row3 col1" >-9.55</td>
#       <td id="T_d7087_row3_col2" class="data row3 col2" >1.43</td>
#       <td id="T_d7087_row3_col3" class="data row3 col3" >-0.74</td>
#       <td id="T_d7087_row3_col4" class="data row3 col4" >-10.55</td>
#       <td id="T_d7087_row3_col5" class="data row3 col5" >-11.13</td>
#     </tr>
#     <tr>
#       <th id="T_d7087_level0_row4" class="row_heading level0 row4" >CHMF</th>
#       <td id="T_d7087_row4_col0" class="data row4 col0" >-9.57</td>
#       <td id="T_d7087_row4_col1" class="data row4 col1" >-2.58</td>
#       <td id="T_d7087_row4_col2" class="data row4 col2" >2.09</td>
#       <td id="T_d7087_row4_col3" class="data row4 col3" >-2.98</td>
#       <td id="T_d7087_row4_col4" class="data row4 col4" >0.74</td>
#       <td id="T_d7087_row4_col5" class="data row4 col5" >2.26</td>
#     </tr>
#     <tr>
#       <th id="T_d7087_level0_row5" class="row_heading level0 row5" >DSKY</th>
#       <td id="T_d7087_row5_col0" class="data row5 col0" >17.84</td>
#       <td id="T_d7087_row5_col1" class="data row5 col1" >-18.73</td>
#       <td id="T_d7087_row5_col2" class="data row5 col2" >13.12</td>
#       <td id="T_d7087_row5_col3" class="data row5 col3" >7.09</td>
#       <td id="T_d7087_row5_col4" class="data row5 col4" >-8.90</td>
#       <td id="T_d7087_row5_col5" class="data row5 col5" >-24.65</td>
#     </tr>
#     <tr>
#       <th id="T_d7087_level0_row6" class="row_heading level0 row6" >GAZP</th>
#       <td id="T_d7087_row6_col0" class="data row6 col0" >2.96</td>
#       <td id="T_d7087_row6_col1" class="data row6 col1" >1.25</td>
#       <td id="T_d7087_row6_col2" class="data row6 col2" >4.80</td>
#       <td id="T_d7087_row6_col3" class="data row6 col3" >3.22</td>
#       <td id="T_d7087_row6_col4" class="data row6 col4" >6.74</td>
#       <td id="T_d7087_row6_col5" class="data row6 col5" >3.96</td>
#     </tr>
#     <tr>
#       <th id="T_d7087_level0_row7" class="row_heading level0 row7" >GMKN</th>
#       <td id="T_d7087_row7_col0" class="data row7 col0" >-0.80</td>
#       <td id="T_d7087_row7_col1" class="data row7 col1" >2.60</td>
#       <td id="T_d7087_row7_col2" class="data row7 col2" >-3.07</td>
#       <td id="T_d7087_row7_col3" class="data row7 col3" >-2.42</td>
#       <td id="T_d7087_row7_col4" class="data row7 col4" >1.16</td>
#       <td id="T_d708

# %%
effects_neutral_news_rand_boosting.mean()
# Out:
# 5 min    -5.471852
# 10 min   -5.353333
# 15 min   -2.913333
# 30 min   -2.143333
# 1 hour   -2.712222
# 1 day    -5.787037
# dtype: float64

# %%
effects_neutral_news_zero_boosting.sort_index().style.applymap(_color_red_or_green).format(precision=2)
# Out:
# <style type="text/css">
# #T_ab4ec_row0_col0, #T_ab4ec_row0_col1, #T_ab4ec_row0_col2, #T_ab4ec_row0_col3, #T_ab4ec_row0_col4, #T_ab4ec_row0_col5, #T_ab4ec_row1_col0, #T_ab4ec_row1_col2, #T_ab4ec_row1_col3, #T_ab4ec_row1_col4, #T_ab4ec_row1_col5, #T_ab4ec_row2_col0, #T_ab4ec_row2_col1, #T_ab4ec_row2_col2, #T_ab4ec_row2_col3, #T_ab4ec_row2_col4, #T_ab4ec_row2_col5, #T_ab4ec_row3_col1, #T_ab4ec_row3_col2, #T_ab4ec_row3_col3, #T_ab4ec_row3_col4, #T_ab4ec_row3_col5, #T_ab4ec_row4_col0, #T_ab4ec_row4_col1, #T_ab4ec_row4_col2, #T_ab4ec_row4_col3, #T_ab4ec_row4_col4, #T_ab4ec_row4_col5, #T_ab4ec_row5_col0, #T_ab4ec_row5_col1, #T_ab4ec_row5_col2, #T_ab4ec_row5_col3, #T_ab4ec_row5_col5, #T_ab4ec_row6_col0, #T_ab4ec_row6_col1, #T_ab4ec_row6_col2, #T_ab4ec_row6_col3, #T_ab4ec_row6_col4, #T_ab4ec_row6_col5, #T_ab4ec_row7_col0, #T_ab4ec_row7_col1, #T_ab4ec_row7_col2, #T_ab4ec_row7_col3, #T_ab4ec_row7_col4, #T_ab4ec_row7_col5, #T_ab4ec_row8_col1, #T_ab4ec_row8_col2, #T_ab4ec_row8_col3, #T_ab4ec_row8_col4, #T_ab4ec_row9_col0, #T_ab4ec_row9_col1, #T_ab4ec_row9_col3, #T_ab4ec_row9_col4, #T_ab4ec_row9_col5, #T_ab4ec_row10_col0, #T_ab4ec_row10_col1, #T_ab4ec_row10_col2, #T_ab4ec_row10_col3, #T_ab4ec_row10_col4, #T_ab4ec_row10_col5, #T_ab4ec_row11_col0, #T_ab4ec_row11_col1, #T_ab4ec_row11_col2, #T_ab4ec_row11_col3, #T_ab4ec_row11_col4, #T_ab4ec_row11_col5, #T_ab4ec_row12_col0, #T_ab4ec_row12_col1, #T_ab4ec_row12_col2, #T_ab4ec_row12_col3, #T_ab4ec_row12_col4, #T_ab4ec_row12_col5, #T_ab4ec_row13_col0, #T_ab4ec_row13_col1, #T_ab4ec_row13_col2, #T_ab4ec_row13_col3, #T_ab4ec_row13_col4, #T_ab4ec_row14_col0, #T_ab4ec_row14_col1, #T_ab4ec_row14_col2, #T_ab4ec_row14_col3, #T_ab4ec_row14_col4, #T_ab4ec_row14_col5, #T_ab4ec_row15_col0, #T_ab4ec_row15_col1, #T_ab4ec_row15_col2, #T_ab4ec_row15_col3, #T_ab4ec_row15_col4, #T_ab4ec_row15_col5, #T_ab4ec_row16_col0, #T_ab4ec_row16_col1, #T_ab4ec_row16_col2, #T_ab4ec_row16_col3, #T_ab4ec_row16_col4, #T_ab4ec_row16_col5, #T_ab4ec_row17_col0, #T_ab4ec_row17_col1, #T_ab4ec_row17_col2, #T_ab4ec_row17_col3, #T_ab4ec_row17_col4, #T_ab4ec_row17_col5, #T_ab4ec_row18_col1, #T_ab4ec_row18_col2, #T_ab4ec_row18_col3, #T_ab4ec_row18_col4, #T_ab4ec_row18_col5, #T_ab4ec_row19_col0, #T_ab4ec_row19_col1, #T_ab4ec_row19_col2, #T_ab4ec_row19_col3, #T_ab4ec_row19_col4, #T_ab4ec_row19_col5, #T_ab4ec_row20_col0, #T_ab4ec_row20_col1, #T_ab4ec_row20_col2, #T_ab4ec_row20_col3, #T_ab4ec_row20_col4, #T_ab4ec_row20_col5, #T_ab4ec_row21_col0, #T_ab4ec_row21_col1, #T_ab4ec_row21_col2, #T_ab4ec_row21_col3, #T_ab4ec_row21_col4, #T_ab4ec_row21_col5, #T_ab4ec_row22_col0, #T_ab4ec_row22_col1, #T_ab4ec_row22_col3, #T_ab4ec_row22_col5, #T_ab4ec_row23_col0, #T_ab4ec_row23_col1, #T_ab4ec_row23_col2, #T_ab4ec_row23_col3, #T_ab4ec_row23_col4, #T_ab4ec_row23_col5, #T_ab4ec_row24_col1, #T_ab4ec_row24_col2, #T_ab4ec_row24_col4, #T_ab4ec_row25_col0, #T_ab4ec_row25_col1, #T_ab4ec_row25_col2, #T_ab4ec_row25_col3, #T_ab4ec_row25_col4, #T_ab4ec_row26_col0, #T_ab4ec_row26_col1, #T_ab4ec_row26_col2, #T_ab4ec_row26_col3, #T_ab4ec_row26_col4 {
#   color: green;
# }
# #T_ab4ec_row1_col1, #T_ab4ec_row3_col0, #T_ab4ec_row5_col4, #T_ab4ec_row8_col0, #T_ab4ec_row8_col5, #T_ab4ec_row9_col2, #T_ab4ec_row13_col5, #T_ab4ec_row18_col0, #T_ab4ec_row22_col2, #T_ab4ec_row22_col4, #T_ab4ec_row24_col0, #T_ab4ec_row24_col3, #T_ab4ec_row24_col5, #T_ab4ec_row25_col5, #T_ab4ec_row26_col5 {
#   color: red;
# }
# </style>
# <table id="T_ab4ec" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ab4ec_level0_col0" class="col_heading level0 col0" >5 min</th>
#       <th id="T_ab4ec_level0_col1" class="col_heading level0 col1" >10 min</th>
#       <th id="T_ab4ec_level0_col2" class="col_heading level0 col2" >15 min</th>
#       <th id="T_ab4ec_level0_col3" class="col_heading level0 col3" >30 min</th>
#       <th id="T_ab4ec_level0_col4" class="col_heading level0 col4" >1 hour</th>
#       <th id="T_ab4ec_level0_col5" class="col_heading level0 col5" >1 day</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ab4ec_level0_row0" class="row_heading level0 row0" >AFKS</th>
#       <td id="T_ab4ec_row0_col0" class="data row0 col0" >0.05</td>
#       <td id="T_ab4ec_row0_col1" class="data row0 col1" >0.09</td>
#       <td id="T_ab4ec_row0_col2" class="data row0 col2" >0.12</td>
#       <td id="T_ab4ec_row0_col3" class="data row0 col3" >0.11</td>
#       <td id="T_ab4ec_row0_col4" class="data row0 col4" >0.19</td>
#       <td id="T_ab4ec_row0_col5" class="data row0 col5" >0.16</td>
#     </tr>
#     <tr>
#       <th id="T_ab4ec_level0_row1" class="row_heading level0 row1" >AFLT</th>
#       <td id="T_ab4ec_row1_col0" class="data row1 col0" >0.07</td>
#       <td id="T_ab4ec_row1_col1" class="data row1 col1" >-0.01</td>
#       <td id="T_ab4ec_row1_col2" class="data row1 col2" >0.08</td>
#       <td id="T_ab4ec_row1_col3" class="data row1 col3" >0.08</td>
#       <td id="T_ab4ec_row1_col4" class="data row1 col4" >0.21</td>
#       <td id="T_ab4ec_row1_col5" class="data row1 col5" >0.10</td>
#     </tr>
#     <tr>
#       <th id="T_ab4ec_level0_row2" class="row_heading level0 row2" >ALRS</th>
#       <td id="T_ab4ec_row2_col0" class="data row2 col0" >0.08</td>
#       <td id="T_ab4ec_row2_col1" class="data row2 col1" >0.13</td>
#       <td id="T_ab4ec_row2_col2" class="data row2 col2" >0.18</td>
#       <td id="T_ab4ec_row2_col3" class="data row2 col3" >0.18</td>
#       <td id="T_ab4ec_row2_col4" class="data row2 col4" >0.29</td>
#       <td id="T_ab4ec_row2_col5" class="data row2 col5" >0.28</td>
#     </tr>
#     <tr>
#       <th id="T_ab4ec_level0_row3" class="row_heading level0 row3" >CBOM</th>
#       <td id="T_ab4ec_row3_col0" class="data row3 col0" >-0.02</td>
#       <td id="T_ab4ec_row3_col1" class="data row3 col1" >0.07</td>
#       <td id="T_ab4ec_row3_col2" class="data row3 col2" >0.16</td>
#       <td id="T_ab4ec_row3_col3" class="data row3 col3" >0.18</td>
#       <td id="T_ab4ec_row3_col4" class="data row3 col4" >0.07</td>
#       <td id="T_ab4ec_row3_col5" class="data row3 col5" >0.03</td>
#     </tr>
#     <tr>
#       <th id="T_ab4ec_level0_row4" class="row_heading level0 row4" >CHMF</th>
#       <td id="T_ab4ec_row4_col0" class="data row4 col0" >0.12</td>
#       <td id="T_ab4ec_row4_col1" class="data row4 col1" >0.20</td>
#       <td id="T_ab4ec_row4_col2" class="data row4 col2" >0.28</td>
#       <td id="T_ab4ec_row4_col3" class="data row4 col3" >0.20</td>
#       <td id="T_ab4ec_row4_col4" class="data row4 col4" >0.17</td>
#       <td id="T_ab4ec_row4_col5" class="data row4 col5" >0.21</td>
#     </tr>
#     <tr>
#       <th id="T_ab4ec_level0_row5" class="row_heading level0 row5" >DSKY</th>
#       <td id="T_ab4ec_row5_col0" class="data row5 col0" >0.53</td>
#       <td id="T_ab4ec_row5_col1" class="data row5 col1" >0.12</td>
#       <td id="T_ab4ec_row5_col2" class="data row5 col2" >0.23</td>
#       <td id="T_ab4ec_row5_col3" class="data row5 col3" >0.32</td>
#       <td id="T_ab4ec_row5_col4" class="data row5 col4" >-0.00</td>
#       <td id="T_ab4ec_row5_col5" class="data row5 col5" >0.02</td>
#     </tr>
#     <tr>
#       <th id="T_ab4ec_level0_row6" class="row_heading level0 row6" >GAZP</th>
#       <td id="T_ab4ec_row6_col0" class="data row6 col0" >0.12</td>
#       <td id="T_ab4ec_row6_col1" class="data row6 col1" >0.11</td>
#       <td id="T_ab4ec_row6_col2" class="data row6 col2" >0.12</td>
#       <td id="T_ab4ec_row6_col3" class="data row6 col3" >0.13</td>
#       <td id="T_ab4ec_row6_col4" class="data row6 col4" >0.16</td>
#       <td id="T_ab4ec_row6_col5" class="data row6 col5" >0.12</td>
#     </tr>
#     <tr>
#       <th id="T_ab4ec_level0_row7" class="row_heading level0 row7" >GMKN</th>
#       <td id="T_ab4ec_row7_col0" class="data row7 col0" >0.13</td>
#       <td id="T_ab4ec_row7_col1" class="data row7 col1" >0.20</td>
#       <td id="T_ab4ec_row7_col2" class="data row7 col2" >0.17</td>
#       <td id="T_ab4ec_row7_col3" class="data row7 col3" >0.15</td>
#       <td id="T_ab4ec_row7_col4" class="data row7 col4" >0.15</td>
#       <td id="T_ab4ec_row7_col5" class="data row7 col5" >0.0

# %%
effects_neutral_news_zero_boosting.mean()
# Out:
# 5 min     0.105112
# 10 min    0.144713
# 15 min    0.151958
# 30 min    0.177827
# 1 hour    0.153655
# 1 day     0.083656
# dtype: float64

# %% [markdown]
# ### Берт Телеграмм

# %% [markdown]
# #### 2 класса

# %%
tg = pd.read_parquet('/content/drive/MyDrive/Диссертация/Парсеры сайтов/tg_comps_raw.parquet')
tg.dropna(subset=['message'],inplace=True)
tg.drop(columns=['views', 'forwards', 'fwd_from', 'source'], inplace=True)

tg_train = tg[tg.date < '2021-01-01'].copy()
tg_val = tg[(tg.date > '2021-01-01') & (tg.date < '2021-06-01')].copy()
tg_test = tg[(tg.date < '2022-01-01') & (tg.date > '2021-06-01')].copy()

# %%
loggs = pd.read_csv('/content/drive/MyDrive/Диссертация/tg_loggs/dist_bert_tg_loggs_bin.csv', index_col=0)

# %%
companies = sorted(['MAGN', 'CHMF', 'DSKY', 'SNGS', 'NVTK'])

# %%
effects_bert_tg_bin = get_effects_bin(tg_train, tg_test, loggs, companies=companies, shortened=True)

# %%
effects_bert_tg_bin.sort_index().style.applymap(_color_red_or_green).format(precision=2)
# Out:
# <style type="text/css">
# #T_a7429_row0_col0, #T_a7429_row0_col1, #T_a7429_row0_col2, #T_a7429_row0_col4, #T_a7429_row1_col0, #T_a7429_row1_col1, #T_a7429_row1_col2, #T_a7429_row1_col3, #T_a7429_row1_col4, #T_a7429_row2_col2, #T_a7429_row2_col5, #T_a7429_row3_col0, #T_a7429_row3_col1, #T_a7429_row3_col2, #T_a7429_row3_col3, #T_a7429_row3_col4, #T_a7429_row4_col1, #T_a7429_row4_col3, #T_a7429_row4_col4, #T_a7429_row4_col5 {
#   color: green;
# }
# #T_a7429_row0_col3, #T_a7429_row0_col5, #T_a7429_row1_col5, #T_a7429_row2_col0, #T_a7429_row2_col1, #T_a7429_row2_col3, #T_a7429_row2_col4, #T_a7429_row3_col5, #T_a7429_row4_col0, #T_a7429_row4_col2 {
#   color: red;
# }
# </style>
# <table id="T_a7429" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a7429_level0_col0" class="col_heading level0 col0" >5 min</th>
#       <th id="T_a7429_level0_col1" class="col_heading level0 col1" >10 min</th>
#       <th id="T_a7429_level0_col2" class="col_heading level0 col2" >15 min</th>
#       <th id="T_a7429_level0_col3" class="col_heading level0 col3" >30 min</th>
#       <th id="T_a7429_level0_col4" class="col_heading level0 col4" >1 hour</th>
#       <th id="T_a7429_level0_col5" class="col_heading level0 col5" >1 day</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a7429_level0_row0" class="row_heading level0 row0" >CHMF</th>
#       <td id="T_a7429_row0_col0" class="data row0 col0" >6.52</td>
#       <td id="T_a7429_row0_col1" class="data row0 col1" >3.32</td>
#       <td id="T_a7429_row0_col2" class="data row0 col2" >5.93</td>
#       <td id="T_a7429_row0_col3" class="data row0 col3" >-3.15</td>
#       <td id="T_a7429_row0_col4" class="data row0 col4" >4.91</td>
#       <td id="T_a7429_row0_col5" class="data row0 col5" >-2.98</td>
#     </tr>
#     <tr>
#       <th id="T_a7429_level0_row1" class="row_heading level0 row1" >DSKY</th>
#       <td id="T_a7429_row1_col0" class="data row1 col0" >7.84</td>
#       <td id="T_a7429_row1_col1" class="data row1 col1" >4.52</td>
#       <td id="T_a7429_row1_col2" class="data row1 col2" >14.88</td>
#       <td id="T_a7429_row1_col3" class="data row1 col3" >8.06</td>
#       <td id="T_a7429_row1_col4" class="data row1 col4" >4.09</td>
#       <td id="T_a7429_row1_col5" class="data row1 col5" >-4.04</td>
#     </tr>
#     <tr>
#       <th id="T_a7429_level0_row2" class="row_heading level0 row2" >MAGN</th>
#       <td id="T_a7429_row2_col0" class="data row2 col0" >-0.72</td>
#       <td id="T_a7429_row2_col1" class="data row2 col1" >-3.40</td>
#       <td id="T_a7429_row2_col2" class="data row2 col2" >0.29</td>
#       <td id="T_a7429_row2_col3" class="data row2 col3" >-0.05</td>
#       <td id="T_a7429_row2_col4" class="data row2 col4" >-0.11</td>
#       <td id="T_a7429_row2_col5" class="data row2 col5" >3.05</td>
#     </tr>
#     <tr>
#       <th id="T_a7429_level0_row3" class="row_heading level0 row3" >NVTK</th>
#       <td id="T_a7429_row3_col0" class="data row3 col0" >0.12</td>
#       <td id="T_a7429_row3_col1" class="data row3 col1" >1.04</td>
#       <td id="T_a7429_row3_col2" class="data row3 col2" >0.82</td>
#       <td id="T_a7429_row3_col3" class="data row3 col3" >1.00</td>
#       <td id="T_a7429_row3_col4" class="data row3 col4" >0.00</td>
#       <td id="T_a7429_row3_col5" class="data row3 col5" >-4.23</td>
#     </tr>
#     <tr>
#       <th id="T_a7429_level0_row4" class="row_heading level0 row4" >SNGS</th>
#       <td id="T_a7429_row4_col0" class="data row4 col0" >-1.03</td>
#       <td id="T_a7429_row4_col1" class="data row4 col1" >2.69</td>
#       <td id="T_a7429_row4_col2" class="data row4 col2" >-2.68</td>
#       <td id="T_a7429_row4_col3" class="data row4 col3" >0.36</td>
#       <td id="T_a7429_row4_col4" class="data row4 col4" >3.08</td>
#       <td id="T_a7429_row4_col5" class="data row4 col5" >2.01</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### 3 класса

# %%
tg = pd.read_parquet('/content/drive/MyDrive/Диссертация/Парсеры сайтов/tg_comps_raw_1,5sigma_.parquet')
tg.dropna(subset=['message'],inplace=True)
tg.drop(columns=['views', 'forwards', 'fwd_from', 'source'], inplace=True)

tg_train = tg[tg.date < '2021-01-01'].copy()
tg_val = tg[(tg.date > '2021-01-01') & (tg.date < '2021-06-01')].copy()
tg_test = tg[(tg.date < '2022-01-01') & (tg.date > '2021-06-01')].copy()

# %%
loggs = pd.read_csv('/content/drive/MyDrive/Диссертация/tg_loggs/dist_bert_tg_loggs_neutral.csv', index_col=0)

# %%
companies = sorted(['ALRS', 'AFLT', 'GAZP', 'LSRG', 'DSKY', 'MAGN', 'MOEX', 'MTSS', 'ROSN', 'NVTK', 'PIKK', 'HYDR', 'CHMF', 'AFKS', 'SNGS', 'PHOR'])

# %%
effects_bert_tg_rand, effects_bert_tg_zero = get_effects_neutral(tg_train, tg_test, loggs, companies=companies)

# %%
effects_bert_tg_rand.sort_index().style.applymap(_color_red_or_green).format(precision=2)
# Out:
# <style type="text/css">
# #T_ec709_row0_col0, #T_ec709_row0_col2, #T_ec709_row0_col3, #T_ec709_row0_col4, #T_ec709_row1_col4, #T_ec709_row2_col0, #T_ec709_row2_col3, #T_ec709_row2_col4, #T_ec709_row2_col5, #T_ec709_row3_col0, #T_ec709_row3_col1, #T_ec709_row3_col2, #T_ec709_row3_col3, #T_ec709_row3_col4, #T_ec709_row3_col5, #T_ec709_row4_col0, #T_ec709_row4_col1, #T_ec709_row4_col2, #T_ec709_row4_col3, #T_ec709_row4_col4, #T_ec709_row4_col5, #T_ec709_row6_col2, #T_ec709_row6_col3, #T_ec709_row6_col4, #T_ec709_row7_col0, #T_ec709_row7_col1, #T_ec709_row7_col2, #T_ec709_row7_col3, #T_ec709_row7_col4, #T_ec709_row7_col5, #T_ec709_row8_col1, #T_ec709_row8_col4, #T_ec709_row8_col5, #T_ec709_row9_col0, #T_ec709_row9_col1, #T_ec709_row9_col2, #T_ec709_row9_col3, #T_ec709_row9_col4, #T_ec709_row9_col5, #T_ec709_row10_col0, #T_ec709_row10_col1, #T_ec709_row10_col3, #T_ec709_row10_col5, #T_ec709_row12_col0, #T_ec709_row12_col1, #T_ec709_row12_col2, #T_ec709_row12_col3, #T_ec709_row12_col4, #T_ec709_row12_col5, #T_ec709_row13_col2, #T_ec709_row14_col3, #T_ec709_row15_col0, #T_ec709_row15_col3 {
#   color: red;
# }
# #T_ec709_row0_col1, #T_ec709_row0_col5, #T_ec709_row1_col0, #T_ec709_row1_col1, #T_ec709_row1_col2, #T_ec709_row1_col3, #T_ec709_row1_col5, #T_ec709_row2_col1, #T_ec709_row2_col2, #T_ec709_row5_col0, #T_ec709_row5_col1, #T_ec709_row5_col2, #T_ec709_row5_col3, #T_ec709_row5_col4, #T_ec709_row5_col5, #T_ec709_row6_col0, #T_ec709_row6_col1, #T_ec709_row6_col5, #T_ec709_row8_col0, #T_ec709_row8_col2, #T_ec709_row8_col3, #T_ec709_row10_col2, #T_ec709_row10_col4, #T_ec709_row11_col0, #T_ec709_row11_col1, #T_ec709_row11_col2, #T_ec709_row11_col3, #T_ec709_row11_col4, #T_ec709_row11_col5, #T_ec709_row13_col0, #T_ec709_row13_col1, #T_ec709_row13_col3, #T_ec709_row13_col4, #T_ec709_row13_col5, #T_ec709_row14_col0, #T_ec709_row14_col1, #T_ec709_row14_col2, #T_ec709_row14_col4, #T_ec709_row14_col5, #T_ec709_row15_col1, #T_ec709_row15_col2, #T_ec709_row15_col4, #T_ec709_row15_col5 {
#   color: green;
# }
# </style>
# <table id="T_ec709" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ec709_level0_col0" class="col_heading level0 col0" >5 min</th>
#       <th id="T_ec709_level0_col1" class="col_heading level0 col1" >10 min</th>
#       <th id="T_ec709_level0_col2" class="col_heading level0 col2" >15 min</th>
#       <th id="T_ec709_level0_col3" class="col_heading level0 col3" >30 min</th>
#       <th id="T_ec709_level0_col4" class="col_heading level0 col4" >1 hour</th>
#       <th id="T_ec709_level0_col5" class="col_heading level0 col5" >1 day</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ec709_level0_row0" class="row_heading level0 row0" >AFKS</th>
#       <td id="T_ec709_row0_col0" class="data row0 col0" >-3.59</td>
#       <td id="T_ec709_row0_col1" class="data row0 col1" >1.96</td>
#       <td id="T_ec709_row0_col2" class="data row0 col2" >-5.60</td>
#       <td id="T_ec709_row0_col3" class="data row0 col3" >-2.38</td>
#       <td id="T_ec709_row0_col4" class="data row0 col4" >-2.12</td>
#       <td id="T_ec709_row0_col5" class="data row0 col5" >0.09</td>
#     </tr>
#     <tr>
#       <th id="T_ec709_level0_row1" class="row_heading level0 row1" >AFLT</th>
#       <td id="T_ec709_row1_col0" class="data row1 col0" >2.06</td>
#       <td id="T_ec709_row1_col1" class="data row1 col1" >2.28</td>
#       <td id="T_ec709_row1_col2" class="data row1 col2" >1.56</td>
#       <td id="T_ec709_row1_col3" class="data row1 col3" >0.89</td>
#       <td id="T_ec709_row1_col4" class="data row1 col4" >-4.61</td>
#       <td id="T_ec709_row1_col5" class="data row1 col5" >4.86</td>
#     </tr>
#     <tr>
#       <th id="T_ec709_level0_row2" class="row_heading level0 row2" >ALRS</th>
#       <td id="T_ec709_row2_col0" class="data row2 col0" >-3.16</td>
#       <td id="T_ec709_row2_col1" class="data row2 col1" >1.35</td>
#       <td id="T_ec709_row2_col2" class="data row2 col2" >1.17</td>
#       <td id="T_ec709_row2_col3" class="data row2 col3" >-1.98</td>
#       <td id="T_ec709_row2_col4" class="data row2 col4" >-3.79</td>
#       <td id="T_ec709_row2_col5" class="data row2 col5" >-0.09</td>
#     </tr>
#     <tr>
#       <th id="T_ec709_level0_row3" class="row_heading level0 row3" >CHMF</th>
#       <td id="T_ec709_row3_col0" class="data row3 col0" >-2.18</td>
#       <td id="T_ec709_row3_col1" class="data row3 col1" >-8.67</td>
#       <td id="T_ec709_row3_col2" class="data row3 col2" >-7.05</td>
#       <td id="T_ec709_row3_col3" class="data row3 col3" >-4.76</td>
#       <td id="T_ec709_row3_col4" class="data row3 col4" >-7.31</td>
#       <td id="T_ec709_row3_col5" class="data row3 col5" >-2.99</td>
#     </tr>
#     <tr>
#       <th id="T_ec709_level0_row4" class="row_heading level0 row4" >DSKY</th>
#       <td id="T_ec709_row4_col0" class="data row4 col0" >-9.19</td>
#       <td id="T_ec709_row4_col1" class="data row4 col1" >-19.53</td>
#       <td id="T_ec709_row4_col2" class="data row4 col2" >-17.59</td>
#       <td id="T_ec709_row4_col3" class="data row4 col3" >-17.72</td>
#       <td id="T_ec709_row4_col4" class="data row4 col4" >-13.51</td>
#       <td id="T_ec709_row4_col5" class="data row4 col5" >-8.28</td>
#     </tr>
#     <tr>
#       <th id="T_ec709_level0_row5" class="row_heading level0 row5" >GAZP</th>
#       <td id="T_ec709_row5_col0" class="data row5 col0" >4.06</td>
#       <td id="T_ec709_row5_col1" class="data row5 col1" >3.79</td>
#       <td id="T_ec709_row5_col2" class="data row5 col2" >2.97</td>
#       <td id="T_ec709_row5_col3" class="data row5 col3" >3.30</td>
#       <td id="T_ec709_row5_col4" class="data row5 col4" >1.93</td>
#       <td id="T_ec709_row5_col5" class="data row5 col5" >2.77</td>
#     </tr>
#     <tr>
#       <th id="T_ec709_level0_row6" class="row_heading level0 row6" >HYDR</th>
#       <td id="T_ec709_row6_col0" class="data row6 col0" >4.37</td>
#       <td id="T_ec709_row6_col1" class="data row6 col1" >4.93</td>
#       <td id="T_ec709_row6_col2" class="data row6 col2" >-0.70</td>
#       <td id="T_ec709_row6_col3" class="data row6 col3" >-0.45</td>
#       <td id="T_ec709_row6_col4" class="data row6 col4" >-2.50</td>
#       <td id="T_ec709_row6_col5" class="data row6 col5" >10.21</td>
#     </tr>
#     <tr>
#       <th id="T_ec709_level0_row7" class="row_heading level0 row7" >LSRG</th>
#       <td id="T_ec709_row7_col0" class="data row7 col0" >-11.36</td>
#       <td id="T_ec709_row7_col1" class="data row7 col1" >-10.61</td>
#       <td id="T_ec709_row7_col2" class="data row7 col2" >-10.04</td>
#       <td id="T_ec709_row7_col3" class="data row7 col3" >-7.43</td>
#       <td id="T_ec709_row7_col4" class="data row7 col4" >-9.05</td>
#       <td id="T_ec709_row7_col5" class="data row7 col5" >-6.43</td>
#     </tr>
#     <tr>
#       <th id="T_ec709_level0_row8" class="row_heading level0 row8" >MAGN</th>
#       <td id="T_ec709_row8_col0" class="data row8 col0" >3.15</td>
#       <td id="T_ec709_row8_col1" class="data row8 col1" >-0.67</td>
#       <td id="T_ec709_row8_col2" class="data row8 col2" >2.87</td>
#       <td id="T_ec709_row8_col3" class="data row8 col3" >6.46</td>
#       <td id="T_ec709_row8_col4" class="data row8 col4" >-0.23</td>
#       <td id="T_ec709_row8_col5" class="data row8 col5" >-0.80</td>
#     </tr>
#     <tr>
#       <th id="T_ec709_level0_row9" class="row_heading level0 row9" >MOEX</th>
#       <td id="T_ec709_row9_col0" class="data row9 col0" >-2.91</td>
#       <td id="T_ec709_row9_col1" class="data row9 col1" >-4.84</td>
#       <td id="T_ec709_row9_col2" class="data row9 col2" >-5.44</td>
#       <td id="T_ec709_row9_col3" class="data row9 col3" >-2.58</td>
#       <td id="T_ec709_row9_col4" class="data row9 col4" >-4.00</td>
#       <td id="T_ec709_row9_col5" class="data row9 col5" >-4.62</td>
#     </tr>
#     <tr>
#       <th id="T_ec709_level0_row10" class="row_heading level0 row10" >MTSS</th>
#       <td id="T_ec709_row10_col0" class="data row10 col0" >-3.47</td>
#       <td id="T_ec709_row10_col1" class="data row10 col1" >-0.82</td>
#       <td id="T_ec709_row10_col2" class="data row10 col2" >0.15</td>
#       <td id="T_ec709_row10_c

# %%
effects_bert_tg_zero.sort_index().style.applymap(_color_red_or_green).format(precision=2)
# Out:
# <style type="text/css">
# #T_0880d_row0_col0, #T_0880d_row0_col1, #T_0880d_row0_col2, #T_0880d_row0_col3, #T_0880d_row0_col4, #T_0880d_row0_col5, #T_0880d_row1_col1, #T_0880d_row1_col2, #T_0880d_row1_col3, #T_0880d_row1_col4, #T_0880d_row1_col5, #T_0880d_row2_col0, #T_0880d_row2_col1, #T_0880d_row2_col2, #T_0880d_row2_col3, #T_0880d_row2_col4, #T_0880d_row2_col5, #T_0880d_row3_col0, #T_0880d_row3_col3, #T_0880d_row3_col4, #T_0880d_row3_col5, #T_0880d_row4_col0, #T_0880d_row4_col1, #T_0880d_row4_col2, #T_0880d_row4_col3, #T_0880d_row4_col4, #T_0880d_row4_col5, #T_0880d_row5_col0, #T_0880d_row5_col1, #T_0880d_row5_col2, #T_0880d_row5_col3, #T_0880d_row5_col4, #T_0880d_row5_col5, #T_0880d_row6_col0, #T_0880d_row6_col1, #T_0880d_row6_col2, #T_0880d_row6_col3, #T_0880d_row6_col4, #T_0880d_row6_col5, #T_0880d_row8_col0, #T_0880d_row8_col1, #T_0880d_row8_col2, #T_0880d_row8_col3, #T_0880d_row8_col4, #T_0880d_row8_col5, #T_0880d_row9_col0, #T_0880d_row9_col1, #T_0880d_row9_col4, #T_0880d_row10_col1, #T_0880d_row10_col2, #T_0880d_row10_col3, #T_0880d_row10_col4, #T_0880d_row11_col0, #T_0880d_row11_col1, #T_0880d_row11_col2, #T_0880d_row11_col3, #T_0880d_row11_col4, #T_0880d_row11_col5, #T_0880d_row12_col1, #T_0880d_row12_col2, #T_0880d_row12_col4, #T_0880d_row12_col5, #T_0880d_row13_col1, #T_0880d_row13_col2, #T_0880d_row13_col3, #T_0880d_row13_col4, #T_0880d_row14_col1, #T_0880d_row14_col2, #T_0880d_row14_col3, #T_0880d_row14_col4, #T_0880d_row15_col0, #T_0880d_row15_col1, #T_0880d_row15_col2, #T_0880d_row15_col3, #T_0880d_row15_col4, #T_0880d_row15_col5 {
#   color: green;
# }
# #T_0880d_row1_col0, #T_0880d_row3_col1, #T_0880d_row3_col2, #T_0880d_row7_col0, #T_0880d_row7_col1, #T_0880d_row7_col2, #T_0880d_row7_col3, #T_0880d_row7_col4, #T_0880d_row7_col5, #T_0880d_row9_col2, #T_0880d_row9_col3, #T_0880d_row9_col5, #T_0880d_row10_col0, #T_0880d_row10_col5, #T_0880d_row12_col0, #T_0880d_row12_col3, #T_0880d_row13_col0, #T_0880d_row13_col5, #T_0880d_row14_col0, #T_0880d_row14_col5 {
#   color: red;
# }
# </style>
# <table id="T_0880d" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0880d_level0_col0" class="col_heading level0 col0" >5 min</th>
#       <th id="T_0880d_level0_col1" class="col_heading level0 col1" >10 min</th>
#       <th id="T_0880d_level0_col2" class="col_heading level0 col2" >15 min</th>
#       <th id="T_0880d_level0_col3" class="col_heading level0 col3" >30 min</th>
#       <th id="T_0880d_level0_col4" class="col_heading level0 col4" >1 hour</th>
#       <th id="T_0880d_level0_col5" class="col_heading level0 col5" >1 day</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0880d_level0_row0" class="row_heading level0 row0" >AFKS</th>
#       <td id="T_0880d_row0_col0" class="data row0 col0" >0.05</td>
#       <td id="T_0880d_row0_col1" class="data row0 col1" >0.04</td>
#       <td id="T_0880d_row0_col2" class="data row0 col2" >0.04</td>
#       <td id="T_0880d_row0_col3" class="data row0 col3" >0.08</td>
#       <td id="T_0880d_row0_col4" class="data row0 col4" >0.07</td>
#       <td id="T_0880d_row0_col5" class="data row0 col5" >0.05</td>
#     </tr>
#     <tr>
#       <th id="T_0880d_level0_row1" class="row_heading level0 row1" >AFLT</th>
#       <td id="T_0880d_row1_col0" class="data row1 col0" >-0.00</td>
#       <td id="T_0880d_row1_col1" class="data row1 col1" >0.09</td>
#       <td id="T_0880d_row1_col2" class="data row1 col2" >0.16</td>
#       <td id="T_0880d_row1_col3" class="data row1 col3" >0.18</td>
#       <td id="T_0880d_row1_col4" class="data row1 col4" >0.12</td>
#       <td id="T_0880d_row1_col5" class="data row1 col5" >0.12</td>
#     </tr>
#     <tr>
#       <th id="T_0880d_level0_row2" class="row_heading level0 row2" >ALRS</th>
#       <td id="T_0880d_row2_col0" class="data row2 col0" >0.08</td>
#       <td id="T_0880d_row2_col1" class="data row2 col1" >0.15</td>
#       <td id="T_0880d_row2_col2" class="data row2 col2" >0.12</td>
#       <td id="T_0880d_row2_col3" class="data row2 col3" >0.16</td>
#       <td id="T_0880d_row2_col4" class="data row2 col4" >0.19</td>
#       <td id="T_0880d_row2_col5" class="data row2 col5" >0.13</td>
#     </tr>
#     <tr>
#       <th id="T_0880d_level0_row3" class="row_heading level0 row3" >CHMF</th>
#       <td id="T_0880d_row3_col0" class="data row3 col0" >0.01</td>
#       <td id="T_0880d_row3_col1" class="data row3 col1" >-0.03</td>
#       <td id="T_0880d_row3_col2" class="data row3 col2" >-0.02</td>
#       <td id="T_0880d_row3_col3" class="data row3 col3" >0.07</td>
#       <td id="T_0880d_row3_col4" class="data row3 col4" >0.04</td>
#       <td id="T_0880d_row3_col5" class="data row3 col5" >0.04</td>
#     </tr>
#     <tr>
#       <th id="T_0880d_level0_row4" class="row_heading level0 row4" >DSKY</th>
#       <td id="T_0880d_row4_col0" class="data row4 col0" >0.02</td>
#       <td id="T_0880d_row4_col1" class="data row4 col1" >0.04</td>
#       <td id="T_0880d_row4_col2" class="data row4 col2" >0.04</td>
#       <td id="T_0880d_row4_col3" class="data row4 col3" >0.08</td>
#       <td id="T_0880d_row4_col4" class="data row4 col4" >0.11</td>
#       <td id="T_0880d_row4_col5" class="data row4 col5" >0.04</td>
#     </tr>
#     <tr>
#       <th id="T_0880d_level0_row5" class="row_heading level0 row5" >GAZP</th>
#       <td id="T_0880d_row5_col0" class="data row5 col0" >0.11</td>
#       <td id="T_0880d_row5_col1" class="data row5 col1" >0.15</td>
#       <td id="T_0880d_row5_col2" class="data row5 col2" >0.09</td>
#       <td id="T_0880d_row5_col3" class="data row5 col3" >0.20</td>
#       <td id="T_0880d_row5_col4" class="data row5 col4" >0.19</td>
#       <td id="T_0880d_row5_col5" class="data row5 col5" >0.09</td>
#     </tr>
#     <tr>
#       <th id="T_0880d_level0_row6" class="row_heading level0 row6" >HYDR</th>
#       <td id="T_0880d_row6_col0" class="data row6 col0" >0.05</td>
#       <td id="T_0880d_row6_col1" class="data row6 col1" >0.06</td>
#       <td id="T_0880d_row6_col2" class="data row6 col2" >0.07</td>
#       <td id="T_0880d_row6_col3" class="data row6 col3" >0.15</td>
#       <td id="T_0880d_row6_col4" class="data row6 col4" >0.07</td>
#       <td id="T_0880d_row6_col5" class="data row6 col5" >0.01</td>
#     </tr>
#     <tr>
#       <th id="T_0880d_level0_row7" class="row_heading level0 row7" >LSRG</th>
#       <td id="T_0880d_row7_col0" class="data row7 col0" >-0.08</td>
#       <td id="T_0880d_row7_col1" class="data row7 col1" >-0.07</td>
#       <td id="T_0880d_row7_col2" class="data row7 col2" >-0.03</td>
#       <td id="T_0880d_row7_col3" class="data row7 col3" >-0.03</td>
#       <td id="T_0880d_row7_col4" class="data row7 col4" >-0.07</td>
#       <td id="T_0880d_row7_col5" class="data row7 col5" >-0.04</td>
#     </tr>
#     <tr>
#       <th id="T_0880d_level0_row8" class="row_heading level0 row8" >MAGN</th>
#       <td id="T_0880d_row8_col0" class="data row8 col0" >0.15</td>
#       <td id="T_0880d_row8_col1" class="data row8 col1" >0.10</td>
#       <td id="T_0880d_row8_col2" class="data row8 col2" >0.16</td>
#       <td id="T_0880d_row8_col3" class="data row8 col3" >0.20</td>
#       <td id="T_0880d_row8_col4" class="data row8 col4" >0.20</td>
#       <td id="T_0880d_row8_col5" class="data row8 col5" >0.01</td>
#     </tr>
#     <tr>
#       <th id="T_0880d_level0_row9" class="row_heading level0 row9" >MOEX</th>
#       <td id="T_0880d_row9_col0" class="data row9 col0" >0.03</td>
#       <td id="T_0880d_row9_col1" class="data row9 col1" >0.04</td>
#       <td id="T_0880d_row9_col2" class="data row9 col2" >-0.04</td>
#       <td id="T_0880d_row9_col3" class="data row9 col3" >-0.00</td>
#       <td id="T_0880d_row9_col4" class="data row9 col4" >0.07</td>
#       <td id="T_0880d_row9_col5" class="data row9 col5" >-0.05</td>
#     </tr>
#     <tr>
#       <th id="T_0880d_level0_row10" class="row_heading level0 row10" >MTSS</th>
#       <td id="T_0880d_row10_col0" class="data row10 col0" >-0.01</td>
#       <td id="T_0880d_row10_col1" class="data row10 col1" >0.06</td>
#       <td id="T_0880d_row10_col2" class="data row10 col2" >0.07</td>
#       <td id="T_0880d_row10_col3" class="data row10 col3" >0.09</

# %% [markdown]
# ### Берт Традиционные новости

# %% [markdown]
# #### 2 класса

# %%
news = pd.read_parquet('/content/drive/MyDrive/Диссертация/Парсеры сайтов/news_comps_raw.parquet')
news['title'] = news['title'].str.replace('no title', '')
news['announce'] = news['announce'].str.replace('no announce', '')

news['message'] = news['title'] + ' ' + news['announce']
news = news[news['message'] != ' '].copy()
news.drop(columns=['link', 'title', 'announce', 'text'], inplace=True)
news.dropna(subset=['message'],inplace=True)

news_train = news[news.date < '2021-01-01'].copy()
news_val = news[(news.date > '2021-01-01') & (news.date < '2021-06-01')].copy()
news_test = news[(news.date < '2022-01-01') & (news.date > '2021-06-01')].copy()

# %%
loggs = pd.read_csv('/content/drive/MyDrive/Диссертация/news_loggs/dist_bert_news_loggs_bin.csv', index_col=0)

# %%
companies = sorted(['TCSG', 'GAZP', 'VTBR'])

# %%
effects_news_bert_bin = get_effects_bin(news_train, news_test, loggs, companies=companies, shortened=True)

# %%
effects_news_bert_bin.sort_index().style.applymap(_color_red_or_green).format(precision=2)
# Out:
# <style type="text/css">
# #T_b853e_row0_col0, #T_b853e_row0_col1, #T_b853e_row0_col5, #T_b853e_row2_col0, #T_b853e_row2_col1, #T_b853e_row2_col2, #T_b853e_row2_col3, #T_b853e_row2_col4, #T_b853e_row2_col5 {
#   color: green;
# }
# #T_b853e_row0_col2, #T_b853e_row0_col3, #T_b853e_row0_col4, #T_b853e_row1_col0, #T_b853e_row1_col1, #T_b853e_row1_col2, #T_b853e_row1_col3, #T_b853e_row1_col4, #T_b853e_row1_col5 {
#   color: red;
# }
# </style>
# <table id="T_b853e" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b853e_level0_col0" class="col_heading level0 col0" >5 min</th>
#       <th id="T_b853e_level0_col1" class="col_heading level0 col1" >10 min</th>
#       <th id="T_b853e_level0_col2" class="col_heading level0 col2" >15 min</th>
#       <th id="T_b853e_level0_col3" class="col_heading level0 col3" >30 min</th>
#       <th id="T_b853e_level0_col4" class="col_heading level0 col4" >1 hour</th>
#       <th id="T_b853e_level0_col5" class="col_heading level0 col5" >1 day</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b853e_level0_row0" class="row_heading level0 row0" >GAZP</th>
#       <td id="T_b853e_row0_col0" class="data row0 col0" >4.52</td>
#       <td id="T_b853e_row0_col1" class="data row0 col1" >5.04</td>
#       <td id="T_b853e_row0_col2" class="data row0 col2" >-7.83</td>
#       <td id="T_b853e_row0_col3" class="data row0 col3" >-1.54</td>
#       <td id="T_b853e_row0_col4" class="data row0 col4" >-8.07</td>
#       <td id="T_b853e_row0_col5" class="data row0 col5" >5.06</td>
#     </tr>
#     <tr>
#       <th id="T_b853e_level0_row1" class="row_heading level0 row1" >TCSG</th>
#       <td id="T_b853e_row1_col0" class="data row1 col0" >-17.54</td>
#       <td id="T_b853e_row1_col1" class="data row1 col1" >-11.33</td>
#       <td id="T_b853e_row1_col2" class="data row1 col2" >-8.51</td>
#       <td id="T_b853e_row1_col3" class="data row1 col3" >-4.88</td>
#       <td id="T_b853e_row1_col4" class="data row1 col4" >-2.73</td>
#       <td id="T_b853e_row1_col5" class="data row1 col5" >-2.83</td>
#     </tr>
#     <tr>
#       <th id="T_b853e_level0_row2" class="row_heading level0 row2" >VTBR</th>
#       <td id="T_b853e_row2_col0" class="data row2 col0" >6.11</td>
#       <td id="T_b853e_row2_col1" class="data row2 col1" >8.49</td>
#       <td id="T_b853e_row2_col2" class="data row2 col2" >8.94</td>
#       <td id="T_b853e_row2_col3" class="data row2 col3" >6.65</td>
#       <td id="T_b853e_row2_col4" class="data row2 col4" >4.41</td>
#       <td id="T_b853e_row2_col5" class="data row2 col5" >0.22</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### 3 класса

# %%
news = pd.read_parquet('/content/drive/MyDrive/Диссертация/Парсеры сайтов/news_comps_raw_1,5sigma_.parquet')
news['title'] = news['title'].str.replace('no title', '')
news['announce'] = news['announce'].str.replace('no announce', '')

news['message'] = news['title'] + ' ' + news['announce']
news = news[news['message'] != ' '].copy()
news.drop(columns=['link', 'title', 'announce', 'text'], inplace=True)
news.dropna(subset=['message'],inplace=True)

news_train = news[news.date < '2021-01-01'].copy()
news_val = news[(news.date > '2021-01-01') & (news.date < '2021-06-01')].copy()
news_test = news[(news.date < '2022-01-01') & (news.date > '2021-06-01')].copy()

# %%
loggs = pd.read_csv('/content/drive/MyDrive/Диссертация/news_loggs/dist_bert_news_loggs_neutral', index_col=0)

# %%
companies = sorted(['MTSS', 'TCSG', 'YNDX', 'RTKM', 'SBER', 'GAZP', 'VTBR'])

# %%
effects_news_bert_neutral_rand, effects_news_bert_neutral_zero = get_effects_neutral(news_train, news_test, loggs, companies=companies)

# %%
effects_news_bert_neutral_rand.sort_index().style.applymap(_color_red_or_green).format(precision=2)
# Out:
# <style type="text/css">
# #T_f5eca_row0_col0, #T_f5eca_row0_col1, #T_f5eca_row0_col2, #T_f5eca_row0_col3, #T_f5eca_row0_col4, #T_f5eca_row3_col0, #T_f5eca_row5_col0, #T_f5eca_row5_col1, #T_f5eca_row5_col2, #T_f5eca_row5_col3, #T_f5eca_row5_col4, #T_f5eca_row5_col5, #T_f5eca_row6_col3, #T_f5eca_row6_col4 {
#   color: green;
# }
# #T_f5eca_row0_col5, #T_f5eca_row1_col0, #T_f5eca_row1_col1, #T_f5eca_row1_col2, #T_f5eca_row1_col3, #T_f5eca_row1_col4, #T_f5eca_row1_col5, #T_f5eca_row2_col0, #T_f5eca_row2_col1, #T_f5eca_row2_col2, #T_f5eca_row2_col3, #T_f5eca_row2_col4, #T_f5eca_row2_col5, #T_f5eca_row3_col1, #T_f5eca_row3_col2, #T_f5eca_row3_col3, #T_f5eca_row3_col4, #T_f5eca_row3_col5, #T_f5eca_row4_col0, #T_f5eca_row4_col1, #T_f5eca_row4_col2, #T_f5eca_row4_col3, #T_f5eca_row4_col4, #T_f5eca_row4_col5, #T_f5eca_row6_col0, #T_f5eca_row6_col1, #T_f5eca_row6_col2, #T_f5eca_row6_col5 {
#   color: red;
# }
# </style>
# <table id="T_f5eca" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f5eca_level0_col0" class="col_heading level0 col0" >5 min</th>
#       <th id="T_f5eca_level0_col1" class="col_heading level0 col1" >10 min</th>
#       <th id="T_f5eca_level0_col2" class="col_heading level0 col2" >15 min</th>
#       <th id="T_f5eca_level0_col3" class="col_heading level0 col3" >30 min</th>
#       <th id="T_f5eca_level0_col4" class="col_heading level0 col4" >1 hour</th>
#       <th id="T_f5eca_level0_col5" class="col_heading level0 col5" >1 day</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f5eca_level0_row0" class="row_heading level0 row0" >GAZP</th>
#       <td id="T_f5eca_row0_col0" class="data row0 col0" >2.06</td>
#       <td id="T_f5eca_row0_col1" class="data row0 col1" >2.38</td>
#       <td id="T_f5eca_row0_col2" class="data row0 col2" >3.77</td>
#       <td id="T_f5eca_row0_col3" class="data row0 col3" >4.58</td>
#       <td id="T_f5eca_row0_col4" class="data row0 col4" >1.40</td>
#       <td id="T_f5eca_row0_col5" class="data row0 col5" >-0.94</td>
#     </tr>
#     <tr>
#       <th id="T_f5eca_level0_row1" class="row_heading level0 row1" >MTSS</th>
#       <td id="T_f5eca_row1_col0" class="data row1 col0" >-5.42</td>
#       <td id="T_f5eca_row1_col1" class="data row1 col1" >-0.51</td>
#       <td id="T_f5eca_row1_col2" class="data row1 col2" >-0.65</td>
#       <td id="T_f5eca_row1_col3" class="data row1 col3" >-1.29</td>
#       <td id="T_f5eca_row1_col4" class="data row1 col4" >-6.83</td>
#       <td id="T_f5eca_row1_col5" class="data row1 col5" >-10.19</td>
#     </tr>
#     <tr>
#       <th id="T_f5eca_level0_row2" class="row_heading level0 row2" >RTKM</th>
#       <td id="T_f5eca_row2_col0" class="data row2 col0" >-19.40</td>
#       <td id="T_f5eca_row2_col1" class="data row2 col1" >-8.49</td>
#       <td id="T_f5eca_row2_col2" class="data row2 col2" >-8.13</td>
#       <td id="T_f5eca_row2_col3" class="data row2 col3" >-6.77</td>
#       <td id="T_f5eca_row2_col4" class="data row2 col4" >-7.01</td>
#       <td id="T_f5eca_row2_col5" class="data row2 col5" >-5.62</td>
#     </tr>
#     <tr>
#       <th id="T_f5eca_level0_row3" class="row_heading level0 row3" >SBER</th>
#       <td id="T_f5eca_row3_col0" class="data row3 col0" >0.59</td>
#       <td id="T_f5eca_row3_col1" class="data row3 col1" >-0.61</td>
#       <td id="T_f5eca_row3_col2" class="data row3 col2" >-0.21</td>
#       <td id="T_f5eca_row3_col3" class="data row3 col3" >-4.26</td>
#       <td id="T_f5eca_row3_col4" class="data row3 col4" >-4.57</td>
#       <td id="T_f5eca_row3_col5" class="data row3 col5" >-9.07</td>
#     </tr>
#     <tr>
#       <th id="T_f5eca_level0_row4" class="row_heading level0 row4" >TCSG</th>
#       <td id="T_f5eca_row4_col0" class="data row4 col0" >-17.46</td>
#       <td id="T_f5eca_row4_col1" class="data row4 col1" >-17.81</td>
#       <td id="T_f5eca_row4_col2" class="data row4 col2" >-10.06</td>
#       <td id="T_f5eca_row4_col3" class="data row4 col3" >-23.44</td>
#       <td id="T_f5eca_row4_col4" class="data row4 col4" >-6.89</td>
#       <td id="T_f5eca_row4_col5" class="data row4 col5" >-5.00</td>
#     </tr>
#     <tr>
#       <th id="T_f5eca_level0_row5" class="row_heading level0 row5" >VTBR</th>
#       <td id="T_f5eca_row5_col0" class="data row5 col0" >4.47</td>
#       <td id="T_f5eca_row5_col1" class="data row5 col1" >5.58</td>
#       <td id="T_f5eca_row5_col2" class="data row5 col2" >6.50</td>
#       <td id="T_f5eca_row5_col3" class="data row5 col3" >9.21</td>
#       <td id="T_f5eca_row5_col4" class="data row5 col4" >9.51</td>
#       <td id="T_f5eca_row5_col5" class="data row5 col5" >12.66</td>
#     </tr>
#     <tr>
#       <th id="T_f5eca_level0_row6" class="row_heading level0 row6" >YNDX</th>
#       <td id="T_f5eca_row6_col0" class="data row6 col0" >-2.09</td>
#       <td id="T_f5eca_row6_col1" class="data row6 col1" >-6.79</td>
#       <td id="T_f5eca_row6_col2" class="data row6 col2" >-6.22</td>
#       <td id="T_f5eca_row6_col3" class="data row6 col3" >1.73</td>
#       <td id="T_f5eca_row6_col4" class="data row6 col4" >1.62</td>
#       <td id="T_f5eca_row6_col5" class="data row6 col5" >-9.23</td>
#     </tr>
#   </tbody>
# </table>

# %%
effects_news_bert_neutral_zero.sort_index().style.applymap(_color_red_or_green).format(precision=2)
# Out:
# <style type="text/css">
# #T_f6e03_row0_col0, #T_f6e03_row0_col1, #T_f6e03_row0_col2, #T_f6e03_row0_col3, #T_f6e03_row0_col4, #T_f6e03_row1_col1, #T_f6e03_row1_col2, #T_f6e03_row1_col4, #T_f6e03_row2_col2, #T_f6e03_row2_col3, #T_f6e03_row2_col4, #T_f6e03_row2_col5, #T_f6e03_row3_col0, #T_f6e03_row3_col1, #T_f6e03_row3_col2, #T_f6e03_row3_col3, #T_f6e03_row3_col4, #T_f6e03_row3_col5, #T_f6e03_row4_col3, #T_f6e03_row4_col5, #T_f6e03_row5_col0, #T_f6e03_row5_col1, #T_f6e03_row5_col2, #T_f6e03_row5_col3, #T_f6e03_row5_col4, #T_f6e03_row5_col5, #T_f6e03_row6_col0, #T_f6e03_row6_col1, #T_f6e03_row6_col2, #T_f6e03_row6_col3, #T_f6e03_row6_col4 {
#   color: green;
# }
# #T_f6e03_row0_col5, #T_f6e03_row1_col0, #T_f6e03_row1_col3, #T_f6e03_row1_col5, #T_f6e03_row2_col0, #T_f6e03_row2_col1, #T_f6e03_row4_col0, #T_f6e03_row4_col1, #T_f6e03_row4_col2, #T_f6e03_row4_col4, #T_f6e03_row6_col5 {
#   color: red;
# }
# </style>
# <table id="T_f6e03" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f6e03_level0_col0" class="col_heading level0 col0" >5 min</th>
#       <th id="T_f6e03_level0_col1" class="col_heading level0 col1" >10 min</th>
#       <th id="T_f6e03_level0_col2" class="col_heading level0 col2" >15 min</th>
#       <th id="T_f6e03_level0_col3" class="col_heading level0 col3" >30 min</th>
#       <th id="T_f6e03_level0_col4" class="col_heading level0 col4" >1 hour</th>
#       <th id="T_f6e03_level0_col5" class="col_heading level0 col5" >1 day</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f6e03_level0_row0" class="row_heading level0 row0" >GAZP</th>
#       <td id="T_f6e03_row0_col0" class="data row0 col0" >0.07</td>
#       <td id="T_f6e03_row0_col1" class="data row0 col1" >0.14</td>
#       <td id="T_f6e03_row0_col2" class="data row0 col2" >0.14</td>
#       <td id="T_f6e03_row0_col3" class="data row0 col3" >0.21</td>
#       <td id="T_f6e03_row0_col4" class="data row0 col4" >0.19</td>
#       <td id="T_f6e03_row0_col5" class="data row0 col5" >-0.00</td>
#     </tr>
#     <tr>
#       <th id="T_f6e03_level0_row1" class="row_heading level0 row1" >MTSS</th>
#       <td id="T_f6e03_row1_col0" class="data row1 col0" >-0.01</td>
#       <td id="T_f6e03_row1_col1" class="data row1 col1" >0.02</td>
#       <td id="T_f6e03_row1_col2" class="data row1 col2" >0.01</td>
#       <td id="T_f6e03_row1_col3" class="data row1 col3" >-0.00</td>
#       <td id="T_f6e03_row1_col4" class="data row1 col4" >0.00</td>
#       <td id="T_f6e03_row1_col5" class="data row1 col5" >-0.05</td>
#     </tr>
#     <tr>
#       <th id="T_f6e03_level0_row2" class="row_heading level0 row2" >RTKM</th>
#       <td id="T_f6e03_row2_col0" class="data row2 col0" >-0.17</td>
#       <td id="T_f6e03_row2_col1" class="data row2 col1" >-0.04</td>
#       <td id="T_f6e03_row2_col2" class="data row2 col2" >0.09</td>
#       <td id="T_f6e03_row2_col3" class="data row2 col3" >0.08</td>
#       <td id="T_f6e03_row2_col4" class="data row2 col4" >0.08</td>
#       <td id="T_f6e03_row2_col5" class="data row2 col5" >0.13</td>
#     </tr>
#     <tr>
#       <th id="T_f6e03_level0_row3" class="row_heading level0 row3" >SBER</th>
#       <td id="T_f6e03_row3_col0" class="data row3 col0" >0.09</td>
#       <td id="T_f6e03_row3_col1" class="data row3 col1" >0.09</td>
#       <td id="T_f6e03_row3_col2" class="data row3 col2" >0.10</td>
#       <td id="T_f6e03_row3_col3" class="data row3 col3" >0.10</td>
#       <td id="T_f6e03_row3_col4" class="data row3 col4" >0.10</td>
#       <td id="T_f6e03_row3_col5" class="data row3 col5" >0.02</td>
#     </tr>
#     <tr>
#       <th id="T_f6e03_level0_row4" class="row_heading level0 row4" >TCSG</th>
#       <td id="T_f6e03_row4_col0" class="data row4 col0" >-0.14</td>
#       <td id="T_f6e03_row4_col1" class="data row4 col1" >-0.06</td>
#       <td id="T_f6e03_row4_col2" class="data row4 col2" >-0.01</td>
#       <td id="T_f6e03_row4_col3" class="data row4 col3" >0.00</td>
#       <td id="T_f6e03_row4_col4" class="data row4 col4" >-0.02</td>
#       <td id="T_f6e03_row4_col5" class="data row4 col5" >0.03</td>
#     </tr>
#     <tr>
#       <th id="T_f6e03_level0_row5" class="row_heading level0 row5" >VTBR</th>
#       <td id="T_f6e03_row5_col0" class="data row5 col0" >0.04</td>
#       <td id="T_f6e03_row5_col1" class="data row5 col1" >0.21</td>
#       <td id="T_f6e03_row5_col2" class="data row5 col2" >0.23</td>
#       <td id="T_f6e03_row5_col3" class="data row5 col3" >0.27</td>
#       <td id="T_f6e03_row5_col4" class="data row5 col4" >0.25</td>
#       <td id="T_f6e03_row5_col5" class="data row5 col5" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_f6e03_level0_row6" class="row_heading level0 row6" >YNDX</th>
#       <td id="T_f6e03_row6_col0" class="data row6 col0" >0.09</td>
#       <td id="T_f6e03_row6_col1" class="data row6 col1" >0.05</td>
#       <td id="T_f6e03_row6_col2" class="data row6 col2" >0.05</td>
#       <td id="T_f6e03_row6_col3" class="data row6 col3" >0.01</td>
#       <td id="T_f6e03_row6_col4" class="data row6 col4" >0.09</td>
#       <td id="T_f6e03_row6_col5" class="data row6 col5" >-0.12</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Перезапуск обученных моделей

# %%
# df = pd.read_csv('/content/drive/MyDrive/Диссертация/tg_loggs/all_loggs_neutral_boosting.csv')
# targets = tg.iloc[:,3:].columns
# for company in companies:
#   n_jobs=-1
#   print(company)
#   os.makedirs(f'/content/drive/MyDrive/Диссертация/tg_loggs/{company}', exist_ok=True)
#   first_dates = pd.read_csv(f'/content/drive/MyDrive/Диссертация/Парсеры сайтов/Стоимость акций/1 мин/first_dates.csv', index_col='company')
#   first_day = pd.to_datetime(first_dates.loc[company,:].values[0])
#   comp = tg[tg[company] == True].copy()
#   comp = comp[comp.date >= first_day].copy()
#   comp.dropna(inplace=True)

#   tfidf = TfidfVectorizer(sublinear_tf=True, min_df=5, ngram_range=(1,2))

#   train, test = comp.iloc[:int(0.8*len(comp)), :], comp.iloc[int(0.8*len(comp)):, :]
#   tfidf.fit(comp['message'])

#   features_train = tfidf.transform(train['message'])
#   features_test = tfidf.transform(test['message'])

#   features_train = np.asarray(features_train.todense())
#   features_test = np.asarray(features_test.todense())

#   tr = [col for col in targets if company in col]
#   if company in tr:
#     tr.remove(company)

#   for t in tr:
#     y_train = train[t].values.astype(int)
#     y_test = test[t].values.astype(int)

#     filename = f'/content/drive/MyDrive/Диссертация/tg_loggs/{company}/{t}_neutral_boosting.sav'
#     gc = pickle.load(open(filename, 'rb'))

#     preds_test = gc.predict(features_test)
#     preds_train = gc.predict(features_train)

#     preds_proba_test = gc.predict_proba(features_test)
#     preds_proba_train = gc.predict_proba(features_train)

#     acc_test = accuracy_score(y_test, preds_test)
#     acc_train = accuracy_score(y_train, preds_train)

#     pre_test = precision_score(y_test, preds_test, average='micro')
#     pre_train = precision_score(y_train, preds_train, average='micro')

#     rec_test = recall_score(y_test, preds_test, average='micro')
#     rec_train = recall_score(y_train, preds_train, average='micro')

#     auc_test = roc_auc_score(y_test, preds_proba_test, average='weighted', multi_class='ovo')
#     auc_train = roc_auc_score(y_train, preds_proba_train, average='weighted', multi_class='ovo')

#     f1_test = f1_score(y_test, preds_test, average='micro')
#     f1_train = f1_score(y_train, preds_train, average='micro')

#     df[t] = [acc_test, acc_train, pre_test, pre_train, rec_test, rec_train, auc_test, auc_train, f1_test, f1_train]

#     df.to_csv('/content/drive/MyDrive/Диссертация/tg_loggs/all_loggs_neutral_boosting.csv', index=False)
